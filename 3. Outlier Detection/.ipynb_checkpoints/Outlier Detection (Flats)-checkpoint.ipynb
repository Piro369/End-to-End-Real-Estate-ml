# %% [markdown]
# # Outline
# - Use Multivariate and Univariate Techniques to identify Outliers.

# %% [markdown]
# - Apply Multivariate Techniques on Area,Bath(s),Bedroom(s),Kitchens, etc

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
flats = pd.read_csv('C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/EDA/flats.csv',index_col=0)

# %%
flats.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1743 entries, 7 to 6481
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Building                            1743 non-null   str
#  1   Main Location                       1743 non-null   str
#  2   Type                                1743 non-null   str
#  3   Price(Cr)                           1743 non-null   float64
#  4   Bath(s)                             1722 non-null   float64
#  5   Area(Marla)                         1743 non-null   float64
#  6   Bedroom(s)                          1703 non-null   float64
#  7   Description                         1743 non-null   str
#  8   Amenities: Main Features            1613 non-null   str
#  9   Amenities: Rooms                    1545 non-null   str
#  10  Amenities: Healthcare Recreational  1268 non-null   str
#  11  Amenities: Other Facilities         1516 non-null   str
#  12  IsPrimeLoc                          1743 non-null   bool
#  13  SolarInstalled                      1743 non-null   bool
#  14  WaterBore                           1743 non-null   bool
#  15  CornerHouse                         1743 non-null   bool
#  16  luxury_type                         1743 non-null   int64
#  17  Built in year                       1416 non-null   float64
#  18  Parking Spaces                      1507 non-null   float64
#  19  Floor                               1139 non-null   float64
#  20  Lobby in Building                   1245 non-null   float64
#  21  Elevators                           1145 non-null   float64
#  22  Service Elevators in Building       1093 non-null   float64
#  23  Floor in Building                   1138 non-null   float64
#  24  Bedrooms                            1480 non-null   float64
#  25  Bathrooms                           1489 non-null   float64
#  26  Servant Quarters                    1065 non-null   float64
#  27  Kitchens                            1488 non-null   float64
#  28  Store Rooms                         1126 non-null   float64
#  29  Swimming Pool                       0 non-null      float64
#  30  Sauna                               1095 non-null   float64
#  31  Jacuzzi                             1087 non-null   float64
#  32  Security Staff                      1512 non-null   float64
#  33  Maintenance Staff                   1296 non-null   float64
#  34  Facilities for Disabled             1122 non-null   float64
#  35  Laundry or Dry Cleaning Facility    726 non-null    float64
#  36  Communal/Shared Kitchen             539 non-null    float64
#  37  Storey Unit                         229 non-null    float64
# dtypes: bool(4), float64(25), int64(1), str(8)
# memory usage: 2.3 MB

# %%
flats.isnull().sum()
# Out:
# Type                                       0
# Price(Cr)                                  0
# Bath(s)                                    9
# Area(Marla)                                0
# Bedroom(s)                                17
# Location                                   0
# Description                                0
# Amenities: Main Features                  42
# Amenities: Rooms                          72
# Amenities: Business and Communication     97
# Amenities: Community Features             93
# Amenities: Healthcare Recreational       192
# Amenities: Other Facilities               92
# IsPrimeLoc                                 0
# SolarInstalled                             0
# WaterBore                                  0
# CornerHouse                                0
# luxury_type                                0
# Built in year                            119
# Parking Spaces                            82
# Floor                                    239
# Lobby in Building                        196
# Elevators                                217
# Service Elevators in Building            252
# Floor in Building                        236
# Bedrooms                                  97
# Bathrooms                                 95
# Servant Quarters                         276
# Kitchens                                  96
# Store Rooms                              237
# Community Swimming Pool                  180
# Community Gym                            154
# Swimming Pool                            730
# Sauna                                    265
# Jacuzzi                                  273
# Security Staff                            94
# Maintenance Staff                        181
# Facilities for Disabled                  273
# Laundry or Dry Cleaning Facility         413
# Communal/Shared Kitchen                  504
# Storey Unit                              644
# dtype: int64

# %%
flats.describe()
# Out:
#         Price(Cr)     Bath(s)  Area(Marla)  Bedroom(s)  luxury_type  \
# count  730.000000  721.000000   730.000000  713.000000   730.000000
# mean     3.104210    2.239945     6.128767    2.099579     0.167123
# std      4.034678    1.139865     3.963211    1.016666     0.373342
# min      0.230000    1.000000     1.000000    0.000000     0.000000
# 25%      0.855000    1.000000     3.200000    1.000000     0.000000
# 50%      1.550000    2.000000     5.100000    2.000000     0.000000
# 75%      3.350000    3.000000     7.600000    3.000000     0.000000
# max     32.000000    7.000000    36.000000   11.000000     1.000000
#
#        Built in year  Parking Spaces       Floor  Lobby in Building  \
# count     611.000000      648.000000  491.000000              534.0
# mean     1790.965630        1.945988    3.918534                1.0
# std       643.891637        5.683446    4.588971                0.0
# min         1.000000        1.000000    1.000000                1.0
# 25%      2019.000000        1.000000    1.000000                1.0
# 50%      2023.000000        1.000000    3.000000                1.0
# 75%      2025.000000        2.000000    5.000000                1.0
# max      2054.000000      100.000000   40.000000                1.0
#
#         Elevators  ...  Community Gym  Swimming Pool  Sauna  Jacuzzi  \
# count  513.000000  ...          576.0            0.0  465.0    457.0
# mean     2.717349  ...            1.0            NaN    1.0      1.0
# std      2.331851  ...            0.0            NaN    0.0      0.0
# min      1.000000  ...            1.0            NaN    1.0      1.0
# 25%      1.000000  ...            1.0            NaN    1.0      1.0
# 50%      2.000000  ...            1.0            NaN    1.0      1.0
# 75%      4.000000  ...            1.0            NaN    1.0      1.0
# max     16.000000  ...            1.0            NaN    1.0      1.0
#
#        Security Staff  Maintenance Staff  Facilities for Disabled  \
# count           636.0              549.0                    457.0
# mean              1.0                1.0                      1.0
# std               0.0                0.0                      0.0
# min               1.0                1.0                      1.0
# 25%               1.0                1.0                      1.0
# 50%               1.0                1.0                      1.0
# 75%               1.0                1.0                      1.0
# max               1.0                1.0                      1.0
#
#        Laundry or Dry Cleaning Facility  Communal/Shared Kitchen  Storey Unit
# count                             317.0                    226.0    86.000000
# mean                                1.0                      1.0     1.988372
# std                                 0.0                      0.0     0.833055
# min                                 1.0                      1.0     1.000000
# 25%                                 1.0                      1.0     1.000000
# 50%                                 1.0                      1.0     2.000000
# 75%                                 1.0                      1.0     3.000000
# max                                 1.0                      1.0     3.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# ## Univariate Approach
# - Z Score --> Normal Distributions
# - IQR --> Non Normal Distributions

# %%
# Price

# %%
sns.boxplot(flats['Price(Cr)'])
# Out:
# <Axes: ylabel='Price(Cr)'>

# %%
# Investigating flats above the price of 10
flats[flats['Price(Cr)']>10]
# Out:
#            Type  Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s)  \
# 153        Flat      19.64      4.0         13.4         2.0
# 154        Flat      17.17      5.0         11.7         3.0
# 195        Flat      14.93      3.0         12.6         3.0
# 254        Flat      13.25      4.0         11.8         3.0
# 282        Flat      19.64      4.0         13.4         2.0
# 413        Flat      14.68      3.0         10.0         2.0
# 476        Flat      14.00      4.0         12.4         4.0
# 477        Flat      13.25      5.0         12.4         4.0
# 496        Flat      23.00      6.0         19.3         4.0
# 571        Flat      12.50      3.0         12.2         3.0
# 660        Flat      17.17      5.0         11.7         3.0
# 663        Flat      17.17      5.0         11.7         3.0
# 677        Flat      17.17      5.0         11.7         3.0
# 678        Flat      19.64      4.0         13.4         2.0
# 679        Flat      19.64      4.0         13.4         2.0
# 684        Flat      17.17      5.0         11.7         3.0
# 698        Flat      17.17      5.0         11.7         3.0
# 700        Flat      19.64      4.0         13.4         2.0
# 701        Flat      19.64      4.0         13.4         2.0
# 702        Flat      19.64      4.0         13.4         2.0
# 704        Flat      19.64      4.0         13.4         2.0
# 709        Flat      16.00      4.0         14.8         3.0
# 718        Flat      19.64      4.0         13.4         2.0
# 719        Flat      19.64      4.0         13.4         2.0
# 720        Flat      19.64      4.0         13.4         2.0
# 721        Flat      19.64      4.0         13.4         2.0
# 723        Flat      21.00      6.0         20.0         4.0
# 817        Flat      11.50      4.0         11.7         4.0
# 899        Flat      13.00      4.0         12.0         3.0
# 1039       Flat      13.50      4.0         11.8         3.0
# 1183       Flat      13.00      4.0         11.7         3.0
# 1448       Flat      22.50      4.0         16.7         4.0
# 1701       Flat      15.25      3.0         11.7         3.0
# 1855       Flat      14.00      3.0         12.6         3.0
# 2012  Penthouse      14.00      NaN         20.0         NaN
# 2076       Flat      11.00      2.0         10.0         2.0
# 2163       Flat      13.28      2.0          9.8         2.0
# 2308       Flat      14.00      3.0         24.0         3.0
# 2411       Flat      13.25      4.0         11.3         3.0
# 2420  Penthouse      13.50      4.0         24.0         3.0
# 2445  Penthouse      32.00      6.0         22.0         5.0
#
#                           Location  \
# 153                            F-8
# 154                            F-8
# 195                           F-10
# 254   Karakoram Diplomatic Enclave
# 282                            F-8
# 413                            F-8
# 476                           F-10
# 477                           F-10
# 496            Constitution Avenue
# 571             Diplomatic Enclave
# 660                            F-8
# 663                            F-8
# 677                            F-8
# 678                            F-8
# 679                            F-8
# 684                            F-8
# 698                            F-8
# 700                            F-8
# 701                            F-8
# 702                            F-8
# 704                            F-8
# 709                      Blue Area
# 718                            F-8
# 719                            F-8
# 720                            F-8
# 721                            F-8
# 723                            F-8
# 817                           F-10
# 899                            F-8
# 1039  Karakoram Diplomatic Enclave
# 1183                           F-8
# 1448                 New Blue Area
# 1701                           F-8
# 1855                           F-8
# 2012                      Eighteen
# 2076                           F-8
# 2163                 New Blue Area
# 2308                          F-11
# 2411  Karakoram Diplomatic Enclave
# 2420                          F-11
# 2445                          F-10
#
#                                             Description  \
# 153   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 154   Purchase Directly from Centaurus Managment Thr...
# 195   Flat Is Available on Easy Installments in Tall...
# 254   Luxurious 3-Bedroom Fully Furnished Corner Apa...
# 282   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 413   One Bedroom Apartment With Maid Room Demand: P...
# 476   Best opportunity for investment. . . . Brand N...
# 477   4bed Corner apartment available for Sale in Su...
# 496   4-Bedroom Apartment for Sale One Constitution ...
# 571   3 Bedroom Modern Apartment Furnished Margalla ...
# 660   *Purchase Directly from Centaurus Managment *T...
# 663   Three Bedroom Apartment with Maid Room Demand:...
# 677   Three Bedroom Apartment with Maid Room Demand:...
# 678   Ultra Luxury 2 Bedroom Duplex Apartment With M...
# 679   Two Bedroom Duplex Apartment With Maid Room De...
# 684   -Three Bedroom Apartment With Maid Room -Deman...
# 698   -Three Bedroom Apartment With Maid Room -Deman...
# 700   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 701   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 702   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 704   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 709   Elegant 3-Bed Apartment For Sale Prime Locatio...
# 718   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 719   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 720   Ultra Luxury Two Bedroom Duplex Apartment with...
# 721   Ultra Luxury 2 Bedroom Duplex Apartment with M...
# 723   Demand Pkr. 210,000,000/-?price per sqft: PKR ...
# 817   Available For Sale Brand New Luxury Corner Apa...
# 899   Luxury Fully Furnished apartments available fo...
# 1039  Karakoram 3 bed rooms apartment with covered a...
# 1183  Centaurus Luxury Apartment 3 Bed Attach Bath T...
# 1448  Available Options: 4-Bedroom Apartment: 3750 s...
# 1701  3 Bedroom with attach washroom, Drawing Dining...
# 1855  ideal location on 16th floor fully furnished 3...
# 2012  Luxurious Penthouse with Full Golf Course & La...
# 2076  2 Bed Corner Fully Furnished. Luxury Apartment...
# 2163  New blue area Apartments for Sale opposite to ...
# 2308  This modern Apartment sits on 5500 square feet...
# 2411  FULLY FURNISHED 03 BEDROOMS, Drawing Dining Ro...
# 2420  Dream home in Islamabad! Welcome to Executive ...
# 2445  Spacious 5-Bedroom Penthouse for Sale in Sukh ...
#
#                                Amenities: Main Features  \
# 153   Built in year: 2020, Parking Spaces: 1, Lobby ...
# 154   Built in year: 2023, Parking Spaces, Lobby in ...
# 195   Built in year: 2026, Parking Spaces: 4, Lobby ...
# 254   Lobby in Building, Central Air Conditioning, C...
# 282   Built in year: 2022, Parking Spaces: 1, Lobby ...
# 413   Built in year, Parking Spaces: 1, Lobby in Bui...
# 476   Built in year: 2025, Parking Spaces: 2, Lobby ...
# 477   Built in year: 2025, Parking Spaces: 2, Lobby ...
# 496   Built in year: 2023, Parking Spaces: 3, Lobby ...
# 571   Parking Spaces: 4, Double Glazed Windows, Cent...
# 660   Built in year: 2022, Parking Spaces: 1, Lobby ...
# 663   Built in year: 2023, Parking Spaces: 1, Lobby ...
# 677   Built in year: 2023, Parking Spaces: 1, Lobby ...
# 678   Built in year, Parking Spaces: 1, Lobby in Bui...
# 679   Built in year: 2010, Parking Spaces: 1, Lobby ...
# 684   Built in year: 2024, Parking Spaces: 1, Lobby ...
# 698   Built in year: 2024, Parking Spaces: 1, Lobby ...
# 700   Parking Spaces: 1, Lobby in Building, Double G...
# 701   Built in year, Parking Spaces: 1, Lobby in Bui...
# 702   Built in year: 2025, Parking Spaces: 1, Lobby ...
# 704   Built in year: 2024, Parking Spaces: 1, Lobby ...
# 709   Built in year: 2025, Parking Spaces: 2, Lobby ...
# 718   Parking Spaces: 1, Lobby in Building, Double G...
# 719   Built in year: 2024, Parking Spaces: 1, Lobby ...
# 720   Built in year: 2024, Parking Spaces: 1, Lobby ...
# 721   Built in year: 2015, Parking Spaces: 1, Lobby ...
# 723   Built in year: 2009, Parking Spaces: 1, Lobby ...
# 817   Built in year: 2024, Parking Spaces: 2, Lobby ...
# 899   Built in year: 2025, Parking Spaces: 2, Lobby ...
# 1039  Built in year: 2018, Parking Spaces: 01, Lobby...
# 1183  Built in year: 2025, Parking Spaces, Lobby in ...
# 1448  Built in year, Parking Spaces, Lobby in Buildi...
# 1701  Parking Spaces: 1, Lobby in Building, Double G...
# 1855  Built in year: 2010, Parking Spaces: 1, Lobby ...
# 2012                                                NaN
# 2076  Parking Spaces, Lobby in Building, Double Glaz...
# 2163  Built in year: 2025, Parking Spaces: 2, Lobby ...
# 2308  Built in year: 2022, Parking Spaces: 2, Lobby ...
# 2411  Built in year: 2021, Parking Spaces: 1, Lobby ...
# 2420                                                NaN
# 2445                                                NaN
#
#                                        Amenities: Rooms  \
# 153   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 154   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 195   Bedrooms: 3, Bathrooms: 3, Servant Quarters: 2...
# 254                                                 NaN
# 282   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 413   Bedrooms: 2, Bathrooms: 1, Servant Quarters: 2...
# 476   Bedrooms: 4, Bathrooms: 4, Servant Quarters: 1...
# 477   Bedrooms: 4, Bathrooms: 5, Servant Quarters: 2...
# 496   Bedrooms: 4, Bathrooms: 7, Servant Quarters: 1...
# 571   Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 660   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 663   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 677   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 678   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 679   Bedrooms: 2, Bathrooms: 5, Servant Quarters: 1...
# 684   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 698   Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 700   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 701   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 702   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 704   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 709   Bedrooms: 3, Bathrooms: 4, Servant Quarters: 2...
# 718   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 719   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 720   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 721   Bedrooms: 2, Bathrooms: 4, Servant Quarters: 1...
# 723   Bedrooms: 4, Bathrooms: 6, Servant Quarters: 1...
# 817   Bedrooms: 4, Bathrooms: 4, Servant Quarters: 1...
# 899   Bedrooms: 3, Bathrooms: 4, Servant Quarters: 1...
# 1039  Bedrooms: 3, Bathrooms: 4, Servant Quarters: 0...
# 1183                                                NaN
# 1448  Bedrooms: 4, Bathrooms: 4, Servant Quarters, D...
# 1701  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 1855  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 2012                                                NaN
# 2076  Bedrooms: 2, Bathrooms: 2, Drawing Room, Dinin...
# 2163  Bedrooms: 2, Bathrooms: 2, Servant Quarters: 4...
# 2308  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 2411  Bedrooms: 3, Bathrooms: 4, Drawing Room, Dinin...
# 2420                                                NaN
# 2445                                                NaN
#
#                   Amenities: Business and Communication  ... Community Gym  \
# 153   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 154   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 195   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 254   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 282   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 413   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 476   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 477   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 496   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 571   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 660   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 663   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 677   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 678   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 679   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 684   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 698   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 700   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 701   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 702   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 704   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 709   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 718   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 719   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 720   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 721   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 723   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 817   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 899   Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1039  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1183  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1448  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1701  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1855  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2012                                                NaN  ...           NaN
# 2076  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2163  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2308  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2411  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2420                                                NaN  ...           NaN
# 2445                                                NaN  ...           NaN
#
#      Swimming Pool Sauna  Jacuzzi  Security Staff  Maintenance Staff  \
# 153            NaN   1.0      1.0             1.0                1.0
# 154            NaN   1.0      1.0             1.0                1.0
# 195            NaN   1.0      1.0             1.0                1.0
# 254            NaN   NaN      NaN             1.0                1.0
# 282            NaN   1.0      1.0             1.0                1.0
# 413            NaN   1.0      1.0             1.0                1.0
# 476            NaN   1.0      1.0             1.0                1.0
# 477            NaN   1.0      1.0             1.0                1.0
# 496            NaN   1.0      1.0             1.0                1.0
# 571            NaN   NaN      NaN             1.0                NaN
# 660            NaN   1.0      1.0             1.0                1.0
# 663            NaN   1.0      1.0             1.0                1.0
# 677            NaN   1.0      1.0             1.0                1.0
# 678            NaN   1.0      1.0             1.0                1.0
# 679            NaN   1.0      1.0             1.0                1.0
# 684            NaN   1.0      1.0             1.0                1.0
# 698            NaN   1.0      1.0             1.0                1.0
# 700            NaN   1.0      1.0             1.0                NaN
# 701            NaN   1.0      1.0             1.0                1.0
# 702            NaN   1.0      1.0             1.0                1.0
# 704            NaN   1.0      1.0             1.0                1.0
# 709            NaN   1.0      NaN             1.0                1.0
# 718            NaN   1.0      1.0             1.0                NaN
# 719            NaN   1.0      1.0             1.0                1.0
# 720            NaN   1.0      1.0             1.0                1.0
# 721            NaN   1.0      1.0             1.0                1.0
# 723            NaN   1.0      1.0             1.0                1.0
# 817            NaN   1.0      1.0             1.0                1.0
# 899            NaN   1.0      1.0             1.0                1.0
# 1039           NaN   1.0      1.0             1.0                1.0
# 1183           NaN   NaN      NaN             1.0                1.0
# 1448           NaN   1.0      1.0             1.0                1.0
# 1701           NaN   1.0      1.0             1.0                NaN
# 1855           NaN   1.0      1.0             1.0                1.0
# 2012           NaN   NaN      NaN             NaN                NaN
# 2076           NaN   NaN      NaN             NaN                NaN
# 2163           NaN   1.0      1.0             1.0                1.0
# 2308           NaN   NaN      NaN             1.0                1.0
# 2411           NaN   1.0      1.0             1.0                1.0
# 2420           NaN   NaN      NaN             NaN                NaN
# 2445           NaN   NaN      NaN             NaN                NaN
#
#       Facilities for Disabled  Laundry or Dry Cleaning Facility  \
# 153                       1.0                               1.0
# 154                       1.0                               NaN
# 195                       1.0                               NaN
# 254                       1.0                               1.0
# 282                       1.0                               1.0
# 413                       1.0                               1.0
# 476                       1.0                               1.0
# 477                       1.0                               1.0
# 496                       1.0                               1.0
# 571                       NaN                               NaN
# 660                       1.0                               1.0
# 663                       1.0                               1.0
# 677                       1.0                               1.0
# 678                       1.0                               1.0
# 679                       1.0                               1.0
# 684                       1.0                               1.0
# 698                       1.0                               NaN
# 700                       NaN                               NaN
# 701                       1.0                               1.0
# 702                       1.0                               1.0
# 704                       1.0                               NaN
# 709                       1.0                               NaN
# 718                       NaN                               NaN
# 719                       1.0                               NaN
# 720                       1.0                               1.0
# 721                       1.0                               1.0
# 723                       1.0                               1.0
# 817                       1.0                               1.0
# 899                       1.0                               1.0
# 1039                      1.0                               NaN
# 1183                      1.0                               NaN
# 1448                      1.0                               1.0
# 1701                      NaN                               NaN
# 1855                      1.0                               1.0
# 2012                      NaN                               NaN
# 2076                      NaN                               NaN
# 2163                      1.0                               1.0
# 2308                      NaN                               1.0
# 2411                      NaN                               1.0
# 2420                      NaN                               NaN
# 2445                      NaN                               NaN
#
#       Communal/Shared Kitchen  Storey Unit
# 153                       NaN          NaN
# 154                       NaN          NaN
# 195                       NaN          NaN
# 254                       NaN          NaN
# 282                       NaN          NaN
# 413                       NaN          NaN
# 476                       1.0          NaN
# 477                       1.0          NaN
# 496                       1.0          NaN
# 571                       NaN          NaN
# 660                       NaN          NaN
# 663                       NaN          NaN
# 677                       NaN          NaN
# 678                       NaN          NaN
# 679                       NaN          NaN
# 684                       1.0          NaN
# 698                       NaN          NaN
# 700                       NaN          NaN
# 701                       1.0          NaN
# 702                       NaN          NaN
# 704                       NaN          NaN
# 709                       NaN          NaN
# 718                       NaN          NaN
# 719                       NaN          NaN
# 720                       NaN          NaN
# 721                       1.0          NaN
# 723                       NaN          2.0
# 817                       1.0          NaN
# 899                       1.0          NaN
# 1039                      NaN          NaN
# 1183                      NaN          NaN
# 1448                      1.0          NaN
# 1701                      NaN          NaN
# 1855                      1.0          NaN
# 2012                      NaN          NaN
# 2076                      NaN          NaN
# 2163                      1.0          NaN
# 2308                      NaN          NaN
# 2411                      NaN          NaN
# 2420                      NaN          NaN
# 2445                      NaN          NaN
#
# [41 rows x 41 columns]

# %%
sns.lmplot(data=flats[flats['Price(Cr)']>7],y='Price(Cr)',x='Area(Marla)',hue='Location',height=8, 
    aspect=2)

# %%
flats['Description'].loc[2445]
# Out:
# 'Spacious 5-Bedroom Penthouse for Sale in Sukh Chayn Residence, F-10 Islamabad Luxury Living at Its Finest! This beautifully designed penthouse offers: 5 Master Bedrooms with attached baths Modern Kitchen & Stylish Interiors Spacious Living & Dining Area Private Balcony with Panoramic Views All Modern Amenities (Elevators, Security, Parking, Backup Power) Prime Location in F-10 with the Best City & Margalla Hills View'

# %% [markdown]
# *The outliers look normal because data points are situated in Expensive Sectors*

# %%
# Area(Marla)

# %%
sns.boxplot(flats['Area(Marla)'])
# Out:
# <Axes: ylabel='Area(Marla)'>

# %%
flats[flats['Area(Marla)']>22]
# Out:
#            Type  Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s)    Location  \
# 2308       Flat       14.0      3.0         24.0         3.0        F-11
# 2420  Penthouse       13.5      4.0         24.0         3.0        F-11
# 2499  Penthouse       10.0      6.0         36.0         6.0  Top City 1
#
#                                             Description  \
# 2308  This modern Apartment sits on 5500 square feet...
# 2420  Dream home in Islamabad! Welcome to Executive ...
# 2499  luxury brand new penthouse top view available ...
#
#                                Amenities: Main Features  \
# 2308  Built in year: 2022, Parking Spaces: 2, Lobby ...
# 2420                                                NaN
# 2499                                                NaN
#
#                                        Amenities: Rooms  \
# 2308  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 2420                                                NaN
# 2499                                                NaN
#
#                   Amenities: Business and Communication  ... Community Gym  \
# 2308  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 2420                                                NaN  ...           NaN
# 2499                                                NaN  ...           NaN
#
#      Swimming Pool Sauna  Jacuzzi  Security Staff  Maintenance Staff  \
# 2308           NaN   NaN      NaN             1.0                1.0
# 2420           NaN   NaN      NaN             NaN                NaN
# 2499           NaN   NaN      NaN             NaN                NaN
#
#       Facilities for Disabled  Laundry or Dry Cleaning Facility  \
# 2308                      NaN                               1.0
# 2420                      NaN                               NaN
# 2499                      NaN                               NaN
#
#       Communal/Shared Kitchen  Storey Unit
# 2308                      NaN          NaN
# 2420                      NaN          NaN
# 2499                      NaN          NaN
#
# [3 rows x 41 columns]

# %% [markdown]
# *Removing data where flat's Area > 22*

# %%
flats = flats[~(flats['Area(Marla)']>22)]

# %%
sns.boxplot(flats['Area(Marla)'])
# Out:
# <Axes: ylabel='Area(Marla)'>

# %% [markdown]
# **Here we have to use Bath(s) and Bedrooms(s) as main features instead of Bathrooms and Bedrooms, because there are alot of errors**

# %%
# Bathrooms

# %%
sns.barplot(flats['Bathrooms'].value_counts())
# Out:
# <Axes: xlabel='Bathrooms', ylabel='count'>

# %%
flats[flats['Bathrooms']>5][['Bathrooms','Bedrooms','Price(Cr)','Area(Marla)']]
# Out:
#       Bathrooms  Bedrooms  Price(Cr)  Area(Marla)
# 97          9.0       9.0     6.0000         22.0
# 139         7.0       6.0     1.4000          5.3
# 241         6.0       5.0     1.4000          4.1
# 377         9.0       7.0     0.7500          2.4
# 396         6.0       5.0     2.0500          6.8
# 432         6.0       5.0     0.3800          1.6
# 496         7.0       4.0    23.0000         19.3
# 556         7.0       5.0     0.6000          2.1
# 644         6.0       5.0     1.1500          4.9
# 658         6.0       6.0     1.6500          3.3
# 667         6.0       5.0     1.1600          2.8
# 723         6.0       4.0    21.0000         20.0
# 726         7.0       5.0     2.8500         10.0
# 737         9.0       8.0     0.4500          2.1
# 753         6.0       6.0     3.2500          6.4
# 799         7.0       6.0     3.9900         12.0
# 801         6.0       5.0     1.8500          6.4
# 852         6.0       5.0     2.9200         12.0
# 937         6.0       6.0     5.5000          4.4
# 983         6.0       6.0     0.7000          1.6
# 1120        6.0       5.0     3.5000          5.8
# 1145        7.0       5.0     6.5000          7.8
# 1321        6.0       6.0     4.1500         14.4
# 1459        6.0       5.0     5.2700         11.5
# 1480        7.0       7.0     2.7000          7.6
# 1494        7.0       7.0     0.7100          2.3
# 1508        7.0       6.0     0.7100          2.3
# 1583        6.0       5.0     1.0500          3.3
# 1657        6.0       4.0     2.1600          2.5
# 1770        6.0       5.0     2.4500          4.4
# 1799        6.0       5.0     0.3600          1.6
# 1800        8.0       8.0     0.8000          3.5
# 1815        6.0       6.0     1.0200          1.8
# 1823        7.0       5.0     1.0500          2.4
# 1908        7.0       6.0     2.4000          8.4
# 1922        6.0       4.0     5.0000         19.0
# 2034        6.0       5.0     1.8500          7.8
# 2091        6.0       5.0     3.4000         10.0
# 2166        6.0       5.0     4.7500          4.4
# 2341        7.0       5.0     6.5000          6.7
# 2422        8.0       6.0     0.4200          1.6
# 2449        6.0       5.0     3.2000          6.7
# 2481        6.0       5.0     1.8500          5.7
# 2593        6.0       5.0     1.3500          3.1
# 2728        7.0       6.0     1.9000          5.5
# 2797        6.0       5.0     0.9918          3.2

# %% [markdown]
# *There are flats where the number of bathrooms and bedrooms are very high that the corresponding Area doesnot make sense*

# %%
# Bath(s)

# %%
flats['Bath(s)'].value_counts()
# Out:
# Bath(s)
# 2.0    272
# 1.0    209
# 3.0    137
# 4.0     70
# 5.0     24
# 6.0      4
# 7.0      2
# Name: count, dtype: int64

# %%
# Check relationship between Bath(s) and Bedroom(s)
plt.figure(figsize=(10,6))
sns.scatterplot(data=flats, x='Bedroom(s)', y='Bath(s)')
plt.title('Bath(s) vs Bedroom(s) for Flats')
plt.show()

# %%
# Calculating Difference between Bedrooms(s) and Bath(s)
flats['BedBath_Diff'] = flats['Bedroom(s)'] - flats['Bath(s)']

# %%
# Find outliers where difference is > 3 or < -3 (unusual bed/bath ratios)
outlier_rows = flats[(flats['BedBath_Diff']>3) | (flats['BedBath_Diff']<-3)]
print(f"Found {len(outlier_rows)} outliers with unusual Bed/Bath ratio")
outlier_rows[['Price(Cr)', 'Bath(s)', 'Bedroom(s)', 'Area(Marla)', 'Location']]
# Out:
# Found 6 outliers with unusual Bed/Bath ratio
#       Price(Cr)  Bath(s)  Bedroom(s)  Area(Marla)              Location
# 377        0.75      1.0         7.0          2.4           Bahria Town
# 556        0.60      1.0         5.0          2.1                  H-13
# 658        1.65      1.0         6.0          3.3                  F-11
# 1799       0.36      1.0         5.0          1.6            Top City 1
# 1815       1.02      1.0         6.0          1.8  Islamabad Expressway
# 2377       1.20      7.0        11.0          1.6           DHA Defence

# %% [markdown]
# *For flats, typically bathrooms should be close to bedrooms. Large differnces indicate data errors.*

# %%
flats['Description'].loc[2377]
# Out:
# 'Experience premium living and solid returns with this 350 sq ft luxury 3 star Marriott hotel suite located in Florence Galleria, a landmark project by Imarat Group on Main GT Road, DHA Phase 2, Islamabad. This fully serviced suite combines elegant design with international hospitality standards, making it a perfect investment property for both local and overseas buyers. Property Highlights: Size: 350 sq ft Price: Rs 11,725,000 Monthly Rent: Rs 97,000 (Guaranteed Income) Prime GT Road front location near Giga Mall Developed by Imarat Group Fully managed hotel suite hassle-free investment World-class amenities: central AC/heating, lifts, 24/7 security, power backup, concierge & room service Ideal for passive investors seeking steady rental income and long-term capital appreciation Contact now for details, payment plans, and booking limited units available!'

# %%
# Check a few descriptions to understand the data
for idx in outlier_rows.index[:3]:
    print(f"Index {idx}:")
    print(flats['Description'].loc[idx][:200] + "...")
    print("-"*50)
# Out:
# Index 377:
# cube Appartments Bahria Enclave Studio Apartment for sale All dues clear Outside parking paid 10 lakh. 7th floor Rental Value 40k...
# --------------------------------------------------
# Index 556:
# Modern Living Meets Smart Investment Discover an exceptional opportunity to own your dream home in the heart of H-13 Islamabad one of the most rapidly developing and high-demand areas near G-13, NUST,...
# --------------------------------------------------
# Index 658:
# Al Rehman associate Offers a Prime Location Luxury 1 Bed Apartment Here are the features: . Luxury Bedrooms . Modern Bathrooms . Drawing dinning . TV Lounge . Kitchen . Big lawn . Servant Quarter . St...
# --------------------------------------------------

# %%
# Remove outliers with unusual Bed/Bath ratio
print(f"Before removal: {flats.shape[0]} rows")
flats = flats[~((flats['BedBath_Diff']>3) | (flats['BedBath_Diff']<-3))]
print(f"After removal: {flats.shape[0]} rows")
# Out:
# Before removal: 727 rows
# After removal: 721 rows

# %%
flats.drop(columns=['Bathrooms','Bedrooms'],inplace=True)

# %% [markdown]
# ## Built in Year Analysis

# %%
flats['Built in year'].value_counts().sort_index()
# Out:
# Built in year
# 1.0        44
# 2.0         6
# 3.0         6
# 4.0         3
# 5.0         6
# 7.0         1
# 8.0         2
# 10.0        1
# 21.0        1
# 2004.0      1
# 2008.0      1
# 2009.0      2
# 2010.0     14
# 2011.0      5
# 2012.0      7
# 2013.0      2
# 2015.0     13
# 2016.0      6
# 2017.0      6
# 2018.0     21
# 2019.0      7
# 2020.0     35
# 2021.0     23
# 2022.0     42
# 2023.0     65
# 2024.0     93
# 2025.0    151
# 2026.0     17
# 2027.0     18
# 2028.0      2
# 2029.0      2
# 2054.0      1
# Name: count, dtype: int64

# %%
# Check for year errors (unusual values)
flats[flats['Built in year'] < 1800]['Built in year'].value_counts()
# Out:
# Built in year
# 1.0     44
# 2.0      6
# 3.0      6
# 5.0      6
# 4.0      3
# 8.0      2
# 7.0      1
# 10.0     1
# 21.0     1
# Name: count, dtype: int64

# %% [markdown]
# *Fixing year errors - setting obvious typos to correct values, and setting invalid years to NaN*

# %%
# Year correction mapping
year_errors = {
    20223: 2023,
    20242: 2024,
    225: 2025,
    2250: 2025,
    2050: 2025,
    20000: 2000,
    205: 2025
}
flats['Built in year'] = flats['Built in year'].replace(year_errors)

# %%
# Set brand new flats to 2025
newFlats = flats[(flats['Built in year'] < 1800) & (flats['Description'].str.lower().str.contains('brand new'))].index
flats.loc[newFlats, 'Built in year'] = 2025
print(f"Updated {len(newFlats)} brand new flats to year 2025")
# Out:
# Updated 4 brand new flats to year 2025

# %%
# Set remaining invalid years (< 1800) to NaN
nan_years = flats[flats['Built in year'] < 1800].index
flats.loc[nan_years, 'Built in year'] = np.nan
print(f"Set {len(nan_years)} invalid years to NaN")
# Out:
# Set 66 invalid years to NaN

# %%
flats['Built in year'].value_counts().sort_index().tail(20)
# Out:
# Built in year
# 2010.0     14
# 2011.0      5
# 2012.0      7
# 2013.0      2
# 2015.0     13
# 2016.0      6
# 2017.0      6
# 2018.0     21
# 2019.0      7
# 2020.0     35
# 2021.0     23
# 2022.0     42
# 2023.0     65
# 2024.0     93
# 2025.0    155
# 2026.0     17
# 2027.0     18
# 2028.0      2
# 2029.0      2
# 2054.0      1
# Name: count, dtype: int64

# %% [markdown]
# ## Floor & Floor in Building Analysis

# %%
flats['Floor in Building'].value_counts().sort_index()
# Out:
# Floor in Building
# 1.0       69
# 2.0        9
# 3.0       12
# 4.0       16
# 5.0       38
# 6.0       39
# 7.0       34
# 8.0       36
# 9.0       65
# 10.0      35
# 11.0      15
# 12.0      30
# 13.0      10
# 14.0      13
# 15.0      12
# 16.0       3
# 17.0       3
# 18.0       8
# 19.0       2
# 20.0       4
# 21.0       4
# 22.0       8
# 23.0       1
# 24.0       1
# 25.0       2
# 26.0       1
# 29.0       1
# 30.0       2
# 32.0       1
# 34.0       2
# 36.0       1
# 37.0       1
# 40.0       9
# 42.0       1
# 60.0       1
# 2018.0     1
# Name: count, dtype: int64

# %% [markdown]
# *40+ Floors in Building doesn't not make sense, so setting them to Nan*

# %%
flats.loc[flats['Floor in Building']>40,'Floor in Building'] = np.nan

# %%
# value count
flats['Floor'].value_counts().sort_index()
# Out:
# Floor
# 1.0     197
# 2.0      45
# 3.0      60
# 4.0      44
# 5.0      43
# 6.0      20
# 7.0      13
# 8.0      16
# 9.0      11
# 10.0      8
# 11.0      3
# 12.0      7
# 13.0      2
# 14.0      2
# 15.0      1
# 16.0      1
# 17.0      3
# 18.0      3
# 20.0      2
# 23.0      1
# 24.0      2
# 32.0      1
# 37.0      1
# 40.0      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(flats['Floor'].value_counts().sort_index())
plt.title('Distribution of Floor Values')
plt.xticks(rotation=45)
plt.show()

# %%
# Check flats with very high floors
flats[flats['Floor'] > 15][['Price(Cr)', 'Area(Marla)', 'Floor', 'Location', 'Bedroom(s)','Floor in Building']]
# Out:
#       Price(Cr)  Area(Marla)  Floor     Location  Bedroom(s)  \
# 283        3.90          3.0   37.0          F-8         1.0
# 421        2.94          7.3   24.0  DHA Defence         3.0
# 436        2.94          7.3   24.0  DHA Defence         3.0
# 716        1.06          2.8   17.0  DHA Defence         NaN
# 781        7.50          7.1   18.0    Blue Area         2.0
# 919        1.08          2.7   17.0  DHA Defence         1.0
# 1181       2.50          8.9   40.0  DHA Defence         2.0
# 1256       1.04          4.9   18.0   Top City 1         2.0
# 1372       3.35          8.0   20.0         G-11         2.0
# 1480       2.70          7.6   23.0      Gulberg         2.0
# 1553       7.99         13.8   32.0         F-10         2.0
# 1855      14.00         12.6   20.0          F-8         3.0
# 2080       1.55          7.6   17.0         B-17         3.0
# 2237       0.80          2.5   18.0         B-17         1.0
# 2581       1.50          5.7   16.0         B-17         3.0
#
#       Floor in Building
# 283                37.0
# 421                40.0
# 436                40.0
# 716                14.0
# 781                22.0
# 919                40.0
# 1181               40.0
# 1256               18.0
# 1372               25.0
# 1480               26.0
# 1553               32.0
# 1855               22.0
# 2080                4.0
# 2237               18.0
# 2581               17.0

# %%
flats['Amenities: Main Features'].loc[1480]
# Out:
# 'Built in year: 2025, Parking Spaces: 7, Lobby in Building, Double Glazed Windows, Central Air Conditioning, Central Heating, Flooring, Electricity Backup, Waste Disposal, Floor: 23, Floors in Building: 26, Elevators: 03, Service Elevators in Building, Other Main Features, Furnished'

# %%
# Caculating the difference between Floor and Floor in Building to check if there is any error
flats['Floor Diff'] = flats['Floor in Building'] - flats['Floor']

# %%
flats['Floor Diff'].value_counts().sort_index()
# Out:
# Floor Diff
# -13.0     1
# -10.0     1
# -5.0      1
# -4.0      3
# -3.0      5
# -2.0      1
# -1.0      6
#  0.0     79
#  1.0     23
#  2.0     45
#  3.0     37
#  4.0     37
#  5.0     34
#  6.0     35
#  7.0     29
#  8.0     40
#  9.0     18
#  10.0    11
#  11.0     6
#  12.0     4
#  13.0     8
#  14.0     4
#  15.0     1
#  16.0     3
#  17.0     5
#  18.0     3
#  19.0     2
#  20.0     2
#  21.0     2
#  23.0     1
#  28.0     1
#  29.0     3
#  30.0     1
#  31.0     4
# Name: count, dtype: int64

# %%
flats[flats['Floor Diff'] < 0][['Floor','Floor in Building']]
# Out:
#       Floor  Floor in Building
# 98      5.0                2.0
# 154     2.0                1.0
# 214     2.0                1.0
# 367     5.0                1.0
# 716    17.0               14.0
# 738     2.0                1.0
# 740     3.0                1.0
# 821     6.0                2.0
# 822     5.0                4.0
# 1258    9.0                6.0
# 1550    4.0                3.0
# 2004   14.0                4.0
# 2080   17.0                4.0
# 2122    6.0                2.0
# 2219    5.0                2.0
# 2411    4.0                1.0
# 2545    2.0                1.0
# 2758    9.0                4.0

# %% [markdown]
# *Swapping the values of Floor and Floor in Building, where the Difference is negative. Because the error could be that the Agent made an error.*

# %%
# Swapping the values where the Floor Diff is negative
mask = flats['Floor Diff'] < 0
cols_to_swap = ['Floor','Floor in Building']

flats.loc[mask,cols_to_swap] = flats.loc[mask,cols_to_swap[::-1]].values

# %%
flats.drop(columns='Floor Diff',inplace =True)

# %% [markdown]
# *After researching, I came to know that there are few buildings where Floor > 15, but there are also some mistakes.<br>
# So that is why I am not changing the column for now but I will use discretization on this column to minimize the effect of Outliers*

# %% [markdown]
# ### Elevators

# %%
# Value count plot
plt.figure(figsize=(12,4))
sns.barplot(flats['Elevators'].value_counts())
# Out:
# <Axes: xlabel='Elevators', ylabel='count'>

# %%
flats['Amenities: Main Features'].loc[46]
# Out:
# 'Built in year: 2, Parking Spaces, Lobby in Building, Double Glazed Windows, Central Air Conditioning, Central Heating, Flooring, Electricity Backup, Waste Disposal, Floor: 9, Floors in Building: 9, Other Main Features, Furnished'

# %%
flats['Amenities: Main Features'].str.contains('Floors in Building').sum()
# Out:
# np.int64(490)

# %%
flats.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 721 entries, 16 to 2859
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Type                                   721 non-null    str
#  1   Price(Cr)                              721 non-null    float64
#  2   Bath(s)                                712 non-null    float64
#  3   Area(Marla)                            721 non-null    float64
#  4   Bedroom(s)                             704 non-null    float64
#  5   Location                               721 non-null    str
#  6   Description                            721 non-null    str
#  7   Amenities: Main Features               681 non-null    str
#  8   Amenities: Rooms                       651 non-null    str
#  9   Amenities: Business and Communication  626 non-null    str
#  10  Amenities: Community Features          631 non-null    str
#  11  Amenities: Healthcare Recreational     531 non-null    str
#  12  Amenities: Other Facilities            632 non-null    str
#  13  IsPrimeLoc                             721 non-null    bool
#  14  SolarInstalled                         721 non-null    bool
#  15  WaterBore                              721 non-null    bool
#  16  CornerHouse                            721 non-null    bool
#  17  luxury_type                            721 non-null    int64
#  18  Built in year                          538 non-null    float64
#  19  Parking Spaces                         641 non-null    float64
#  20  Floor                                  487 non-null    float64
#  21  Lobby in Building                      529 non-null    float64
#  22  Elevators                              507 non-null    float64
#  23  Service Elevators in Building          473 non-null    float64
#  24  Floor in Building                      487 non-null    float64
#  25  Servant Quarters                       447 non-null    float64
#  26  Kitchens                               627 non-null    float64
#  27  Store Rooms                            487 non-null    float64
#  28  Community Swimming Pool                544 non-null    float64
#  29  Community Gym                          570 non-null    float64
#  30  Swimming Pool                          0 non-null      float64
#  31  Sauna                                  459 non-null    float64
#  32  Jacuzzi                                451 non-null    float64
#  33  Security Staff                         630 non-null    float64
#  34  Maintenance Staff                      544 non-null    float64
#  35  Facilities for Disabled                454 non-null    float64
#  36  Laundry or Dry Cleaning Facility       314 non-null    float64
#  37  Communal/Shared Kitchen                224 non-null    float64
#  38  Storey Unit                            86 non-null     float64
#  39  BedBath_Diff                           704 non-null    float64
# dtypes: bool(4), float64(26), int64(1), str(9)
# memory usage: 1.2 MB

# %% [markdown]
# ### Kitchens

# %%
flats['Kitchens'].value_counts()
# Out:
# Kitchens
# 1.0    488
# 0.0     70
# 2.0     66
# 3.0      2
# 5.0      1
# Name: count, dtype: int64

# %%
flats[flats['Kitchens']==0].iloc[1]['Amenities: Rooms']
# Out:
# 'Bedrooms: 6, Bathrooms: 7, Servant Quarters, Drawing Room, Dining Room, Kitchens, Study Room, Prayer Room, Powder Room, Store Rooms, Steam Room, Lounge or Sitting Room, Laundry Room'

# %%
flats[~(flats['Communal/Shared Kitchen'].isnull())].iloc[2]
# Out:
# Type                                                                                  Flat
# Price(Cr)                                                                              6.0
# Bath(s)                                                                                7.0
# Area(Marla)                                                                           22.0
# Bedroom(s)                                                                             9.0
# Location                                                                              H-13
# Description                              Discover a one-of-a-kind investment in the hea...
# Amenities: Main Features                 Built in year: 2025, Parking Spaces, Lobby in ...
# Amenities: Rooms                         Bedrooms: 09, Bathrooms: 09, Servant Quarters,...
# Amenities: Business and Communication    Broadband Internet Access, Satellite or Cable ...
# Amenities: Community Features            Community Lawn or Garden, Community Swimming P...
# Amenities: Healthcare Recreational       Sauna, Jacuzzi, Other Healthcare and Recreatio...
# Amenities: Other Facilities              Maintenance Staff, Security Staff, Laundry or ...
# IsPrimeLoc                                                                            True
# SolarInstalled                                                                       False
# WaterBore                                                                            False
# CornerHouse                                                                          False
# luxury_type                                                                              0
# Built in year                                                                       2025.0
# Parking Spaces                                                                         1.0
# Floor                                                                                  1.0
# Lobby in Building                                                                      1.0
# Elevators                                                                              1.0
# Service Elevators in Building                                                          1.0
# Floor in Building                                                                     10.0
# Servant Quarters                                                                       0.0
# Kitchens                                                                               5.0
# Store Rooms                                                                            0.0
# Community Swimming Pool                                                                1.0
# Community Gym                                                                          1.0
# Swimming Pool                                                                          NaN
# Sauna                                                                                  1.0
# Jacuzzi                                                                                1.0
# Security Staff                                                                         1.0
# Maintenance Staff                                                                      1.0
# Facilities for Disabled                                                                1.0
# Laundry or Dry Cleaning Facility                                                       1.0
# Communal/Shared Kitchen                                                                1.0
# Storey Unit                                                                            NaN
# BedBath_Diff                                                                           2.0
# Name: 97, dtype: object

# %% [markdown]
# *Performing Multivariate Techniques to detect outliers for Kitchens, because there could be human error when entering the valeus for Kitchens*

# %% [markdown]
# ### Parking Spaces

# %%
sns.barplot(flats['Parking Spaces'].value_counts())
# Out:
# <Axes: xlabel='Parking Spaces', ylabel='count'>

# %%
# Capping the vaues till 3 for Parking Spaces
flats['Parking Spaces'] =  flats['Parking Spaces'].clip(lower=1,upper=3)

# %% [markdown]
# # Multivariate Approach
# Now, we will use Multivariate Techiniques to detect Outliers.Following are the techniques:
#
# - Isolation Forest
# - Local Outlier Factor

# %%
# Isolation Forest

# %%
# Choosing 'Area','Bedroom(s)','Bath(s)','Kitchens' 
cols_to_use = ['Bath(s)', 'Area(Marla)', 'Bedroom(s)','Kitchens']

data = flats[cols_to_use].copy()

# %%
# Filling the missing values

from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='most_frequent')

data = pd.DataFrame(imputer.fit_transform(data),columns=cols_to_use)
data.head()
# Out:
#    Bath(s)  Area(Marla)  Bedroom(s)  Kitchens
# 0      2.0          6.1         2.0       1.0
# 1      2.0          4.5         2.0       1.0
# 2      2.0          3.9         2.0       1.0
# 3      2.0          3.8         2.0       1.0
# 4      1.0          3.2         1.0       0.0

# %%
data.isnull().sum()
# Out:
# Bath(s)        0
# Area(Marla)    0
# Bedroom(s)     0
# Kitchens       0
# dtype: int64

# %%
from sklearn.ensemble import IsolationForest

clf = IsolationForest(n_estimators=400,contamination=0.03)
clf.fit(data)
# Out:
# IsolationForest(contamination=0.03, n_estimators=400)

# %%
y_pred = clf.predict(data)

# %%
is_outlier_forest = y_pred == -1

# %%
flats.loc[is_outlier_forest,cols_to_use]
# Out:
#       Bath(s)  Area(Marla)  Bedroom(s)  Kitchens
# 97        7.0         22.0         9.0       5.0
# 154       5.0         11.7         3.0       0.0
# 241       6.0          4.1         5.0       2.0
# 424       4.0         19.1         4.0       0.0
# 496       6.0         19.3         4.0       2.0
# 723       6.0         20.0         4.0       1.0
# 737       1.0          2.1         1.0       3.0
# 799       5.0         12.0         4.0       2.0
# 920       5.0          4.2         4.0       1.0
# 1258      4.0         18.7         4.0       1.0
# 1448      4.0         16.7         4.0       0.0
# 1467      5.0          6.7         5.0       NaN
# 1542      5.0         20.0         4.0       1.0
# 1922      5.0         19.0         4.0       2.0
# 2034      5.0          7.8         4.0       2.0
# 2418      4.0         20.0         4.0       NaN
# 2422      1.0          1.6         1.0       3.0
# 2445      6.0         22.0         5.0       NaN
# 2506      1.0          1.4         4.0       2.0
# 2600      4.0         11.6         4.0       0.0
# 2811      4.0         10.7         4.0       2.0
# 2859      1.0          1.7         3.0       2.0

# %%
# Local Outlier Factor
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=25,contamination=0.03)

y_pred = lof.fit_predict(data)

# %%
is_outlier_lof = y_pred == -1

# %%
flats.loc[is_outlier_lof,cols_to_use]
# Out:
#       Bath(s)  Area(Marla)  Bedroom(s)  Kitchens
# 500       1.0          2.9         2.0       1.0
# 570       3.0          4.0         2.0       1.0
# 650       3.0          3.7         3.0       1.0
# 667       1.0          2.8         1.0       2.0
# 716       1.0          2.8         NaN       NaN
# 740       1.0          2.8         1.0       0.0
# 754       1.0          2.8         1.0       2.0
# 924       2.0          3.6         3.0       1.0
# 1549      1.0          2.7         1.0       2.0
# 1551      1.0          4.0         NaN       NaN
# 1596      1.0          2.9         NaN       NaN
# 1605      3.0          1.1         3.0       1.0
# 1825      2.0          3.8         2.0       0.0
# 1860      2.0          2.7         1.0       1.0
# 2023      1.0          2.7         1.0       2.0
# 2035      2.0          4.0         1.0       1.0
# 2077      2.0          4.0         2.0       0.0
# 2147      1.0          2.7         1.0       2.0
# 2253      2.0          4.1         2.0       2.0
# 2450      1.0          2.8         2.0       1.0
# 2563      2.0          3.8         2.0       2.0
# 2577      2.0          4.0         3.0       1.0

# %%
flats.loc[is_outlier_forest,cols_to_use].index == flats.loc[is_outlier_lof,cols_to_use].index
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# *After looking at the Outliers detected by both LOF and Isolation Forest, it can be seen that the Outliers detected by LOF is more reliable because 2,3 Marla cannot have 3,4 Bathrooms and Bedrooms, while 20 Marla can have 4 Bathrooms and Bedrooms*

# %%
# Removing the Outliers detected by LOF
flats = flats.loc[~is_outlier_lof]

# %%
# Removing the Columns which are not usefull for predicting price
cols_to_remove = ['Type','SolarInstalled','WaterBore', 'CornerHouse', 'Security Staff',
       'Maintenance Staff','Facilities for Disabled', 'Laundry or Dry Cleaning Facility',
       'Communal/Shared Kitchen', 'Storey Unit','Community Swimming Pool', 'Community Gym']

# %%
flats.drop(columns=cols_to_remove,inplace=True)

# %%
flats.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 699 entries, 16 to 2859
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Price(Cr)                              699 non-null    float64
#  1   Bath(s)                                690 non-null    float64
#  2   Area(Marla)                            699 non-null    float64
#  3   Bedroom(s)                             685 non-null    float64
#  4   Location                               699 non-null    str
#  5   Description                            699 non-null    str
#  6   Amenities: Main Features               659 non-null    str
#  7   Amenities: Rooms                       631 non-null    str
#  8   Amenities: Business and Communication  606 non-null    str
#  9   Amenities: Community Features          610 non-null    str
#  10  Amenities: Healthcare Recreational     513 non-null    str
#  11  Amenities: Other Facilities            613 non-null    str
#  12  IsPrimeLoc                             699 non-null    bool
#  13  luxury_type                            699 non-null    int64
#  14  Built in year                          520 non-null    float64
#  15  Parking Spaces                         621 non-null    float64
#  16  Floor                                  473 non-null    float64
#  17  Lobby in Building                      513 non-null    float64
#  18  Elevators                              496 non-null    float64
#  19  Service Elevators in Building          459 non-null    float64
#  20  Floor in Building                      476 non-null    float64
#  21  Servant Quarters                       433 non-null    float64
#  22  Kitchens                               608 non-null    float64
#  23  Store Rooms                            472 non-null    float64
#  24  Swimming Pool                          0 non-null      float64
#  25  Sauna                                  445 non-null    float64
#  26  Jacuzzi                                437 non-null    float64
#  27  BedBath_Diff                           685 non-null    float64
# dtypes: bool(1), float64(18), int64(1), str(8)
# memory usage: 1.1 MB

# %%
flats.to_csv('flats_outlier_handled.csv')
