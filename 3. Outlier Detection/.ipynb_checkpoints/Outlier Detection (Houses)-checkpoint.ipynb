# %% [markdown]
# # Outline
# - Use Univariate and Multivariate Techniques to identify Outliers

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
houses = pd.read_csv('C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/EDA/houses.csv',index_col=0)

# %%
houses.drop(columns=['Community Swimming Pool', 'Community Gym', 'Sauna',
       'Jacuzzi', 'Security Staff', 'Maintenance Staff',
       'Facilities for Disabled', 'Laundry or Dry Cleaning Facility',
       'Communal/Shared Kitchen','Lobby in Building', 'Elevators',
       'Service Elevators in Building','Floor in Building'],inplace=True)

# %%
houses.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 2080 entries, 0 to 2865
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Type                                   2080 non-null   str
#  1   Price(Cr)                              2080 non-null   float64
#  2   Bath(s)                                2041 non-null   float64
#  3   Area(Marla)                            2080 non-null   float64
#  4   Bedroom(s)                             2049 non-null   float64
#  5   Location                               2080 non-null   str
#  6   Description                            2080 non-null   str
#  7   Amenities: Main Features               1943 non-null   str
#  8   Amenities: Rooms                       1912 non-null   str
#  9   Amenities: Business and Communication  1831 non-null   str
#  10  Amenities: Community Features          1824 non-null   str
#  11  Amenities: Healthcare Recreational     1689 non-null   str
#  12  Amenities: Other Facilities            1798 non-null   str
#  13  IsPrimeLoc                             2080 non-null   bool
#  14  SolarInstalled                         2080 non-null   bool
#  15  WaterBore                              2080 non-null   bool
#  16  CornerHouse                            2080 non-null   bool
#  17  luxury_type                            2080 non-null   int64
#  18  Built in year                          1701 non-null   float64
#  19  Parking Spaces                         1826 non-null   float64
#  20  Floor                                  1530 non-null   float64
#  21  Bedrooms                               1831 non-null   float64
#  22  Bathrooms                              1834 non-null   float64
#  23  Servant Quarters                       1642 non-null   float64
#  24  Kitchens                               1828 non-null   float64
#  25  Store Rooms                            1552 non-null   float64
#  26  Swimming Pool                          1078 non-null   float64
#  27  Storey Unit                            714 non-null    float64
# dtypes: bool(4), float64(14), int64(1), str(9)
# memory usage: 2.8 MB

# %%
print('Houses Duplicated',houses.duplicated().sum())
# Out:
# Houses Duplicated 0

# %% [markdown]
# ## Univariate Outlier Detection
# - Z Score --> for Normal Distributions
# - IQR --> for Non Normal Distributions

# %% [markdown]
# ### Price

# %%
sns.boxplot(houses['Price(Cr)'])
# Out:
# <Axes: ylabel='Price(Cr)'>

# %%
# Analyzing the rows where Price > 150 Cr
print('Shape of Houses having Price greater than 100 Cr : ',houses[houses['Price(Cr)']>100].shape[0])
houses[houses['Price(Cr)']>100][['Location', 'Price(Cr)', 'Area(Marla)']].sort_values(by='Price(Cr)', ascending=False)
# Out:
# Shape of Houses having Price greater than 100 Cr :  27
#      Location  Price(Cr)  Area(Marla)
# 863       F-7      400.0         80.0
# 289       F-6      235.0         78.0
# 2399      F-6      200.0         80.0
# 1622      F-6      180.0         80.0
# 1851      F-7      180.0         80.0
# 1303      F-6      175.0        100.0
# 2052      F-7      175.0         80.0
# 1681      F-6      175.0         76.0
# 292       F-8      175.0         80.0
# 1564      F-7      170.0         80.0
# 2279      F-6      160.0         82.0
# 1728      F-6      150.0         96.0
# 1241      F-6      145.0         96.0
# 95        F-7      140.0         58.0
# 1838      E-7      130.0         50.0
# 148       F-6      130.0        100.0
# 1574      F-6      130.0         96.0
# 1077      F-6      125.0         80.0
# 1227      F-6      125.0         80.0
# 1325      F-6      125.0         96.0
# 1700      F-7      120.0         80.0
# 1547      F-6      115.0         66.0
# 2556      F-7      115.0         42.0
# 1173      G-6      110.0         46.0
# 739       F-6      110.0         42.0
# 2724      F-6      110.0         48.0
# 2767      F-7      110.0         80.0

# %%
# All rows included
houses.groupby('Location')['Price(Cr)'].mean().sort_values(ascending=False).head(10)
# Out:
# Location
# E-7             73.818182
# F-7             64.196970
# F-6             63.956522
# G-6             46.290000
# F-8             45.905000
# G-7             40.000000
# F-10            26.782456
# F-11            18.602632
# Park Enclave    17.333333
# Eighteen        16.644000
# Name: Price(Cr), dtype: float64

# %%
# All rows except the rows where Price > 100 Cr
houses[houses['Price(Cr)']<100].groupby('Location')['Price(Cr)'].mean().sort_values(ascending=False).head(10)
# Out:
# Location
# E-7             71.142857
# F-7             48.741379
# F-8             43.716949
# G-7             40.000000
# G-6             39.211111
# F-6             36.980769
# F-10            26.782456
# F-11            18.602632
# Park Enclave    17.333333
# Eighteen        16.644000
# Name: Price(Cr), dtype: float64

# %% [markdown]
# *Although F-6, F-8, F-10, G-6, E-7 etc are high cost sectors, but removing outliers still has the same distribution. So we will drop them*

# %%
houses = houses[~(houses['Price(Cr)']>=100)]

# %%
houses.shape
# Out:
# (2052, 28)

# %%
sns.boxplot(houses['Price(Cr)'])
# Out:
# <Axes: ylabel='Price(Cr)'>

# %%
# Now the Price column is normal (it could be beneficial for Predciting)
sns.boxplot(houses['Price(Cr)'],log_scale=True)
# Out:
# <Axes: ylabel='Price(Cr)'>

# %%
# Area(Marla)

# %%
sns.boxplot(houses['Area(Marla)'])
plt.grid()

# %%
# Removed the Obvious Outlier
houses = houses[houses['Area(Marla)'] != houses['Area(Marla)'].max()]

# %%
sns.boxplot(houses['Area(Marla)'])
plt.grid()

# %%
from sklearn.ensemble import IsolationForest

X = houses[['Price(Cr)','Area(Marla)']]
clf = IsolationForest(n_estimators=200,contamination=0.015)

y_pred = clf.fit_predict(X)

is_outlier_forest = y_pred == -1

plt.figure(figsize=(10, 6))
plt.scatter(X.loc[:,'Area(Marla)'],X.loc[:,'Price(Cr)'], color='b', s=20, edgecolor='k')


plt.scatter(X.loc[is_outlier_forest,'Area(Marla)'], X.loc[is_outlier_forest, 'Price(Cr)'], color='r', s=50, edgecolor='k')

plt.title("Outlier Detection with Isolation Forest")
plt.xlabel("Area(Marla)")
plt.ylabel("Price(Cr)")
plt.show()

# %%
# Scatter plot with out Outliers
sns.scatterplot(data=houses.loc[~is_outlier_forest], x='Area(Marla)',y='Price(Cr)')
# Out:
# <Axes: xlabel='Area(Marla)', ylabel='Price(Cr)'>

# %%
# Analyzing the rows having more Area but very less Price
houses[(houses['Area(Marla)']>60)& (houses['Price(Cr)']<40)]
# Out:
#        Type  Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s)     Location  \
# 791   House       35.0      7.0        100.0         8.0      Gulberg
# 874   House       16.5      6.0         80.0        10.0    Bani Gala
# 1135  House       22.5      6.0         64.0         6.0  Bahria Town
# 1684  House       17.5      6.0         76.0         6.0  Bahria Town
# 1686  House       30.0      6.0         76.0         5.0  Bahria Town
# 2683  House       16.5      7.0         80.0         9.0  Bahria Town
#
#                                             Description  \
# 791   Live Like the King You Are Meant to Be. Your P...
# 874   4 Kanal Luxury House 1 Sweet Bed With TV Loung...
# 1135  Bahira Town Garden City 3.25 Kanal House For S...
# 1684  So if you're interested in buying this propert...
# 1686  About this rental Featuring an extraordinary 1...
# 2683  Exceptional 4 Kanal 8 Marla Structure for Sale...
#
#                                Amenities: Main Features  \
# 791   Built in year: 2025, Parking Spaces: 8, Double...
# 874   Parking Spaces: 1, Double Glazed Windows, Cent...
# 1135  Built in year: 2024, Parking Spaces: 5, Double...
# 1684  Built in year, Parking Spaces: 3, Double Glaze...
# 1686  Built in year: 2025, Parking Spaces: 5, Double...
# 2683  Built in year: 2018, Parking Spaces, Double Gl...
#
#                                        Amenities: Rooms  \
# 791                                                 NaN
# 874   Bedrooms: 3, Bathrooms: 4, Servant Quarters: 1...
# 1135  Bedrooms: 6, Bathrooms: 7, Servant Quarters: 2...
# 1684  Bedrooms: 8, Bathrooms: 8, Servant Quarters: 1...
# 1686  Bedrooms: 5, Bathrooms: 6, Servant Quarters: 2...
# 2683  Bedrooms: 8, Bathrooms: 9, Servant Quarters: 2...
#
#                   Amenities: Business and Communication  ... Built in year  \
# 791   Broadband Internet Access, Satellite or Cable ...  ...        2025.0
# 874   Broadband Internet Access, Satellite or Cable ...  ...           NaN
# 1135  Broadband Internet Access, Satellite or Cable ...  ...        2024.0
# 1684  Broadband Internet Access, Satellite or Cable ...  ...           1.0
# 1686  Broadband Internet Access, Satellite or Cable ...  ...        2025.0
# 2683  Broadband Internet Access, Satellite or Cable ...  ...        2018.0
#
#      Parking Spaces Floor  Bedrooms  Bathrooms  Servant Quarters  Kitchens  \
# 791             8.0   3.0       NaN        NaN               NaN       NaN
# 874             1.0   NaN       3.0        4.0               1.0       2.0
# 1135            5.0   2.0       6.0        7.0               2.0       1.0
# 1684            3.0   NaN       8.0        8.0               1.0       2.0
# 1686            5.0   2.0       5.0        6.0               2.0       1.0
# 2683            1.0   4.0       8.0        9.0               2.0       3.0
#
#       Store Rooms  Swimming Pool  Storey Unit
# 791           NaN            NaN          NaN
# 874           NaN            NaN          NaN
# 1135          1.0            1.0          1.0
# 1684          1.0            1.0          NaN
# 1686          1.0            1.0          NaN
# 2683          2.0            1.0          NaN
#
# [6 rows x 28 columns]

# %%
sns.boxplot(data=houses.loc[~is_outlier_forest],y='Area(Marla)',)
# Out:
# <Axes: ylabel='Area(Marla)'>

# %% [markdown]
# *Removing the Outliers*

# %%
# Removing the rows where Area(Marla) > 80
houses = houses.loc[~is_outlier_forest,:]

# %%
sns.boxplot(houses['Area(Marla)'])
# Out:
# <Axes: ylabel='Area(Marla)'>

# %% [markdown]
# ### Bath(s) & Bedroom(s)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Initialize the figure and a 2x2 grid of axes
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 2. Plot each column on its respective axis
# Row 0, Col 0: Bath(s)
sns.barplot(x=houses['Bath(s)'].value_counts().index, 
            y=houses['Bath(s)'].value_counts().values, 
            ax=axes[0, 0]).set_title('Bath(s)')

# Row 0, Col 1: Bedroom(s)
sns.barplot(x=houses['Bedroom(s)'].value_counts().index, 
            y=houses['Bedroom(s)'].value_counts().values, 
            ax=axes[0, 1]).set_title('Bedroom(s)')

# Row 1, Col 0: Bathrooms
sns.barplot(x=houses['Bathrooms'].value_counts().index, 
            y=houses['Bathrooms'].value_counts().values, 
            ax=axes[1, 0]).set_title('Bathrooms')

# Row 1, Col 1: Bedrooms
sns.barplot(x=houses['Bedrooms'].value_counts().index, 
            y=houses['Bedrooms'].value_counts().values, 
            ax=axes[1, 1]).set_title('Bedrooms')

# 3. Clean up the layout so titles don't overlap
plt.tight_layout()
plt.show()

# %%
# Analyzing the Houses having more than 8 Bath(s)
houses[houses['Bath(s)']>=8][['Location','Price(Cr)','Area(Marla)','Bedroom(s)','Bath(s)','Storey Unit','Floor']]
# Out:
#                 Location  Price(Cr)  Area(Marla)  Bedroom(s)  Bath(s)  \
# 524                 F-10      30.00         28.0         8.0      8.0
# 532          Soan Garden       6.65         20.0         7.0      9.0
# 619   Faisal Town - F-18      10.50         14.0         9.0     10.0
# 635          DHA Defence      11.95         20.0         5.0      8.0
# 777                  F-7      42.50         42.0         4.0     10.0
# 778                  F-8      65.00         36.0         6.0      8.0
# 779                  F-8      41.00         36.0        10.0     12.0
# 898                 F-11      18.50         20.0         8.0      8.0
# 1067                 F-8      65.00         36.0         9.0      9.0
# 1185                F-10      55.00         40.0         8.0      8.0
# 1187                F-10      23.00         22.0         8.0     10.0
# 1191                F-10      34.00         48.0         8.0      8.0
# 1197                 F-7      32.00         26.0        10.0     10.0
# 1203                F-10      40.00         26.0         8.0      8.0
# 1214                 F-7      38.00         40.0         8.0      9.0
# 1387         DHA Defence       7.75         20.0         6.0      8.0
# 1447             Gulberg      11.00         20.0         9.0      9.0
# 1624                 F-7      65.00         40.0         9.0     12.0
# 1696                G-13      16.00         20.0         8.0      9.0
# 1819                F-11      24.00         32.0        11.0     10.0
# 1820                F-11      25.00         26.0         9.0     10.0
# 1821                F-11      25.50         32.0        10.0     10.0
# 1841                 F-6      36.00         16.0         7.0      8.0
# 1861                 E-7      60.00         38.0         7.0      8.0
# 1962           Bani Gala       7.50         20.0        10.0     12.0
# 2235                B-17       4.10         10.0         6.0      8.0
# 2390                 F-6      27.00         22.0         6.0      8.0
# 2462                E-11      18.00         20.0        10.0     10.0
# 2476                F-11      18.00         20.0         9.0      9.0
# 2633                 I-8      13.00         14.2         8.0      8.0
# 2699                 F-8      40.00         20.0         9.0      9.0
# 2838                 F-7      65.00         40.0        10.0     11.0
# 2853                 F-7      34.00         28.0         7.0      8.0
# 2856                D-12      26.00         20.0         8.0      8.0
# 2865                G-11      16.00         22.0        14.0     16.0
#
#       Storey Unit  Floor
# 524           NaN    1.0
# 532           2.0    2.0
# 619           NaN    3.0
# 635           NaN    NaN
# 777           NaN    2.0
# 778           NaN    1.0
# 779           NaN    3.0
# 898           NaN    3.0
# 1067          3.0    3.0
# 1185          3.0    NaN
# 1187          3.0    3.0
# 1191          NaN    2.0
# 1197          3.0    3.0
# 1203          3.0    3.0
# 1214          NaN    2.0
# 1387          NaN    2.0
# 1447          1.0    3.0
# 1624          NaN    NaN
# 1696          2.0    2.0
# 1819          NaN    NaN
# 1820          3.0    NaN
# 1821          3.0    2.0
# 1841          NaN    2.0
# 1861          NaN    2.0
# 1962          1.0    2.0
# 2235          2.0    1.0
# 2390          NaN    NaN
# 2462          3.0    3.0
# 2476          3.0    NaN
# 2633          3.0    2.0
# 2699          3.0    3.0
# 2838          NaN    3.0
# 2853          NaN    2.0
# 2856          NaN    3.0
# 2865          NaN    3.0

# %%
sns.scatterplot(x=houses['Bath(s)'],y=houses['Bedroom(s)'])
# Out:
# <Axes: xlabel='Bath(s)', ylabel='Bedroom(s)'>

# %% [markdown]
# *Using Multivaraite Approaches to Detect Outliers*

# %%
# Using Isolation to determine outliers between Bathrooms and Bedrooms
from sklearn.ensemble import IsolationForest

X = houses[['Bath(s)','Bedroom(s)']]
clf = IsolationForest(n_estimators=200,contamination=0.015)

y_pred = clf.fit_predict(X)

is_outlier_forest = y_pred == -1

plt.figure(figsize=(10, 6))
plt.scatter(X.loc[:,'Bath(s)'],X.loc[:,'Bedroom(s)'], color='b', s=20, edgecolor='k')


plt.scatter(X.loc[is_outlier_forest,'Bath(s)'], X.loc[is_outlier_forest, 'Bedroom(s)'], color='r', s=50, edgecolor='k')

plt.title("Outlier Detection with Isolation Forest")
plt.xlabel("Bath(s)")
plt.ylabel("Price(Cr)")
plt.show()

# %%
X.isnull().sum()
# Out:
# Bath(s)       37
# Bedroom(s)    30
# dtype: int64

# %%
# Using Isolation to determine outliers between Bathrooms and Bedrooms
from sklearn.ensemble import IsolationForest

X = houses[['Bath(s)','Bedroom(s)']]
clf = IsolationForest(n_estimators=200,contamination=0.01)

y_pred = clf.fit_predict(X)

is_outlier_forest = y_pred == -1

plt.figure(figsize=(10, 6))
plt.scatter(X.loc[:,'Bath(s)'],X.loc[:,'Bedroom(s)'], color='b', s=20, edgecolor='k')


plt.scatter(X.loc[is_outlier_forest,'Bath(s)'], X.loc[is_outlier_forest, 'Bedroom(s)'], color='r', s=50, edgecolor='k')

plt.title("Outlier Detection with Isolation Forest")
plt.xlabel("Bath(s)")
plt.ylabel("Price(Cr)")
plt.show()

# %%
# Using LOF to determine outliers between Bathrooms and Bedrooms

X = houses.dropna(subset=['Bath(s)','Bedroom(s)'],how='any')

from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor(contamination = 0.01)
y_pred = clf.fit_predict(X[['Bath(s)','Bedroom(s)']])

is_outlier = y_pred == -1

plt.figure(figsize=(10, 6))
plt.scatter(X.loc[:,'Bath(s)'],X.loc[:,'Bedroom(s)'], color='b', s=20, edgecolor='k')


plt.scatter(X.loc[is_outlier,'Bath(s)'], X.loc[is_outlier, 'Bedroom(s)'], color='r', s=50, edgecolor='k')

plt.title("Outlier Detection with Isolation Forest")
plt.xlabel("Bath(s)")
plt.ylabel("Price(Cr)")
plt.show()
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\neighbors\_lof.py:325: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(

# %% [markdown]
# **The Mulitvariate Outlier Detection is not working as it should be, so the best way is to remove those rows where the difference between Bathrooms and Bedrooms is greater than 3**

# %%
houses['BedBath_Diff'] = houses['Bedroom(s)'] - houses['Bath(s)']

# %%
outlier_rows = houses[(houses['BedBath_Diff']>3)|(houses['BedBath_Diff']<-3)]

# %%
outlier_rows[['Area(Marla)','Storey Unit','Floor','Bath(s)','Bedroom(s)']]
# Out:
#       Area(Marla)  Storey Unit  Floor  Bath(s)  Bedroom(s)
# 147          40.0          3.0    2.0      5.0         9.0
# 262          20.0          NaN    3.0      7.0        11.0
# 290          36.0          NaN    NaN      6.0        10.0
# 365          20.0          NaN    NaN      4.0         8.0
# 366          20.0          3.0    3.0      1.0         9.0
# 630          44.0          NaN    2.0      6.0        10.0
# 686          20.0          NaN    2.0      6.0        10.0
# 693          20.0          NaN    2.0      6.0        10.0
# 777          42.0          NaN    2.0     10.0         4.0
# 1106         34.0          NaN    NaN      3.0         8.0
# 1184         40.0          NaN    NaN      6.0        10.0
# 1712          5.0          1.0    3.0      5.0         1.0
# 1786         20.0          3.0    3.0      6.0        10.0
# 1814         42.0          NaN    2.0      4.0         8.0
# 1817         26.0          3.0    1.0      6.0        10.0
# 1840         40.0          NaN    1.0      2.0         6.0
# 1988         20.0          NaN    3.0      6.0        10.0
# 2465         20.0          NaN    2.0      4.0         8.0
# 2557         14.2          NaN    1.0      2.0         9.0
# 2698         14.0          NaN    NaN      6.0        10.0
# 2745         48.0          NaN    2.0      6.0        10.0
# 2780         14.2          NaN    1.0      7.0         2.0
# 2795         20.0          3.0    1.0      6.0        10.0
# 2839         50.0          3.0    NaN      1.0         8.0
# 2843         40.0          NaN    2.0      6.0        10.0

# %%
sns.scatterplot(data=houses[(houses['BedBath_Diff']>4)|(houses['BedBath_Diff']<-4)],x='Bath(s)',y='Bedroom(s)')
# Out:
# <Axes: xlabel='Bath(s)', ylabel='Bedroom(s)'>

# %%
outlier_rows.shape
# Out:
# (25, 29)

# %%
outlier_rows[['Price(Cr)', 'Bath(s)','Area(Marla)', 'Bedroom(s)']]
# Out:
#       Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s)
# 147       80.00      5.0         40.0         9.0
# 262        8.00      7.0         20.0        11.0
# 290       55.00      6.0         36.0        10.0
# 365       15.00      4.0         20.0         8.0
# 366       16.00      1.0         20.0         9.0
# 630       33.50      6.0         44.0        10.0
# 686        6.10      6.0         20.0        10.0
# 693       24.00      6.0         20.0        10.0
# 777       42.50     10.0         42.0         4.0
# 1106      30.00      3.0         34.0         8.0
# 1184      32.00      6.0         40.0        10.0
# 1712       2.35      5.0          5.0         1.0
# 1786      10.90      6.0         20.0        10.0
# 1814      65.00      4.0         42.0         8.0
# 1817      25.00      6.0         26.0        10.0
# 1840      75.00      2.0         40.0         6.0
# 1988      12.00      6.0         20.0        10.0
# 2465      18.00      4.0         20.0         8.0
# 2557      15.50      2.0         14.2         9.0
# 2698       7.80      6.0         14.0        10.0
# 2745      60.00      6.0         48.0        10.0
# 2780      19.00      7.0         14.2         2.0
# 2795      14.00      6.0         20.0        10.0
# 2839      65.00      1.0         50.0         8.0
# 2843      30.00      6.0         40.0        10.0

# %%
scatter = plt.scatter(data=houses.drop(index=outlier_rows.index),x='Bath(s)',y='Bedroom(s)',s='Area(Marla)')

# %%
outlier_rows.index
# Out:
# Index([ 147,  262,  290,  365,  366,  630,  686,  693,  777, 1106, 1184, 1712,
#        1786, 1814, 1817, 1840, 1988, 2465, 2557, 2698, 2745, 2780, 2795, 2839,
#        2843],
#       dtype='int64')

# %%
# Removing the outliers rows
houses.drop(outlier_rows.index,inplace=True)

# %%
houses.shape
# Out:
# (1995, 29)

# %% [markdown]
# ### Built in Year

# %%
houses['Built in year'].value_counts()
# Out:
# Built in year
# 2025.0     812
# 2024.0     246
# 1.0        121
# 2023.0     101
# 2020.0      45
# 2022.0      41
# 2015.0      30
# 2021.0      30
# 2018.0      22
# 2010.0      21
# 2019.0      18
# 2000.0      16
# 2017.0      13
# 2016.0      10
# 2026.0       9
# 2005.0       9
# 1990.0       8
# 2.0          8
# 2012.0       8
# 1998.0       6
# 1999.0       5
# 2014.0       5
# 2027.0       4
# 2009.0       4
# 2001.0       3
# 10.0         3
# 2002.0       3
# 20223.0      2
# 2013.0       2
# 2008.0       2
# 225.0        2
# 2028.0       2
# 4.0          1
# 1997.0       1
# 2250.0       1
# 1970.0       1
# 15.0         1
# 2050.0       1
# 40.0         1
# 5.0          1
# 1996.0       1
# 2003.0       1
# 2004.0       1
# 2011.0       1
# 1978.0       1
# 20000.0      1
# 205.0        1
# 20242.0      1
# 3.0          1
# 1995.0       1
# 1898.0       1
# 2007.0       1
# 1965.0       1
# 7.0          1
# 1987.0       1
# Name: count, dtype: int64

# %%
houses[houses['Built in year']==2050]
# Out:
#       Type  Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s) Location  \
# 537  House        4.2      7.0          7.0         5.0  Gulberg
#
#                                            Description  \
# 537  Block F Near to park 5 bad 7 bath 2 lounge 2 k...
#
#                               Amenities: Main Features  \
# 537  Built in year: 2050, Parking Spaces: 3, Double...
#
#                                       Amenities: Rooms  \
# 537  Bedrooms: 6, Bathrooms: 7, Servant Quarters: 1...
#
#                  Amenities: Business and Communication  ... Parking Spaces  \
# 537  Broadband Internet Access, Satellite or Cable ...  ...            3.0
#
#     Floor Bedrooms  Bathrooms  Servant Quarters  Kitchens  Store Rooms  \
# 537   3.0      6.0        7.0               1.0       2.0          1.0
#
#      Swimming Pool  Storey Unit  BedBath_Diff
# 537            1.0          NaN          -2.0
#
# [1 rows x 29 columns]

# %%
# There are many Errors, need to correct them manually

year_errors = {
    20242:2024,
    20223:2023,
    225:2025,
    2250:2025,
    2050:2025,
    20000:2000,
    205:2025,
    20242:2024
}

houses['Built in year'] = houses['Built in year'].replace(year_errors)

# %% [markdown]
# *Changing the Built in year of Brand New Houses to 2025*

# %%
newHouses = houses[(houses['Built in year']< 1800)&(houses['Description'].str.lower().str.contains('brand new'))].index

# %%
newHouses
# Out:
# Index([   0,    6,    8,   34,   35,   49,   50,   67,  288,  440,  441,  451,
#         699,  916, 1091, 1228, 1237, 1301, 1305, 1313, 1359, 1364, 1384, 1403,
#        1405, 1571, 1678, 1719, 1735, 1782, 1906, 1907, 1974, 1995, 2154, 2215,
#        2243, 2257, 2262, 2264, 2502, 2542, 2595, 2701],
#       dtype='int64')

# %%
houses.loc[newHouses,'Built in year'] = 2025

# %% [markdown]
# *Changing the value to Nan where Built in year is misleading (e.g where there is values less than 1800)*

# %%
Nanyear = houses[houses['Built in year']<1800].index

houses.loc[Nanyear,'Built in year'] = np.nan

# %%
houses['Built in year'].value_counts()
# Out:
# Built in year
# 2025.0    861
# 2024.0    247
# 2023.0    103
# 2020.0     45
# 2022.0     41
# 2015.0     30
# 2021.0     30
# 2018.0     22
# 2010.0     21
# 2019.0     18
# 2000.0     17
# 2017.0     13
# 2016.0     10
# 2026.0      9
# 2005.0      9
# 1990.0      8
# 2012.0      8
# 1998.0      6
# 1999.0      5
# 2014.0      5
# 2027.0      4
# 2009.0      4
# 2001.0      3
# 2002.0      3
# 2013.0      2
# 2008.0      2
# 2028.0      2
# 1997.0      1
# 1970.0      1
# 1996.0      1
# 2003.0      1
# 2004.0      1
# 2011.0      1
# 1978.0      1
# 1995.0      1
# 1898.0      1
# 2007.0      1
# 1965.0      1
# 1987.0      1
# Name: count, dtype: int64

# %% [markdown]
# ### Parking Spaces

# %%
plt.figure(figsize=(12,6))
sns.barplot(houses['Parking Spaces'].value_counts())
# Out:
# <Axes: xlabel='Parking Spaces', ylabel='count'>

# %%
houses['Parking Spaces'].value_counts()
# Out:
# Parking Spaces
# 1.0       698
# 2.0       464
# 3.0       296
# 4.0       136
# 5.0        63
# 6.0        33
# 10.0       19
# 7.0        18
# 8.0        11
# 100.0       2
# 15.0        2
# 20.0        1
# 11.0        1
# 21.0        1
# 250.0       1
# 32.0        1
# 1000.0      1
# 12.0        1
# Name: count, dtype: int64

# %%
houses[houses['Parking Spaces']>=5]
# Out:
#        Type  Price(Cr)  Bath(s)  Area(Marla)  Bedroom(s)     Location  \
# 37    House       19.0      7.0         20.0         9.0         F-11
# 41    House       19.0      6.0         24.0         8.0         G-10
# 69    House       26.5      6.0         20.0         7.0         D-12
# 94    House       58.0      6.0         38.0         5.0          E-7
# 112   House       10.0      5.0         20.0         5.0  DHA Defence
# ...     ...        ...      ...          ...         ...          ...
# 2824  House       39.0      6.0         26.0         6.0          F-7
# 2832  House       65.0      3.0         38.0         3.0          E-7
# 2838  House       65.0     11.0         40.0        10.0          F-7
# 2853  House       34.0      8.0         28.0         7.0          F-7
# 2865  House       16.0     16.0         22.0        14.0         G-11
#
#                                             Description  \
# 37    Corner House For Sale 50/90 Triple Story Prime...
# 41    outstanding location Beautiful House 60/90 600...
# 69    Luxurious 3-Story Kanal House for Sale Key Fea...
# 94    Details; 1. Size 80 x 105 : 975 sqyrds. 2. Sun...
# 112   We offer you just the right House to purchase....
# ...                                                 ...
# 2824  Fully Renovated House Available For Sale In F7...
# 2832  When you have a property of 933 Square Yards w...
# 2838  Details: 1. Size 100 x 90 = 1000 sqyrds. 2. su...
# 2853  house available for sale in f7 demoliable hous...
# 2865  Kanal+ Big and Elegant House is available for ...
#
#                                Amenities: Main Features  \
# 37    Built in year: 1998, Parking Spaces: 6, Double...
# 41    Built in year: 1997, Parking Spaces: 6, Double...
# 69    Built in year: 2025, Parking Spaces: 6, Double...
# 94    Built in year: 1990, Parking Spaces: 10, Doubl...
# 112   Built in year: 2024, Parking Spaces: 5, Double...
# ...                                                 ...
# 2824  Built in year: 2024, Parking Spaces: 5, Double...
# 2832  Built in year: 2025, Parking Spaces: 6, Double...
# 2838  Parking Spaces: 6, Double Glazed Windows, Cent...
# 2853  Built in year: 2024, Parking Spaces: 5, Double...
# 2865  Built in year: 2025, Parking Spaces: 6, Floori...
#
#                                        Amenities: Rooms  \
# 37    Bedrooms: 9, Bathrooms: 10, Servant Quarters: ...
# 41    Bedrooms: 8, Bathrooms: 8, Servant Quarters: 2...
# 69    Bedrooms: 7, Bathrooms: 7, Servant Quarters: 1...
# 94    Bedrooms: 5, Bathrooms: 6, Servant Quarters: 2...
# 112   Bedrooms: 5, Bathrooms: 5, Servant Quarters: 2...
# ...                                                 ...
# 2824  Bedrooms: 6, Bathrooms: 6, Servant Quarters: 2...
# 2832  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 1...
# 2838  Bedrooms: 10, Bathrooms: 11, Servant Quarters:...
# 2853  Bedrooms: 7, Bathrooms: 8, Servant Quarters: 2...
# 2865  Bedrooms: 14, Bathrooms: 16, Servant Quarters:...
#
#                   Amenities: Business and Communication  ... Parking Spaces  \
# 37    Broadband Internet Access, Satellite or Cable ...  ...            6.0
# 41    Broadband Internet Access, Satellite or Cable ...  ...            6.0
# 69    Broadband Internet Access, Satellite or Cable ...  ...            6.0
# 94    Broadband Internet Access, Satellite or Cable ...  ...           10.0
# 112   Broadband Internet Access, Satellite or Cable ...  ...            5.0
# ...                                                 ...  ...            ...
# 2824  Broadband Internet Access, Satellite or Cable ...  ...            5.0
# 2832  Broadband Internet Access, Satellite or Cable ...  ...            6.0
# 2838  Broadband Internet Access, Satellite or Cable ...  ...            6.0
# 2853  Broadband Internet Access, Satellite or Cable ...  ...            5.0
# 2865  Broadband Internet Access, Satellite or Cable ...  ...            6.0
#
#      Floor Bedrooms  Bathrooms  Servant Quarters  Kitchens  Store Rooms  \
# 37     3.0      9.0       10.0               1.0       2.0          1.0
# 41     3.0      8.0        8.0               2.0       2.0          2.0
# 69     3.0      7.0        7.0               1.0       2.0          1.0
# 94     2.0      5.0        6.0               2.0       1.0          1.0
# 112    2.0      5.0        5.0               2.0       2.0          2.0
# ...    ...      ...        ...               ...       ...          ...
# 2824   2.0      6.0        6.0               2.0       2.0          2.0
# 2832   2.0      3.0        3.0               1.0       1.0          1.0
# 2838   3.0     10.0       11.0               2.0       2.0          2.0
# 2853   2.0      7.0        8.0               2.0       2.0          1.0
# 2865   3.0     14.0       16.0               3.0       6.0          2.0
#
#       Swimming Pool  Storey Unit  BedBath_Diff
# 37              1.0          3.0           2.0
# 41              1.0          3.0           2.0
# 69              NaN          3.0           1.0
# 94              1.0          1.0          -1.0
# 112             1.0          NaN           0.0
# ...             ...          ...           ...
# 2824            1.0          NaN           0.0
# 2832            1.0          NaN           0.0
# 2838            NaN          NaN          -1.0
# 2853            1.0          NaN          -1.0
# 2865            NaN          NaN          -2.0
#
# [155 rows x 29 columns]

# %%
sns.scatterplot(houses[houses['Parking Spaces']<=4],x='Area(Marla)',y='Parking Spaces')
# Out:
# <Axes: xlabel='Area(Marla)', ylabel='Parking Spaces'>

# %% [markdown]
# *By looking at this chart, we can deduce that the Parking Space column is misleading even though it looks useful.*
#
# The reason could be human error, the agent exaggerated this feature.
#
# **So the best thing is to drop it to avoid any error in the model**

# %% [markdown]
# ### Floor and Storey Unit

# %% [markdown]
# *Storey Unit is more reliable because we directly extracted from the description column.*
#
# ### What to do:
#
# 1. Use Storey Unit as the Floor column
# 2. And use Floor column where Storey Unit information is missing.

# %%
sns.barplot(houses['Floor'].value_counts())
# Out:
# <Axes: xlabel='Floor', ylabel='count'>

# %%
sns.barplot(houses['Storey Unit'].value_counts())
# Out:
# <Axes: xlabel='Storey Unit', ylabel='count'>

# %%
Nanstorey = houses['Storey Unit'].isnull()[houses['Storey Unit'].isnull()==True].index

# %%
houses.loc[Nanstorey,'Storey Unit'] = houses.loc[Nanstorey,'Floor']

# %%
sns.barplot(houses['Storey Unit'].value_counts())
# Out:
# <Axes: xlabel='Storey Unit', ylabel='count'>

# %% [markdown]
# ### Servant Quarter

# %%
houses['Servant Quarters'].value_counts()
# Out:
# Servant Quarters
# 1.0     964
# 2.0     397
# 0.0     178
# 3.0      21
# 8.0       4
# 4.0       4
# 6.0       2
# 12.0      2
# 7.0       1
# Name: count, dtype: int64

# %%
sns.barplot(houses['Servant Quarters'].value_counts())
# Out:
# <Axes: xlabel='Servant Quarters', ylabel='count'>

# %% [markdown]
# *Setting to Nan for equal to 0 and 2+*

# %%
Nanservantquar = houses[~houses['Servant Quarters'].isin([1,2])].index

# %%
houses.loc[Nanservantquar,'Servant Quarters'] = np.nan

# %% [markdown]
# ### Store Rooms

# %%
sns.barplot(houses['Store Rooms'].value_counts())
# Out:
# <Axes: xlabel='Store Rooms', ylabel='count'>

# %% [markdown]
# *Setting to Nan for equal to 0 and 2+*

# %%
Nanstore = houses[~houses['Store Rooms'].isin([1,2,3])].index

# %%
houses.loc[Nanstore,'Store Rooms'] = np.nan

# %% [markdown]
# ### Kitchens

# %%
sns.barplot(houses['Kitchens'].value_counts())
# Out:
# <Axes: xlabel='Kitchens', ylabel='count'>

# %%
houses[houses['Kitchens']>3].index
# Out:
# Index([456, 545, 566, 977, 2142, 2716, 2729, 2794, 2865], dtype='int64')

# %%
houses.loc[2865]
# Out:
# Type                                                                                 House
# Price(Cr)                                                                             16.0
# Bath(s)                                                                               16.0
# Area(Marla)                                                                           22.0
# Bedroom(s)                                                                            14.0
# Location                                                                              G-11
# Description                              Kanal+ Big and Elegant House is available for ...
# Amenities: Main Features                 Built in year: 2025, Parking Spaces: 6, Floori...
# Amenities: Rooms                         Bedrooms: 14, Bathrooms: 16, Servant Quarters:...
# Amenities: Business and Communication    Broadband Internet Access, Satellite or Cable ...
# Amenities: Community Features             Community Lawn or Garden, Kids Play Area, Mosque
# Amenities: Healthcare Recreational                                          Lawn or Garden
# Amenities: Other Facilities                               Security Staff, Other Facilities
# IsPrimeLoc                                                                           False
# SolarInstalled                                                                       False
# WaterBore                                                                            False
# CornerHouse                                                                           True
# luxury_type                                                                              1
# Built in year                                                                       2025.0
# Parking Spaces                                                                         6.0
# Floor                                                                                  3.0
# Bedrooms                                                                              14.0
# Bathrooms                                                                             16.0
# Servant Quarters                                                                       NaN
# Kitchens                                                                               6.0
# Store Rooms                                                                            2.0
# Swimming Pool                                                                          NaN
# Storey Unit                                                                            3.0
# BedBath_Diff                                                                          -2.0
# Name: 2865, dtype: object

# %%
houses['Description'].loc[2865]
# Out:
# 'Kanal+ Big and Elegant House is available for Sale in G11 Islamabad Size 60x90 14 Bedrooms 16 Washrooms 6 Drwaing Dinings 6 TVLs 6 Kitchens 3 Gates 4 Gas Meters 4 Electric Meters Ample parking space Corner with extra land and basement Wide streets Near by Masjid and Market CDA Transfer P. S. : Pictures are real'

# %% [markdown]
# *Upon further analyzing, Kitchens > 3 doesn't seems outlier, so we will keep them*

# %% [markdown]
# *However changing the Kitchens = 0 to Nan*

# %%
Nankitchens = houses[~houses['Kitchens'].isin([1,2])].index

# %%
houses.loc[Nankitchens,'Kitchens'] = np.nan

# %%
# Saving the file

# %%
houses.to_csv('houses_outlier_handled.csv')
