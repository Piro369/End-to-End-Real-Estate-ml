# %% [markdown]
# ## Final Funcion at the end

# %%
import pandas as pd

# %%
import os

# %%
os.path.isfile('app.py')
# Out:
# True

# %%
files = os.listdir("C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/Scraping")

files = [i for i in files if i.startswith('final_data')]

# %%
files
# Out:
# ['final_data_(0_to_300_rows).csv',
#  'final_data_(1001_to_1300_rows).csv',
#  'final_data_(1301_to_1500_rows).csv',
#  'final_data_(1501_to_2000_rows).csv',
#  'final_data_(2001_to_2300_rows).csv',
#  'final_data_(2301_to_2600_rows).csv',
#  'final_data_(2601_to_3000_rows).csv',
#  'final_data_(301_to_600_rows).csv',
#  'final_data_(601_to_1000_rows).csv']

# %%
original_df = pd.DataFrame()

# %%
#df1 = pd.read_csv('final_data_(0_to_300_rows).csv')
for fileName in files:
    temp = pd.read_csv(fileName)

    original_df = pd.concat((original_df,temp))

# %%
original_df
# Out:
#                                            Scraped_URL   Type          Price  \
# 0    https://www.zameen.com/Property/d_12_d-12_2_10...  House    PKR12 Crore
# 1    https://www.zameen.com/Property/d_12_d-12_4_4_...  House   PKR4.3 Crore
# 2    https://www.zameen.com/Property/d_12_d-12_1_5_...  House  PKR5.75 Crore
# 3    https://www.zameen.com/Property/bahria_enclave...  House   PKR2.7 Crore
# 4    https://www.zameen.com/Property/fechs_jinnah_g...  House     PKR3 Crore
# ..                                                 ...    ...            ...
# 316  https://www.zameen.com/Property/dha_valley_dha...  House     PKR83 Lakh
# 317  https://www.zameen.com/Property/dha_valley_ole...  House     PKR75 Lakh
# 318  https://www.zameen.com/Property/islamabad_h-13...  House   PKR2.4 Crore
# 319  https://www.zameen.com/Property/islamabad_e-11...  House   PKR7.9 Crore
# 320  https://www.zameen.com/Property/islamabad_g-11...  House    PKR16 Crore
#
# ...

# %%
import pandas as pd
pd.concat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 pd.concat()
#
# TypeError: concat() missing 1 required positional argument: 'objs'

# %%
def mergingDFs():
    import pandas as pd
    import os

    global files
    files = os.listdir("C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/Scraping")

    files = [i for i in files if i.startswith('final_data')]

    original_df = pd.DataFrame()

    for fileName in files:
        temp = pd.read_csv(fileName)
    
        original_df = pd.concat((original_df,temp),)

    return original_df

# %%
mergingDFs()
# Out:
#                                            Scraped_URL   Type          Price  \
# 0    https://www.zameen.com/Property/d_12_d-12_2_10...  House    PKR12 Crore
# 1    https://www.zameen.com/Property/d_12_d-12_4_4_...  House   PKR4.3 Crore
# 2    https://www.zameen.com/Property/d_12_d-12_1_5_...  House  PKR5.75 Crore
# 3    https://www.zameen.com/Property/bahria_enclave...  House   PKR2.7 Crore
# 4    https://www.zameen.com/Property/fechs_jinnah_g...  House     PKR3 Crore
# ..                                                 ...    ...            ...
# 316  https://www.zameen.com/Property/dha_valley_dha...  House     PKR83 Lakh
# 317  https://www.zameen.com/Property/dha_valley_ole...  House     PKR75 Lakh
# 318  https://www.zameen.com/Property/islamabad_h-13...  House   PKR2.4 Crore
# 319  https://www.zameen.com/Property/islamabad_e-11...  House   PKR7.9 Crore
# 320  https://www.zameen.com/Property/islamabad_g-11...  House    PKR16 Crore
#
# ...

# %%
df = mergingDFs()

# %%
df.head()
# Out:
#                                          Scraped_URL   Type          Price  \
# 0  https://www.zameen.com/Property/d_12_d-12_2_10...  House    PKR12 Crore
# 1  https://www.zameen.com/Property/d_12_d-12_4_4_...  House   PKR4.3 Crore
# 2  https://www.zameen.com/Property/d_12_d-12_1_5_...  House  PKR5.75 Crore
# 3  https://www.zameen.com/Property/bahria_enclave...  House   PKR2.7 Crore
# 4  https://www.zameen.com/Property/fechs_jinnah_g...  House     PKR3 Crore
#
#   Bath(s)       Area   Purpose Bedroom(s)        Added  \
# 0       7   10 Marla  For Sale          6   2 days ago
# 1       5  4.4 Marla  For Sale          3   2 days ago
# 2       6    5 Marla  For Sale          5   2 days ago
# 3       4    5 Marla  For Sale          3   5 days ago
# 4       6    7 Marla  For Sale          5  2 weeks ago
#
#                                     Location  \
# 0         D-12, Islamabad, Islamabad Capital
# 1         D-12, Islamabad, Islamabad Capital
# ...

# %%
df.to_csv('C:\\Users\\Wajih\\Work (DataScience)\\CAPSTONE PROJECTS\\Real Estate Project\\Zameen.com\\Data Cleaning\\zameen.csv')
