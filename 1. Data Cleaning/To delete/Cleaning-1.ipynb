# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('zameen.csv',index_col=0)

# %%
df.head()
# Out:
#                                          Scraped_URL   Type          Price  \
# 0  https://www.zameen.com/Property/d_12_d-12_2_10...  House    PKR12 Crore
# 1  https://www.zameen.com/Property/d_12_d-12_4_4_...  House   PKR4.3 Crore
# 2  https://www.zameen.com/Property/d_12_d-12_1_5_...  House  PKR5.75 Crore
# 3  https://www.zameen.com/Property/bahria_enclave...  House   PKR2.7 Crore
# 4  https://www.zameen.com/Property/fechs_jinnah_g...  House     PKR3 Crore
#
#   Bath(s)       Area   Purpose Bedroom(s)        Added  \
# 0       7   10 Marla  For Sale          6   2 days ago
# 1       5  4.4 Marla  For Sale          3   2 days ago
# 2       6    5 Marla  For Sale          5   2 days ago
# 3       4    5 Marla  For Sale          3   5 days ago
# 4       6    7 Marla  For Sale          5  2 weeks ago
#
#                                     Location  \
# 0         D-12, Islamabad, Islamabad Capital
# 1         D-12, Islamabad, Islamabad Capital
# 2         D-12, Islamabad, Islamabad Capital
# 3  Bahria Town, Islamabad, Islamabad Capital
# 4        FECHS, Islamabad, Islamabad Capital
#
#                                          Description  \
# 0  10 MARLA LUXXARY BRAND NEW PARK FACE AVAILABLE...
# 1  4.44 Marla Single Unit Luxury House with Open ...
# 2  5 Marla Double Unit Front-Open 50 ft street Ho...
# 3  Brand-New Designer House for Sale in Bahria En...
# 4  Now We Found A Beautiful And Luxury House In J...
#
#                             Amenities: Main Features  \
# 0  Built in year, Parking Spaces: 4, Double Glaze...
# 1  Built in year, Parking Spaces: 1, Double Glaze...
# 2  Built in year: 4, Parking Spaces: 2, Double Gl...
# 3  Built in year: 2025, Parking Spaces, Double Gl...
# 4  Built in year, Parking Spaces, Double Glazed W...
#
#                                     Amenities: Rooms  \
# 0  Bedrooms: 6, Bathrooms: 8, Servant Quarters: 2...
# 1  Bedrooms: 3, Bathrooms: 5, Servant Quarters: 1...
# 2  Bedrooms: 5, Bathrooms: 6, Servant Quarters: 1...
# 3  Bedrooms: 3, Bathrooms: 4, Servant Quarters: 1...
# 4  Bedrooms: 3, Bathrooms: 3, Servant Quarters: 2...
#
#                Amenities: Business and Communication  \
# 0  Broadband Internet Access, Satellite or Cable ...
# 1  Broadband Internet Access, Satellite or Cable ...
# 2  Broadband Internet Access, Satellite or Cable ...
# 3  Broadband Internet Access, Satellite or Cable ...
# 4  Broadband Internet Access, Satellite or Cable ...
#
#                        Amenities: Community Features  \
# 0  Community Lawn or Garden, Community Swimming P...
# 1  Community Lawn or Garden, Community Swimming P...
# 2  Community Lawn or Garden, Community Swimming P...
# 3  Community Lawn or Garden, Community Swimming P...
# 4  Community Lawn or Garden, Community Swimming P...
#
#                   Amenities: Healthcare Recreational  \
# 0  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 1  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 2  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 3  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 4  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
#
#     Amenities: Nearby Locations and Other Facilities  \
# 0  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 2  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 3  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 4  Nearby Schools, Nearby Hospitals, Nearby Shopp...
#
#                          Amenities: Other Facilities Initial Amount  \
# 0                   Security Staff, Other Facilities            NaN
# 1                   Security Staff, Other Facilities            NaN
# 2  Maintenance Staff, Security Staff, Facilities ...            NaN
# 3  Maintenance Staff, Security Staff, Facilities ...            NaN
# 4  Maintenance Staff, Security Staff, Facilities ...            NaN
#
#   Monthly Installment Remaining Installments
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2879 entries, 0 to 2879
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Scraped_URL                                       2879 non-null   object
#  1   Type                                              2879 non-null   object
#  2   Price                                             2879 non-null   object
#  3   Bath(s)                                           2879 non-null   object
#  4   Area                                              2879 non-null   object
#  5   Purpose                                           2879 non-null   object
#  6   Bedroom(s)                                        2879 non-null   object
#  7   Added                                             2879 non-null   object
#  8   Location                                          2879 non-null   object
#  9   Description                                       2879 non-null   object
#  10  Amenities: Main Features                          2695 non-null   object
#  11  Amenities: Rooms                                  2634 non-null   object
#  12  Amenities: Business and Communication             2528 non-null   object
#  13  Amenities: Community Features                     2521 non-null   object
#  14  Amenities: Healthcare Recreational                2283 non-null   object
#  15  Amenities: Nearby Locations and Other Facilities  2693 non-null   object
#  16  Amenities: Other Facilities                       2495 non-null   object
#  17  Initial Amount                                    83 non-null     object
#  18  Monthly Installment                               83 non-null     object
#  19  Remaining Installments                            83 non-null     object
# dtypes: object(20)
# memory usage: 472.3+ KB

# %%
df.isnull().sum()
# Out:
# Scraped_URL                                            0
# Type                                                   0
# Price                                                  0
# Bath(s)                                                0
# Area                                                   0
# Purpose                                                0
# Bedroom(s)                                             0
# Added                                                  0
# Location                                               0
# Description                                            0
# Amenities: Main Features                             184
# Amenities: Rooms                                     245
# Amenities: Business and Communication                351
# Amenities: Community Features                        358
# Amenities: Healthcare Recreational                   596
# Amenities: Nearby Locations and Other Facilities     186
# Amenities: Other Facilities                          384
# Initial Amount                                      2796
# Monthly Installment                                 2796
# Remaining Installments                              2796
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cols_to_remove = ['Scraped_URL','Purpose','Added','Initial Amount','Monthly Installment','Remaining Installments']

# %%
df.drop(columns=cols_to_remove,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2879 entries, 0 to 2879
# Data columns (total 14 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Type                                              2879 non-null   object
#  1   Price                                             2879 non-null   object
#  2   Bath(s)                                           2879 non-null   object
#  3   Area                                              2879 non-null   object
#  4   Bedroom(s)                                        2879 non-null   object
#  5   Location                                          2879 non-null   object
#  6   Description                                       2879 non-null   object
#  7   Amenities: Main Features                          2695 non-null   object
#  8   Amenities: Rooms                                  2634 non-null   object
#  9   Amenities: Business and Communication             2528 non-null   object
#  10  Amenities: Community Features                     2521 non-null   object
#  11  Amenities: Healthcare Recreational                2283 non-null   object
#  12  Amenities: Nearby Locations and Other Facilities  2693 non-null   object
#  13  Amenities: Other Facilities                       2495 non-null   object
# dtypes: object(14)
# memory usage: 337.4+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %% [markdown]
# ### Price
# Selecting a common unit

# %%
df['Price'].str.split(' ').str.get(1).value_counts()
# Out:
# Price
# Crore    2583
# Lakh      261
# Arab       35
# Name: count, dtype: int64

# %%
df['Price'].str.split(' ').str.get(0).str[3:].astype('float')
# Out:
# 0       12.00
# 1        4.30
# 2        5.75
# 3        2.70
# 4        3.00
#         ...
# 2875    83.00
# 2876    75.00
# 2877     2.40
# 2878     7.90
# 2879    16.00
# Name: Price, Length: 2879, dtype: float64

# %%
def Price_to_Cr(series):
    unit = series.strip().split(' ')[1]
    price = float(series.strip().split(' ')[0][3:])
    if (unit =='Lakh'):
        price = price / 100
    elif (unit =='Arab'):
        price = price * 100

    series = price
    return series

# %%
df['Price'].apply(Price_to_Cr)
# Out:
# 0       12.00
# 1        4.30
# 2        5.75
# 3        2.70
# 4        3.00
#         ...
# 2875     0.83
# 2876     0.75
# 2877     2.40
# 2878     7.90
# 2879    16.00
# Name: Price, Length: 2879, dtype: float64

# %%
df['Price'] = df['Price'].apply(Price_to_Cr)

# %%
df['Price'].sample(10)
# Out:
# 1014    19.50
# 1391     0.71
# 321      2.50
# 1825    24.00
# 2496     8.50
# 2861    30.00
# 34      10.75
# 999     13.50
# 1475     2.15
# 2460     0.75
# Name: Price, dtype: float64

# %%
df.rename(columns={"Price":'Price(Cr)'},inplace=True)

# %% [markdown]
# ### Bath(s)
# There is '-' category,<br>We can fill it from 'Amenities: Room'

# %%
df['Bath(s)'].value_counts()
# Out:
# Bath(s)
# 6     959
# 5     412
# 2     320
# 4     288
# 3     271
# 7     235
# 1     213
# -     178
# 10      2
# 9       1
# Name: count, dtype: int64

# %%
df[df['Bath(s)'] == '-']['Amenities: Rooms'].str.split(',').str.get(1).str.split(':').str.get(0).value_counts()
# Out:
# Amenities: Rooms
# Bathrooms       126
# Dining Room      18
# Drawing Room      1
# Other Rooms       1
# Name: count, dtype: int64

# %%
df[df['Bath(s)'] == '-']['Amenities: Rooms'].sample(5)
# Out:
# 1860                     Servant Quarters: 1, Other Rooms
# 392     Bedrooms, Bathrooms, Servant Quarters, Drawing...
# 243     Bedrooms: 5, Bathrooms: 6, Servant Quarters: 1...
# 2526                            Drawing Room, Dining Room
# 1072    Bedrooms: 9, Bathrooms: 9, Servant Quarters: 3...
# Name: Amenities: Rooms, dtype: object

# %% [markdown]
# <br>
# **Will remove those rows where you cannot fill the 'Bath(s)' information from 'Amenities: Room'

# %%
temp = df[df['Bath(s)'] == '-']['Amenities: Rooms'].str.split('Bathrooms').str.get(1).str.split(',').str.get(0).str.strip()
empty_idxs = temp[temp==''].index

# %%
temp.sample(5)
# Out:
# 1683    : 5
# 2244    : 5
# 2363
# 472     : 6
# 1931
# Name: Amenities: Rooms, dtype: object

# %%
empty_idxs
# Out:
# Index([392, 443, 1457, 1931, 2363], dtype='int64')

# %%
df.drop(index=empty_idxs,inplace=True)

# %%
df.shape[0]
# Out:
# 2874

# %% [markdown]
# ### Area
# Converting Kanal to Marla. <br>
# 1 Kanal = 20 Marla

# %%
df['Area'].sample(5)
# Out:
# 2334    10 Marla
# 2680    10 Marla
# 2541     1 Kanal
# 2251    10 Marla
# 885      6 Marla
# Name: Area, dtype: object

# %%
# No other unit for Area
df['Area'].str.split().str.get(1).value_counts()
# Out:
# Area
# Marla    2027
# Kanal     847
# Name: count, dtype: int64

# %%
# Out:
#        Type  Price(Cr) Bath(s)       Area Bedroom(s)  \
# 1651   Flat       0.23       1  1.1 Marla          -
# 1144   Flat       0.26       1  1.1 Marla          -
# 1815   Flat       0.29       -    1 Marla          -
# 1020   Flat       0.35       2  2.3 Marla          2
# 2017   Flat       0.35       1  1.3 Marla          -
# ...     ...        ...     ...        ...        ...
# 1628  House     180.00       -    4 Kanal          -
# 1857  House     180.00       5    4 Kanal          7
# 2408  House     200.00       6    4 Kanal          6
# 291   House     235.00       6  3.9 Kanal          9
# 868   House     400.00       -    4 Kanal          8
#
#                                        Location  \
# 1651         E-16, Islamabad, Islamabad Capital
# 1144  Soan Garden, Islamabad, Islamabad Capital
# 1815   Top City 1, Islamabad, Islamabad Capital
# 1020         H-13, Islamabad, Islamabad Capital
# 2017      Gulberg, Islamabad, Islamabad Capital
# ...                                         ...
# 1628          F-6, Islamabad, Islamabad Capital
# 1857          F-7, Islamabad, Islamabad Capital
# 2408          F-6, Islamabad, Islamabad Capital
# 291           F-6, Islamabad, Islamabad Capital
# 868           F-7, Islamabad, Islamabad Capital
#
#                                             Description  \
# 1651  Tower-X, Main Boulevard, Sector E-16/3 CDECHS ...
# 1144  In this add we discussed about Gross 250 sqft ...
# 1815  studio apartment for sale in top city 1 Islama...
# 1020  solid building Fully ventilation Apartment Siz...
# 2017  Studio Apartment for Sale in Gulberg Rasidenci...
# ...                                                 ...
# 1628  #Top Location #Hill Road #Corner #Extra land #...
# 1857  Marriott Estate And Builders Offer a Ideal Hou...
# 2408  f6-3 Most Desirable Location with swimming poo...
# 291   F-6/3 Beautiful House 100 % Out of Market Deal...
# 868   Marriott Estate And Builders Offer a Ideal Hou...
#
#                                Amenities: Main Features  \
# 1651                                                NaN
# 1144  Built in year: 2024, Parking Spaces: 5, Lobby ...
# 1815  Lobby in Building, Double Glazed Windows, Cent...
# 1020                   Flooring, Floor: 3, Elevators: 6
# 2017  Built in year: 2024, Parking Spaces: 2, Lobby ...
# ...                                                 ...
# 1628  Built in year: 2025, Parking Spaces: 2, Double...
# 1857  Built in year: 2009, Parking Spaces: 7, Double...
# 2408  Built in year: 2023, Parking Spaces, Double Gl...
# 291   Built in year: 2023, Parking Spaces: 4, Double...
# 868   Built in year: 20223, Parking Spaces: 7, Doubl...
#
#                                        Amenities: Rooms  \
# 1651                                                NaN
# 1144  Bedrooms: 1, Bathrooms: 1, Drawing Room, Dinin...
# 1815  Drawing Room, Dining Room, Study Room, Prayer ...
# 1020             Bedrooms: 2, Bathrooms: 2, Kitchens: 1
# 2017  Bedrooms: 1, Bathrooms: 1, Servant Quarters, D...
# ...                                                 ...
# 1628  Bedrooms: 5, Bathrooms: 6, Servant Quarters: 1...
# 1857  Bedrooms: 4, Bathrooms: 5, Servant Quarters: 2...
# 2408  Bedrooms: 2, Bathrooms: 6, Servant Quarters: 2...
# 291   Bedrooms: 9, Bathrooms: 10, Servant Quarters: ...
# 868   Bedrooms: 6, Bathrooms: 7, Servant Quarters: 2...
#
#                   Amenities: Business and Communication  \
# 1651                                                NaN
# 1144  Broadband Internet Access, Satellite or Cable ...
# 1815  Broadband Internet Access, Satellite or Cable ...
# 1020                                                NaN
# 2017  Broadband Internet Access, Satellite or Cable ...
# ...                                                 ...
# 1628  Broadband Internet Access, Satellite or Cable ...
# 1857  Broadband Internet Access, Satellite or Cable ...
# 2408  Broadband Internet Access, Satellite or Cable ...
# 291   Broadband Internet Access, Satellite or Cable ...
# 868   Broadband Internet Access, Satellite or Cable ...
#
#                           Amenities: Community Features  \
# 1651                                                NaN
# 1144  Community Lawn or Garden, Community Swimming P...
# 1815  Community Lawn or Garden, First Aid or Medical...
# 1020                                                NaN
# 2017  Community Lawn or Garden, Community Swimming P...
# ...                                                 ...
# 1628  Community Lawn or Garden, Community Gym, First...
# 1857  Community Lawn or Garden, Community Gym, First...
# 2408  Community Lawn or Garden, Community Swimming P...
# 291   Community Lawn or Garden, Community Swimming P...
# 868   Community Lawn or Garden, Community Swimming P...
#
#                      Amenities: Healthcare Recreational  \
# 1651                                                NaN
# 1144  Sauna, Jacuzzi, Other Healthcare and Recreatio...
# 1815                                     Sauna, Jacuzzi
# 1020                                                NaN
# 2017  Sauna, Jacuzzi, Other Healthcare and Recreatio...
# ...                                                 ...
# 1628  Lawn or Garden, Sauna, Other Healthcare and Re...
# 1857                     Lawn or Garden, Sauna, Jacuzzi
# 2408  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 291   Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 868   Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
#
#        Amenities: Nearby Locations and Other Facilities  \
# 1651                                                NaN
# 1144  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1815  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1020                                                NaN
# 2017  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# ...                                                 ...
# 1628  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1857  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 2408  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 291   Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 868   Nearby Schools, Nearby Hospitals, Nearby Shopp...
#
#                             Amenities: Other Facilities
# 1651                                                NaN
# 1144  Maintenance Staff, Security Staff, Facilities ...
# 1815                   Security Staff, Other Facilities
# 1020                                                NaN
# 2017  Maintenance Staff, Security Staff, Laundry or ...
# ...                                                 ...
# 1628                                                NaN
# 1857  Maintenance Staff, Security Staff, Facilities ...
# 2408                   Security Staff, Other Facilities
# 291   Maintenance Staff, Security Staff, Facilities ...
# 868   Maintenance Staff, Security Staff, Facilities ...
#
# [2874 rows x 14 columns]

# %%
def Areaunitconverter(series):
    unit = series.split()[1].strip()
    no = float(series.split()[0])
    if unit == 'Kanal':
        no *= 20

    return no

# %%
df['Area'].apply(Areaunitconverter).tail(5)
# Out:
# 2875     5.0
# 2876     5.0
# 2877     5.0
# 2878     8.0
# 2879    22.0
# Name: Area, dtype: float64

# %%
df['Area'].tail(5)
# Out:
# 2875      5 Marla
# 2876      5 Marla
# 2877      5 Marla
# 2878      8 Marla
# 2879    1.1 Kanal
# Name: Area, dtype: object

# %%
df['Area'] = df['Area'].apply(Areaunitconverter)

# %%
df.rename(columns={'Area':'Area(Marla)'},inplace=True)

# %% [markdown]
# ### Location
# Remove the part 'Islamabad, Islmabad Capital' since it is the same every where.

# %%
df['Location']
# Out:
# 0              D-12, Islamabad, Islamabad Capital
# 1              D-12, Islamabad, Islamabad Capital
# 2              D-12, Islamabad, Islamabad Capital
# 3       Bahria Town, Islamabad, Islamabad Capital
# 4             FECHS, Islamabad, Islamabad Capital
#                           ...
# 2875    DHA Defence, Islamabad, Islamabad Capital
# 2876    DHA Defence, Islamabad, Islamabad Capital
# 2877           H-13, Islamabad, Islamabad Capital
# 2878           E-11, Islamabad, Islamabad Capital
# 2879           G-11, Islamabad, Islamabad Capital
# Name: Location, Length: 2874, dtype: object

# %%
df['Location'].str.split(',',n=1).str.get(1).value_counts()
# Out:
# Location
# Islamabad, Islamabad Capital    2874
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
df['Location'].str.split(',').str.get(0).value_counts().sort_index()
# Out:
# Location
# Abdullah Garden                     1
# Airport Enclave                     3
# Alipur Farash                       1
# Arsalan Town                        2
# B-17                              234
# Bahria Town                       184
# Bani Gala                         100
# Bhara kahu                          8
# Blue Area                           7
# Burma Town                          2
# C-18                                1
# CBR Town                           12
# Chak Shahzad                       12
# Constitution Avenue                 2
# D-12                               89
# D-17                               29
# DHA Defence                       533
# Diplomatic Enclave                 12
# E-11                               72
# E-16                                4
# E-17                                1
# E-18                                9
# E-7                                22
# Emaar Canyon Views                  8
# F-10                               86
# F-11                               86
# F-17                               11
# F-6                                69
# F-7                                66
# F-8                                96
# FECHS                              50
# Faisal Hills                       16
# Faisal Town - F-18                 64
# G-10                               36
# G-11                               55
# G-12                                1
# G-13                              100
# G-14                               21
# G-15                               27
# G-16                                6
# G-6                                10
# G-7                                 1
# G-8                                 5
# G-9                                28
# GT Road                            12
# Ghauri Town                         8
# Green Avenue                        1
# Gulberg                           137
# H-12                                1
# H-13                               31
# I-10                               15
# I-11                               12
# I-12                               19
# I-13                                1
# I-14                               13
# I-16                               13
# I-8                                48
# I-9                                 1
# Islamabad - Murree Expressway       1
# Islamabad Expressway               12
# Jhangi Syedan                       1
# Karakoram Diplomatic Enclave       10
# Kashmir Highway                    31
# Khanna Pul                         13
# Korang Town                         4
# Kuri Road                           8
# Lehtrar Road                        3
# Margalla Town                       1
# Multi Residencia & Orchards         2
# Mumtaz City                        28
# National Police Foundation          1
# National Police Foundation O-9      3
# Naval Anchorage                    21
# New Blue Area                       5
# OPF Valley                          1
# PAF Tarnol                          1
# PECHS                               2
# PWD Housing Scheme                 19
# Pakistan Town                       3
# Park Enclave                        6
# Park Road                           1
# Park View City                     15
# Phulgran                            1
# Pir Sohawa                          2
# Rawal Enclave                       1
# River Garden                        4
# Sarai Kharbuza                      1
# Sehala Farm House                   1
# Shah Allah Ditta                    1
# Shehzad Town                        1
# Simly Dam Road                      1
# Soan Garden                        49
# Taramrri                            1
# Tarlai                              3
# Tarnol                              4
# Top City 1                        110
# University Town                     2
# Zaraj Housing Scheme                6
# Name: count, dtype: int64

# %%
df['Location'] = df['Location'].str.split(',').str.get(0).str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2874 entries, 0 to 2879
# Data columns (total 14 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Type                                              2874 non-null   object
#  1   Price(Cr)                                         2874 non-null   float64
#  2   Bath(s)                                           2874 non-null   object
#  3   Area(Marla)                                       2874 non-null   float64
#  4   Bedroom(s)                                        2874 non-null   object
#  5   Location                                          2874 non-null   object
#  6   Description                                       2874 non-null   object
#  7   Amenities: Main Features                          2690 non-null   object
#  8   Amenities: Rooms                                  2629 non-null   object
#  9   Amenities: Business and Communication             2523 non-null   object
#  10  Amenities: Community Features                     2516 non-null   object
#  11  Amenities: Healthcare Recreational                2278 non-null   object
#  12  Amenities: Nearby Locations and Other Facilities  2688 non-null   object
#  13  Amenities: Other Facilities                       2491 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 401.3+ KB

# %%
df['Amenities: Rooms'].iloc[0]
# Out:
# 'Bedrooms: 6, Bathrooms: 8, Servant Quarters: 2, Drawing Room, Dining Room, Kitchens: 2, Study Room, Prayer Room, Powder Room, Gym, Store Rooms: 1, Steam Room, Lounge or Sitting Room, Laundry Room, Other Rooms'

# %%
df['Amenities: Main Features'].iloc[1]
# Out:
# 'Built in year, Parking Spaces: 1, Double Glazed Windows, Central Air Conditioning, Central Heating, Flooring, Electricity Backup, Waste Disposal, Floors: 2, Other Main Features'

# %%
df.to_csv('zameen_cleaned_v1.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(6)
