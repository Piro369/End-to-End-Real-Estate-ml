# %% [markdown]
# # Outline
#
# - Perform Preprocessing
# - Use a model to calculate the r2 score and MAE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv('../Feature Selection/X_train_flats.csv',index_col=0)
X_test = pd.read_csv('../Feature Selection/X_test_flats.csv',index_col=0)
y_train = pd.read_csv('../Feature Selection/y_train_flats.csv',index_col=0)
y_test = pd.read_csv('../Feature Selection/y_test_flats.csv',index_col=0)

# %%
X_train.head()
# Out:
#       Property era_Brand New (2025)  Property era_Established  \
# 6148                            0.0                       0.0
# 4031                            0.0                       0.0
# 1222                            0.0                       0.0
# 1783                            0.0                       0.0
# 1550                            0.0                       0.0
#
#       Property era_Future  Property era_Recently Built  Property era_Vintage  \
# 6148                  0.0                          1.0                   0.0
# 4031                  0.0                          0.0                   0.0
# 1222                  0.0                          1.0                   0.0
# 1783                  0.0                          1.0                   0.0
# 1550                  0.0                          1.0                   0.0
#
#       Floor Level_Ground/First Floor  Floor Level_High-Rise  \
# 6148                             1.0                    0.0
# ...
