# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/final_data_(0_to_300_rows).csv')

# %%
df1
# Out:
#                                            Scraped_URL   Type           Price  \
# 0    https://www.zameen.com/Property/d_12_d-12_2_10...  House     PKR12 Crore
# 1    https://www.zameen.com/Property/d_12_d-12_4_4_...  House    PKR4.3 Crore
# 2    https://www.zameen.com/Property/d_12_d-12_1_5_...  House   PKR5.75 Crore
# 3    https://www.zameen.com/Property/bahria_enclave...  House    PKR2.7 Crore
# 4    https://www.zameen.com/Property/fechs_jinnah_g...  House      PKR3 Crore
# ..                                                 ...    ...             ...
# 249  https://www.zameen.com/Property/gulberg_greens...   Flat   PKR1.75 Crore
# 250  https://www.zameen.com/Property/gulberg_reside...  House      PKR4 Crore
# 251  https://www.zameen.com/Property/islamabad_airp...  House    PKR1.5 Crore
# 252  https://www.zameen.com/Property/dha_defence_dh...  House  PKR13.75 Crore
# 253  https://www.zameen.com/Property/islamabad_f-8_...  House     PKR26 Crore
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Scraped_URL                                       254 non-null    object
#  1   Type                                              254 non-null    object
#  2   Price                                             254 non-null    object
#  3   Bath(s)                                           254 non-null    object
#  4   Area                                              254 non-null    object
#  5   Purpose                                           254 non-null    object
#  6   Bedroom(s)                                        254 non-null    object
#  7   Added                                             254 non-null    object
#  8   Location                                          254 non-null    object
# ...

# %%
df1['Type'].value_counts()
# Out:
# Type
# House         205
# Flat           43
# Farm House      6
# Name: count, dtype: int64

# %%
df1['Bath(s)'].value_counts()
# Out:
# Bath(s)
# 6    105
# 5     39
# 7     28
# 4     24
# 3     24
# 2     23
# 1      6
# -      5
# Name: count, dtype: int64

# %%
df1['Bedroom(s)'].value_counts()
# Out:
# Bedroom(s)
# 5     79
# 6     44
# 4     35
# 3     31
# 2     29
# 7     11
# 8     10
# 1      5
# 9      4
# -      4
# 10     2
# Name: count, dtype: int64
