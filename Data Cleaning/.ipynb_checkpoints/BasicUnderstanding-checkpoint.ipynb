# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Wajih/Work (DataScience)/CAPSTONE PROJECTS/Real Estate Project/Zameen.com/Scraping/final_data_(301_to_600_rows).csv')

# %%
df
# Out:
#                                            Scraped_URL        Type  \
# 0    https://www.zameen.com/Property/d_12_d-12_3_co...       House
# 1    https://www.zameen.com/Property/islamabad_chak...  Farm House
# 2    https://www.zameen.com/Property/top_city_1_top...       House
# 3    https://www.zameen.com/Property/islamabad_mumt...       House
# 4    https://www.zameen.com/Property/dha_defence_dh...       House
# ..                                                 ...         ...
# 220  https://www.zameen.com/Property/islamabad_fais...        Flat
# 221  https://www.zameen.com/Property/islamabad_fais...        Flat
# 222  https://www.zameen.com/Property/islamabad_b-17...       House
# 223  https://www.zameen.com/Property/islamabad_g-14...       House
# 224  https://www.zameen.com/Property/i_11_i-11_2_br...       House
#
#              Price Bath(s)       Area   Purpose Bedroom(s)        Added  \
# 0      PKR32 Crore       6  1.1 Kanal  For Sale          7   2 days ago
# 1      PKR1.1 Arab       7   23 Kanal  For Sale          7   6 days ago
# 2     PKR4.4 Crore       5   10 Marla  For Sale          5   1 week ago
# 3    PKR4.38 Crore       7   10 Marla  For Sale          5  3 weeks ago
# 4    PKR11.5 Crore       6    1 Kanal  For Sale          5   1 week ago
# ..             ...     ...        ...       ...        ...          ...
# 220     PKR60 Lakh       1  2.7 Marla  For Sale          1   1 week ago
# 221     PKR85 Lakh       2  4.7 Marla  For Sale          2   1 week ago
# 222   PKR2.2 Crore       6    5 Marla  For Sale          4  4 weeks ago
# 223  PKR7.85 Crore       6   10 Marla  For Sale          6   5 days ago
# 224   PKR6.3 Crore       7    8 Marla  For Sale          7  1 month ago
#
#                                              Location  \
# 0                  D-12, Islamabad, Islamabad Capital
# 1          Chak Shahzad, Islamabad, Islamabad Capital
# 2            Top City 1, Islamabad, Islamabad Capital
# 3           Mumtaz City, Islamabad, Islamabad Capital
# 4           DHA Defence, Islamabad, Islamabad Capital
# ..                                                ...
# 220        Faisal Hills, Islamabad, Islamabad Capital
# 221  Faisal Town - F-18, Islamabad, Islamabad Capital
# 222                B-17, Islamabad, Islamabad Capital
# 223                G-14, Islamabad, Islamabad Capital
# 224                I-11, Islamabad, Islamabad Capital
#
#                                            Description  \
# 0    Corner Park-Facing House for Sale D-12/3, Isla...
# 1    AN EXCELLET PALACIAL FARM HOUSE/ 23 KANALS/ NE...
# 2    The property of 10 Marla is an ideal option in...
# 3    DOUBLE ROAD 10 MARLA HOUSE AVAILABLE HIGHTED P...
# 4    Dha Phase 2 Ialamabad 1 Kanal single Unit Hous...
# ..                                                 ...
# 220  AFFORDABLE LUXURY, BUILDING IN FINISHING STAGE...
# 221  2 BED APARTMENT FOR SALE, LOCATED IN FAISAL TO...
# 222  Mpchs multi garden B-17 Islamabad 5 Marla ultr...
# 223  Best location brandnew house Huge extra land a...
# 224  Top location Brand new house High quality cons...
#
#                               Amenities: Main Features  \
# 0    Parking Spaces: 3, Double Glazed Windows, Floo...
# 1    Built in year: 6, Parking Spaces, Double Glaze...
# 2    Built in year: 1, Parking Spaces: 1, Double Gl...
# 3    Built in year: 2025, Parking Spaces: 2, Double...
# 4    Built in year: 2025, Parking Spaces: 3, Double...
# ..                                                 ...
# 220  Built in year: 2025, Parking Spaces, Lobby in ...
# 221  Built in year: 2024, Parking Spaces, Lobby in ...
# 222  Built in year: 2027, Parking Spaces: 1, Double...
# 223                      Built in year: 2025, Flooring
# 224                                                NaN
#
#                                       Amenities: Rooms  \
# 0    Bedrooms: 7, Bathrooms: 9, Servant Quarters: 2...
# 1    Bedrooms: 4, Bathrooms: 6, Servant Quarters, D...
# 2    Bedrooms: 4, Bathrooms: 5, Servant Quarters, D...
# 3    Bedrooms: 6, Bathrooms: 6, Servant Quarters, D...
# 4    Bedrooms: 5, Bathrooms: 6, Servant Quarters: 2...
# ..                                                 ...
# 220  Bedrooms: 1, Bathrooms: 1, Kitchens: 1, Lounge...
# 221  Bedrooms: 2, Bathrooms: 2, Drawing Room, Dinin...
# 222  Bedrooms: 4, Bathrooms: 6, Servant Quarters: 1...
# 223                                                NaN
# 224                                                NaN
#
#                  Amenities: Business and Communication  \
# 0    Broadband Internet Access, Satellite or Cable ...
# 1    Broadband Internet Access, Satellite or Cable ...
# 2    Broadband Internet Access, Satellite or Cable ...
# 3                            Broadband Internet Access
# 4    Broadband Internet Access, Satellite or Cable ...
# ..                                                 ...
# 220  Satellite or Cable TV Ready, Other Business an...
# 221  Broadband Internet Access, Satellite or Cable ...
# 222  Broadband Internet Access, Satellite or Cable ...
# 223  Broadband Internet Access, Satellite or Cable ...
# 224                                                NaN
#
#                          Amenities: Community Features  \
# 0    Community Lawn or Garden, Community Swimming P...
# 1    Community Lawn or Garden, Community Swimming P...
# 2    Community Lawn or Garden, Community Swimming P...
# 3    Community Lawn or Garden, Community Swimming P...
# 4    Community Lawn or Garden, Community Swimming P...
# ..                                                 ...
# 220  Community Lawn or Garden, Community Swimming P...
# 221  Community Lawn or Garden, Community Swimming P...
# 222  Community Lawn or Garden, Community Swimming P...
# 223  Community Gym, First Aid or Medical Centre, Mo...
# 224                                                NaN
#
#                     Amenities: Healthcare Recreational  \
# 0           Other Healthcare and Recreation Facilities
# 1    Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 2                                       Sauna, Jacuzzi
# 3                                       Lawn or Garden
# 4    Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# ..                                                 ...
# 220         Other Healthcare and Recreation Facilities
# 221         Other Healthcare and Recreation Facilities
# 222  Lawn or Garden, Swimming Pool, Sauna, Jacuzzi,...
# 223                                                NaN
# 224                                                NaN
#
#       Amenities: Nearby Locations and Other Facilities  \
# 0    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 2    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 3    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 4    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# ..                                                 ...
# 220  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 221  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 222  Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 223                                                NaN
# 224  Nearby Schools, Nearby Hospitals, Nearby Shopp...
#
#                            Amenities: Other Facilities Initial Amount  \
# 0                                                  NaN            NaN
# 1    Maintenance Staff, Security Staff, Facilities ...            NaN
# 2    Maintenance Staff, Security Staff, Facilities ...            NaN
# 3                                       Security Staff            NaN
# 4    Maintenance Staff, Security Staff, Facilities ...            NaN
# ..                                                 ...            ...
# 220                                                NaN            NaN
# 221                   Security Staff, Other Facilities            NaN
# 222  Maintenance Staff, Security Staff, Facilities ...            NaN
# 223                                                NaN            NaN
# 224                   Security Staff, Other Facilities            NaN
#
#     Monthly Installment Remaining Installments
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
# ..                  ...                    ...
# 220                 NaN                    NaN
# 221                 NaN                    NaN
# 222                 NaN                    NaN
# 223                 NaN                    NaN
# 224                 NaN                    NaN
#
# [225 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Scraped_URL                                       225 non-null    object
#  1   Type                                              225 non-null    object
#  2   Price                                             225 non-null    object
#  3   Bath(s)                                           225 non-null    object
#  4   Area                                              225 non-null    object
#  5   Purpose                                           225 non-null    object
#  6   Bedroom(s)                                        225 non-null    object
#  7   Added                                             225 non-null    object
#  8   Location                                          225 non-null    object
#  9   Description                                       225 non-null    object
#  10  Amenities: Main Features                          204 non-null    object
#  11  Amenities: Rooms                                  209 non-null    object
#  12  Amenities: Business and Communication             194 non-null    object
#  13  Amenities: Community Features                     198 non-null    object
#  14  Amenities: Healthcare Recreational                182 non-null    object
#  15  Amenities: Nearby Locations and Other Facilities  215 non-null    object
#  16  Amenities: Other Facilities                       191 non-null    object
#  17  Initial Amount                                    2 non-null      object
#  18  Monthly Installment                               2 non-null      object
#  19  Remaining Installments                            2 non-null      object
# dtypes: object(20)
# memory usage: 35.3+ KB

# %% [markdown]
# ### Type

# %%
df['Type'].value_counts()
# Out:
# Type
# House         174
# Flat           48
# Farm House      2
# Penthouse       1
# Name: count, dtype: int64

# %% [markdown]
# *There is a Pennthouse also*

# %% [markdown]
# ### Price

# %%
df['Price'].str.split('PKR').str.get(1).str.split(' ').str.get(1).value_counts()
# Out:
# Price
# Crore    206
# Lakh      16
# Arab       3
# Name: count, dtype: int64

# %% [markdown]
# #### Bath(s)

# %%
df['Bath(s)'].value_counts()
# Out:
# Bath(s)
# 6    87
# 5    35
# 3    21
# 4    19
# 2    19
# 7    17
# 1    15
# -    12
# Name: count, dtype: int64

# %% [markdown]
# *There is a '-' category*

# %%
df[df['Bath(s)']=='-']['Amenities: Rooms']
# Out:
# 17     Bedrooms: 7, Bathrooms: 7, Drawing Room, Dinin...
# 39     Bedrooms: 3, Bathrooms: 4, Servant Quarters: 1...
# 49     Bedrooms: 6, Bathrooms: 8, Servant Quarters: 1...
# 50     Bedrooms: 4, Bathrooms: 5, Servant Quarters: 1...
# 60     Bedrooms: 4, Bathrooms: 5, Servant Quarters: 1...
# 135                                                  NaN
# 136    Bedrooms: 5, Bathrooms: 6, Servant Quarters: 1...
# 172    Bedrooms, Bathrooms, Servant Quarters, Drawing...
# 173                                                  NaN
# 183    Bedrooms: 6, Bathrooms: 7, Servant Quarters: 2...
# 184    Bedrooms: 5, Bathrooms: 6, Servant Quarters: 2...
# 208    Bedrooms: 6, Bathrooms: 8, Servant Quarters: 1...
# Name: Amenities: Rooms, dtype: object

# %% [markdown]
# *Extract the no of Bathrooms from 'Amenities: Room'*

# %% [markdown]
# ### Area

# %%
df['Area'].str.split(' ').str.get(1).value_counts()
# Out:
# Area
# Marla    162
# Kanal     63
# Name: count, dtype: int64

# %% [markdown]
# *The unit of Area is Marla or Kanal*

# %% [markdown]
# ### Purpose

# %%
df['Purpose'].value_counts()
# Out:
# Purpose
# For Sale    225
# Name: count, dtype: int64

# %% [markdown]
# ### Location

# %%
df['Location'].str.split(',').str.get(0).nunique()
# Out:
# 46

# %% [markdown]
# *The only thing here useful is Sector/Town while the rest is same for all*

# %% [markdown]
# ### Description

# %%
df['Description']
# Out:
# 0      Corner Park-Facing House for Sale D-12/3, Isla...
# 1      AN EXCELLET PALACIAL FARM HOUSE/ 23 KANALS/ NE...
# 2      The property of 10 Marla is an ideal option in...
# 3      DOUBLE ROAD 10 MARLA HOUSE AVAILABLE HIGHTED P...
# 4      Dha Phase 2 Ialamabad 1 Kanal single Unit Hous...
#                              ...
# 220    AFFORDABLE LUXURY, BUILDING IN FINISHING STAGE...
# 221    2 BED APARTMENT FOR SALE, LOCATED IN FAISAL TO...
# 222    Mpchs multi garden B-17 Islamabad 5 Marla ultr...
# 223    Best location brandnew house Huge extra land a...
# 224    Top location Brand new house High quality cons...
# Name: Description, Length: 225, dtype: object

# %%
df['Description'].iloc[110]
# Out:
# 'Blue Rock Investment Present the 1kanal beautiful brand new designer and Stylish House Up For Sale in dha2 Islamabad all appliances, Fitting and finishing are imported. The Main Feature Are : Design As Single Unit 5 beautiful Bedrooms 6 stylish bathrooms 2 specious TV Lounge Drawing and Dinning 2 Luxurious kitchen Serventrooms with bath Store 3 Car parking Green lush Lawn For More details please contact as feel free Very neat and clean deal Meeting direct with house owner Almost all Dha2 sales houses are available.'

# %%
df['Scraped_URL'].get(101)
# Out:
# 'https://www.zameen.com/Property/g_6_g-6_3_g-6_3_old_house_for_sale_near_main_embassy_road_dead_end_street-49203593-3364-1.html'

# %% [markdown]
# **How to extract**
# - Dimensions: The word 'Size' is mentioned before, also in () after [Kanal/marla]
# - Location Details: Different Types (Sectors,City,Town). [Name] 'City', [Alphabet] - [Number]/[Number] , [Town Name] Phase [Phase Number], also 'Sector' is misspelled as 'Sec', also Location is written like this 'For sale in [Location]'
# - IsPrimeLocation: The words 'Prime' or 'Prime Location is mentioned'
# - SolarPanelAvailable: The word 'Solar' or 'Solar Panel' is mentioned. Spelling mistake 'Sollar'.
# - Storey unit --> 1 or 2 or 3. There are spelling mistakes in Storey and unit, unite, Story, also 'First Floor' or '1st Floor' is mentioned, there is a data point where someone wrote 'two point five story' meaning 2.5 .
# - MasterBedrooms --> specify number, [Number] Master Bedroom(s)
# - ElevatorAvailable --> For flats , [Elevator Number] Elevator
# - BalconyAvailable --> [Adjective] Balcony
# - CornerHouse --> True or False , Sometimes only 'Corner' is mentioned. And somewhere 'Second to Corner Location' is used.
# - WaterBoreAvailable --> 'Water Boring' or 'Water Bore'

# %% [markdown]
# ### Amenitites: Main Feature

# %%
df['Amenities: Main Features'].iloc[9]
# Out:
# 'Built in year: 4, Parking Spaces: 1, Lobby in Building, Central Air Conditioning, Central Heating, Flooring, Electricity Backup, Waste Disposal, Floor: 12, Floors in Building: 15, Elevators: 2, Service Elevators in Building, Furnished'

# %%
df['Amenities: Main Features'].str.count('Lobby').value_counts()
# Out:
# Amenities: Main Features
# 0.0    166
# 1.0     38
# Name: count, dtype: int64

# %%
df.dropna(subset=['Amenities: Main Features'])[df.dropna(subset=['Amenities: Main Features'])['Amenities: Main Features'].str.contains('Central Air Conditioning')]['Scraped_URL'].sample(20)
# Out:
# 172    https://www.zameen.com/Property/islamabad_orch...
# 170    https://www.zameen.com/Property/d_17_margalla_...
# 167    https://www.zameen.com/Property/dha_defence_dh...
# 120    https://www.zameen.com/Property/fechs_jinnah_g...
# 209    https://www.zameen.com/Property/islamabad_bani...
# 138    https://www.zameen.com/Property/islamabad_b-17...
# 112    https://www.zameen.com/Property/islamabad_f-6_...
# 213    https://www.zameen.com/Property/islamabad_top_...
# 25     https://www.zameen.com/Property/islamabad_d-12...
# 50     https://www.zameen.com/Property/b_17_faisal_ma...
# 35     https://www.zameen.com/Property/bahria_enclave...
# 54     https://www.zameen.com/Property/islamabad_g-13...
# 146    https://www.zameen.com/Property/islamabad_fais...
# 56     https://www.zameen.com/Property/dha_defence_dh...
# 161    https://www.zameen.com/Property/bahria_enclave...
# 139    https://www.zameen.com/Property/islamabad_g-10...
# 181    https://www.zameen.com/Property/dha_defence_ph...
# 106    https://www.zameen.com/Property/jinnah_gardens...
# 150    https://www.zameen.com/Property/dha_defence_dh...
# 4      https://www.zameen.com/Property/dha_defence_dh...
# Name: Scraped_URL, dtype: object

# %% [markdown]
# **What to Extract and How**
#
# - BuiltinYear
# - WindowsType
# - IsFurnished
# - HowManyFloors
# - ElectricityBackupAvail
# - NoofParkingSpaces
# - LobbyInBuilding

# %% [markdown]
# ### Amenitites: Rooms

# %%
df['Amenities: Rooms'].iloc[2]
# Out:
# 'Bedrooms: 4, Bathrooms: 5, Servant Quarters, Drawing Room, Dining Room, Kitchens: 2, Study Room, Prayer Room, Powder Room, Gym, Store Rooms, Steam Room, Lounge or Sitting Room, Laundry Room'

# %%
df['Amenities: Rooms'].str.contains('Laundry').value_counts()
# Out:
# Amenities: Rooms
# True     159
# False     50
# Name: count, dtype: int64

# %%
df.dropna(subset=['Amenities: Rooms'])[df.dropna(subset=['Amenities: Rooms'])['Amenities: Rooms'].str.contains('Gym')]['Scraped_URL'].sample(20)
# Out:
# 22     https://www.zameen.com/Property/islamabad_expr...
# 65     https://www.zameen.com/Property/dha_defence_dh...
# 57     https://www.zameen.com/Property/bahria_enclave...
# 26     https://www.zameen.com/Property/dha_defence_dh...
# 155    https://www.zameen.com/Property/d_12_d-12_4_7_...
# 14     https://www.zameen.com/Property/dha_defence_dh...
# 151    https://www.zameen.com/Property/islamabad_f-7_...
# 2      https://www.zameen.com/Property/top_city_1_top...
# 188    https://www.zameen.com/Property/bahria_enclave...
# 13     https://www.zameen.com/Property/dha_defence_dh...
# 35     https://www.zameen.com/Property/bahria_enclave...
# 165    https://www.zameen.com/Property/dha_defence_dh...
# 139    https://www.zameen.com/Property/islamabad_g-10...
# 18     https://www.zameen.com/Property/gulberg_gulber...
# 78     https://www.zameen.com/Property/islamabad_top_...
# 218    https://www.zameen.com/Property/g_15_zarkon_he...
# 36     https://www.zameen.com/Property/bahria_enclave...
# 107    https://www.zameen.com/Property/g_9_g-9_3_g_9_...
# 144    https://www.zameen.com/Property/soan_garden_so...
# 195    https://www.zameen.com/Property/dha_defence_dh...
# Name: Scraped_URL, dtype: object

# %% [markdown]
# **What and How to Extact**
#
# - Bedrooms
# - Bathrooms
# - ServantQuarters
# - Kitchen
# - StoreRooms
# - Lounge
# - PowderRoom
# - DrawingRoom
# - DiningRoom
# - LaundryRoom

# %% [markdown]
# ### Amenities: Business and Communication

# %%
df['Amenities: Business and Communication'].iloc[0]
# Out:
# 'Broadband Internet Access, Satellite or Cable TV Ready, Other Business and Communication Facilities'

# %%
df[df['Type']=='Flat']['Amenities: Business and Communication'].iloc[2]
# Out:
# 'Broadband Internet Access, Satellite or Cable TV Ready, Business Center or Media Room in Building, Conference Room in Building, Intercom, ATM Machines'

# %%
df[df['Type']!='Flat']['Amenities: Business and Communication'].str.contains('Media Room in Building').value_counts()
# Out:
# Amenities: Business and Communication
# False    154
# Name: count, dtype: int64

# %% [markdown]
# *'Business Center or Media Room in Building, Conference Room in Building, Intercom, ATM Machines' is only in flats*

# %%
df[df['Type']=='Flat']['Amenities: Business and Communication'].str.contains('Media Room in Building').value_counts()
# Out:
# Amenities: Business and Communication
# True     28
# False    12
# Name: count, dtype: int64

# %%
df[df['Type']=='Flat']['Amenities: Business and Communication'].str.contains('Conference Room in Building').value_counts()
# Out:
# Amenities: Business and Communication
# True     26
# False    14
# Name: count, dtype: int64

# %% [markdown]
# **What to Extract**
#
# - ATM Machines
# - Media Room
# - Conference Room
# - Intercom

# %% [markdown]
# ## Amenitites: Community Features

# %%
df['Amenities: Community Features'].duplicated().sum()
# Out:
# np.int64(194)

# %%
df['Amenities: Community Features'].drop_duplicates().iloc[6]
# Out:
# 'Mosque'

# %%
df.iloc[6]['Scraped_URL']
# Out:
# 'https://www.zameen.com/Property/bahria_enclave_bahria_enclave_-_sector_h_5_marla_house_for_sale-53347645-11983-1.html'

# %%
df.loc[27]
# Out:
# Scraped_URL                                         https://www.zameen.com/Property/islamabad_e-11...
# Type                                                                                             Flat
# Price                                                                                      PKR1 Crore
# Bath(s)                                                                                             3
# Area                                                                                        6.2 Marla
# Purpose                                                                                      For Sale
# Bedroom(s)                                                                                          3
# Added                                                                                     4 weeks ago
# Location                                                           E-11, Islamabad, Islamabad Capital
# Description                                         E11 Three Bedroom Unfurnished Apartment Availa...
# Amenities: Main Features                            Built in year: 5, Parking Spaces: 1, Lobby in ...
# Amenities: Rooms                                    Bedrooms: 3, Bathrooms: 3, Drawing Room, Dinin...
# Amenities: Business and Communication                                                             NaN
# Amenities: Community Features                                                                  Mosque
# Amenities: Healthcare Recreational                                                                NaN
# Amenities: Nearby Locations and Other Facilities    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# Amenities: Other Facilities                         Maintenance Staff, Security Staff, Laundry or ...
# Initial Amount                                                                                    NaN
# Monthly Installment                                                                               NaN
# Remaining Installments                                                                            NaN
# Name: 27, dtype: object

# %% [markdown]
# ### Amenities Healthcare Recreational

# %%
df['Amenities: Healthcare Recreational'].iloc[0]
# Out:
# 'Other Healthcare and Recreation Facilities'

# %%
df['Amenities: Healthcare Recreational'].duplicated().sum()
# Out:
# np.int64(205)

# %%
df['Amenities: Healthcare Recreational'].drop_duplicates().iloc[8]
# Out:
# 'Lawn or Garden, Swimming Pool, Sauna, Jacuzzi'

# %% [markdown]
# ### Amenities Nearby Locations

# %%
df['Amenities: Nearby Locations and Other Facilities'].duplicated().sum()
# Out:
# np.int64(217)

# %%
df['Amenities: Nearby Locations and Other Facilities'].str.contains('Distance').value_counts()
# Out:
# Amenities: Nearby Locations and Other Facilities
# True     204
# False     11
# Name: count, dtype: int64

# %%
temp = df.dropna(subset=['Amenities: Nearby Locations and Other Facilities'])
temp[temp['Amenities: Nearby Locations and Other Facilities'].str.contains('Distance')]['Amenities: Nearby Locations and Other Facilities']
# Out:
# 0      Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 1      Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 2      Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 3      Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 4      Nearby Schools, Nearby Hospitals, Nearby Shopp...
#                              ...
# 219    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 220    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 221    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 222    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# 224    Nearby Schools, Nearby Hospitals, Nearby Shopp...
# Name: Amenities: Nearby Locations and Other Facilities, Length: 204, dtype: object

# %%
temp[temp['Amenities: Nearby Locations and Other Facilities'].str.contains('Distance')]['Amenities: Nearby Locations and Other Facilities'].iloc[0]
# Out:
# 'Nearby Schools, Nearby Hospitals, Nearby Shopping Malls, Nearby Restaurants, Distance From Airport (kms), Nearby Public Transport Service, Other Nearby Places'

# %% [markdown]
# *'Distance From Airport (kms)' could be extracted from this Column*

# %% [markdown]
# ### Amenities: Other Facilites

# %%
df['Amenities: Other Facilities'].iloc[3]
# Out:
# 'Security Staff'

# %%
df.columns
# Out:
# Index(['Scraped_URL', 'Type', 'Price', 'Bath(s)', 'Area', 'Purpose',
#        'Bedroom(s)', 'Added', 'Location', 'Description',
#        'Amenities: Main Features', 'Amenities: Rooms',
#        'Amenities: Business and Communication',
#        'Amenities: Community Features', 'Amenities: Healthcare Recreational',
#        'Amenities: Nearby Locations and Other Facilities',
#        'Amenities: Other Facilities', 'Initial Amount', 'Monthly Installment',
#        'Remaining Installments'],
#       dtype='object')
