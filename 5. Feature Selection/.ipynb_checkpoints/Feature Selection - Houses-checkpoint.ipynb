# %% [markdown]
# # Outline
#
# Using different Techniques to select the Features

# %% [markdown]
# *But first we have perform Feature Engineering (categorical encoding and scaling)*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv('../Missing Values Imputation/Houses/X_train.csv',index_col=0)
X_test = pd.read_csv('../Missing Values Imputation/Houses/X_test.csv',index_col=0)
y_train = pd.read_csv('../Missing Values Imputation/Houses/y_train.csv',index_col=0)
y_test = pd.read_csv('../Missing Values Imputation/Houses/y_test.csv',index_col=0)

# %%
X_train.shape
# Out:
# (2878, 14)

# %%
y_test.shape
# Out:
# (1419, 1)

# %%
X_train.head()
# Out:
#       Bath(s)  Area(Marla)  Bedroom(s)  Servant Quarters  Kitchens  \
# 906       5.0          7.0         5.0               1.0       2.0
# 3379      6.0         10.0         5.0               1.0       2.0
# 2094      4.0          5.0         3.0               1.0       2.0
# 218       6.0         14.0         6.0               1.0       1.0
# 3455      5.0          4.0         5.0               1.0       2.0
#
#       Store Rooms  Storey Unit          Main Location  IsPrimeLoc  \
# 906           1.0          2.0                   D-12       False
# 3379          1.0          2.0         Bahria Enclave       False
# 2094          1.0          2.0  MPCHS - Multi Gardens        True
# 218           1.0          2.0                    G-9        True
# 3455          1.0          2.0                   G-13        True
#
#       SolarInstalled  WaterBore  CornerHouse  luxury_type      Property era
# 906            False      False        False            0  Brand New (2025)
# 3379           False      False        False            0  Brand New (2025)
# 2094           False      False         True            0  Brand New (2025)
# 218            False      False        False            0  Brand New (2025)
# 3455           False      False        False            0  Brand New (2025)

# %% [markdown]
# - Main Location --> Binary Encoding/ Target Encoding <br>

# %%
from sklearn.preprocessing import OneHotEncoder,FunctionTransformer,RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from category_encoders import TargetEncoder
from sklearn import set_config

set_config(transform_output='pandas')

# %%
# 1. Chronological order: From oldest to future concepts
property_era_mapping = {
    'Vintage': 1,
    'Established': 2,
    'Recently Built': 3,
    'Modern Era': 4,
    'Brand New (2025)': 5,
    'Future': 6
}

X_train['Property era'] = X_train['Property era'].map(property_era_mapping)
X_test['Property era'] = X_test['Property era'].map(property_era_mapping)

# %%
y_train_log = np.log1p(y_train)

preprocessor = ColumnTransformer(
    transformers=[
        
        ('TargetEncoding', TargetEncoder(smoothing=5, min_samples_leaf=2, handle_unknown='value'), ['Main Location']),
        
        ('LogTransform', FunctionTransformer(np.log1p), ['Area(Marla)'])
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
)

X_train_transformed = preprocessor.fit_transform(X_train, y_train['Price(Cr)'])

# %%
X_train_transformed.head()
# Out:
#       Main Location  Area(Marla)  Bath(s)  Bedroom(s)  Servant Quarters  \
# 906       11.633882     2.079442      5.0         5.0               1.0
# 3379       4.004817     2.397895      6.0         5.0               1.0
# 2094       3.778618     1.791759      4.0         3.0               1.0
# 218        9.283625     2.708050      6.0         6.0               1.0
# 3455       7.172108     1.609438      5.0         5.0               1.0
#
#       Kitchens  Store Rooms  Storey Unit  IsPrimeLoc  SolarInstalled  \
# 906        2.0          1.0          2.0       False           False
# 3379       2.0          1.0          2.0       False           False
# 2094       2.0          1.0          2.0        True           False
# 218        1.0          1.0          2.0        True           False
# 3455       2.0          1.0          2.0        True           False
#
#       WaterBore  CornerHouse  luxury_type  Property era
# 906       False        False            0             5
# 3379      False        False            0             5
# 2094      False         True            0             5
# 218       False        False            0             5
# 3455      False        False            0             5

# %%
X_test_transformed = preprocessor.transform(X_test)

# %%
X_test_transformed.shape
# Out:
# (1419, 14)

# %%
X_train_transformed.columns
# Out:
# Index(['Main Location', 'Area(Marla)', 'Bath(s)', 'Bedroom(s)',
#        'Servant Quarters', 'Kitchens', 'Store Rooms', 'Storey Unit',
#        'IsPrimeLoc', 'SolarInstalled', 'WaterBore', 'CornerHouse',
#        'luxury_type', 'Property era'],
#       dtype='str')

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %% [markdown]
# ### 1. Random Forest Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(random_state=42)
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9345666341517767
# Mean absolute error 1.3090865191193954

# %%
# Importances

df1_rf = pd.DataFrame(data=clf.feature_importances_,columns=['RF Importance'],index=clf.feature_names_in_).sort_values(by='RF Importance',ascending=False)

# %%
df1_rf.head()
# Out:
#                RF Importance
# Area(Marla)         0.664224
# Main Location       0.270798
# Bath(s)             0.022438
# Bedroom(s)          0.022373
# Property era        0.004474

# %% [markdown]
# ### 2. Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

clf = GradientBoostingRegressor(random_state=42)
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9361530715359323
# Mean absolute error 1.3977815588961546

# %%
# Importances

df2_gb = pd.DataFrame(data=clf.feature_importances_,columns=['Gb Importance'],index=clf.feature_names_in_).sort_values(by='Gb Importance',ascending=False)

# %%
df2_gb.head()
# Out:
#                Gb Importance
# Area(Marla)         0.629900
# Main Location       0.322424
# Bedroom(s)          0.022478
# Bath(s)             0.020133
# Property era        0.002264

# %% [markdown]
# ### 3. Permutation Importances

# %%
y_test_log = np.log1p(y_test)

# %%
from sklearn.inspection import permutation_importance

rf_clf = RandomForestRegressor(random_state=42)
rf_clf.fit(X_train_transformed,y_train_log)

perm_clf = permutation_importance(rf_clf,X_test_transformed,y_test_log,n_repeats=20,random_state=42)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
perm_clf.importances_mean
# Out:
# array([4.98539829e-01, 6.81796864e-01, 1.65015830e-02, 2.13533053e-02,
#        2.36485154e-04, 4.68766324e-04, 2.79441804e-04, 3.59196230e-04,
#        3.65582801e-05, 3.35290343e-04, 3.01744359e-04, 1.36812055e-03,
#        3.26709006e-04, 3.78781534e-03])

# %%
# Importances

df3_pm = pd.DataFrame(data=perm_clf.importances_mean,columns=['PM Importance'],index=X_train_transformed.columns).sort_values(by='PM Importance',ascending=False)
df3_pm.head()
# Out:
#                PM Importance
# Area(Marla)         0.681797
# Main Location       0.498540
# Bedroom(s)          0.021353
# Bath(s)             0.016502
# Property era        0.003788

# %%
X_train_transformed['Area(Marla)'].describe()
# Out:
# count    2878.000000
# mean        2.436152
# std         0.578076
# min         1.098612
# 25%         1.945910
# 50%         2.397895
# 75%         3.044522
# max         4.204693
# Name: Area(Marla), dtype: float64

# %% [markdown]
# ### 4. Lasso

# %%
from sklearn.linear_model import Lasso

clf = Lasso(alpha=0.001,random_state=42)
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.5957490875794962
# Mean absolute error 2.40180049873945

# %%
clf.coef_
# Out:
# array([ 0.03863111,  0.62146946,  0.01474821,  0.08330037,  0.01346871,
#         0.04935815, -0.01528603,  0.04223184,  0.04408673,  0.04138252,
#         0.05038365,  0.0552117 , -0.05337676,  0.02335148])

# %%
# Importances

df4_lasso =  pd.DataFrame(data=clf.coef_,columns=['Lasso Importance'],index=clf.feature_names_in_).sort_values(by='Lasso Importance',ascending=False)
df4_lasso.head()
# Out:
#              Lasso Importance
# Area(Marla)          0.621469
# Bedroom(s)           0.083300
# CornerHouse          0.055212
# WaterBore            0.050384
# Kitchens             0.049358

# %% [markdown]
# ### 5. Linear Regression

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression()
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.5952177558297476
# Mean absolute error 2.404953783352746

# %%
# Importances

df5_linear_reg =  pd.DataFrame(data=clf.coef_.ravel(),columns=['LR Importance'],index=clf.feature_names_in_).sort_values(by='LR Importance',ascending=False)
df5_linear_reg.head()
# Out:
#                 LR Importance
# Area(Marla)          0.627879
# Bedroom(s)           0.082149
# CornerHouse          0.065447
# SolarInstalled       0.064420
# WaterBore            0.058082

# %% [markdown]
# ### 6. RFE

# %%
from sklearn.feature_selection import RFE

estimator = RandomForestRegressor(random_state=42)

rfe_clf = RFE(estimator,n_features_to_select=X_train_transformed.shape[1],step=1)
rfe_clf.fit(X_train_transformed,y_train_log)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RFE(estimator=RandomForestRegressor(random_state=42), n_features_to_select=14)

# %%
rfe_clf.estimator_.feature_importances_
# Out:
# array([0.27079821, 0.6642243 , 0.02243801, 0.0223725 , 0.00131633,
#        0.00208193, 0.00144753, 0.00338179, 0.00186272, 0.00080464,
#        0.00111415, 0.00167579, 0.00200844, 0.00447367])

# %%
# Importances

df6_rfe = pd.DataFrame(data=rfe_clf.estimator_.feature_importances_,columns=['RFE Importance'],index=rfe_clf.feature_names_in_).sort_values(by='RFE Importance',ascending=False)
df6_rfe.head()
# Out:
#                RFE Importance
# Area(Marla)          0.664224
# Main Location        0.270798
# Bath(s)              0.022438
# Bedroom(s)           0.022373
# Property era         0.004474

# %% [markdown]
# ### 7. Shap

# %%
import shap

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train_transformed,y_train_log)

explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X_test_transformed)

shap_sum = np.abs(shap_values).mean(axis=0)

shap_sum
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# array([0.29357411, 0.45649521, 0.03793945, 0.03903706, 0.00330647,
#        0.00406321, 0.00297292, 0.00470859, 0.00424106, 0.00249863,
#        0.002319  , 0.00531932, 0.00368952, 0.01936312])

# %%
df7_shap = pd.DataFrame(index=X_train_transformed.columns,columns=['SHAP_score'],data=np.abs(shap_values).mean(axis=0)).sort_values(by='SHAP_score', ascending=False)
df7_shap.head()
# Out:
#                SHAP_score
# Area(Marla)      0.456495
# Main Location    0.293574
# Bedroom(s)       0.039037
# Bath(s)          0.037939
# Property era     0.019363

# %% [markdown]
# ### 8. XGBoost

# %%
from xgboost import XGBRegressor

clf = XGBRegressor(max_depth=2)
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9327821731567383
# Mean absolute error 1.4384479522705078

# %%
# Importances

df8_xgb = pd.DataFrame(data=rfe_clf.estimator_.feature_importances_,columns=['XGB Importance'],index=rfe_clf.feature_names_in_).sort_values(by='XGB Importance',ascending=False)
df8_xgb.head()
# Out:
#                XGB Importance
# Area(Marla)          0.664224
# Main Location        0.270798
# Bath(s)              0.022438
# Bedroom(s)           0.022373
# Property era         0.004474

# %%
# Concatenating all feature importance dataframes
final_feature_df = pd.concat((df1_rf,df2_gb,df3_pm,df4_lasso,df5_linear_reg,df6_rfe,df7_shap,df8_xgb),axis=1)
final_feature_df
# Out:
#                   RF Importance  Gb Importance  PM Importance  \
# Area(Marla)            0.664224       0.629900       0.681797
# Main Location          0.270798       0.322424       0.498540
# Bath(s)                0.022438       0.020133       0.016502
# Bedroom(s)             0.022373       0.022478       0.021353
# Property era           0.004474       0.002264       0.003788
# Storey Unit            0.003382       0.000837       0.000359
# Kitchens               0.002082       0.000199       0.000469
# luxury_type            0.002008       0.000039       0.000327
# IsPrimeLoc             0.001863       0.000228       0.000037
# CornerHouse            0.001676       0.000436       0.001368
# Store Rooms            0.001448       0.000311       0.000279
# Servant Quarters       0.001316       0.000091       0.000236
# WaterBore              0.001114       0.000394       0.000302
# SolarInstalled         0.000805       0.000265       0.000335
#
#                   Lasso Importance  LR Importance  RFE Importance  SHAP_score  \
# Area(Marla)               0.621469       0.627879        0.664224    0.456495
# Main Location             0.038631       0.038436        0.270798    0.293574
# Bath(s)                   0.014748       0.013466        0.022438    0.037939
# Bedroom(s)                0.083300       0.082149        0.022373    0.039037
# Property era              0.023351       0.024382        0.004474    0.019363
# Storey Unit               0.042232       0.046984        0.003382    0.004709
# Kitchens                  0.049358       0.053954        0.002082    0.004063
# luxury_type              -0.053377      -0.060652        0.002008    0.003690
# IsPrimeLoc                0.044087       0.049077        0.001863    0.004241
# CornerHouse               0.055212       0.065447        0.001676    0.005319
# Store Rooms              -0.015286      -0.027923        0.001448    0.002973
# Servant Quarters          0.013469       0.021780        0.001316    0.003306
# WaterBore                 0.050384       0.058082        0.001114    0.002319
# SolarInstalled            0.041383       0.064420        0.000805    0.002499
#
#                   XGB Importance
# Area(Marla)             0.664224
# Main Location           0.270798
# Bath(s)                 0.022438
# Bedroom(s)              0.022373
# Property era            0.004474
# Storey Unit             0.003382
# Kitchens                0.002082
# luxury_type             0.002008
# IsPrimeLoc              0.001863
# CornerHouse             0.001676
# Store Rooms             0.001448
# Servant Quarters        0.001316
# WaterBore               0.001114
# SolarInstalled          0.000805

# %%
final_feature_df.abs().sum(axis=0)
# Out:
# RF Importance       1.000000
# Gb Importance       1.000000
# PM Importance       1.225692
# Lasso Importance    1.146287
# LR Importance       1.234630
# RFE Importance      1.000000
# SHAP_score          0.879528
# XGB Importance      1.000000
# dtype: float64

# %%
# Normalize the score
normalized_features_df = final_feature_df.divide(final_feature_df.abs().sum(axis=0),axis=1)

# %%
normalized_features_df.sum(axis=1).sort_values(ascending=False)
# Out:
# Area(Marla)         4.748566
# Main Location       1.940180
# Bedroom(s)          0.290608
# Bath(s)             0.167820
# CornerHouse         0.113803
# Kitchens            0.098207
# WaterBore           0.097617
# SolarInstalled      0.094072
# Storey Unit         0.091527
# IsPrimeLoc          0.088878
# Property era        0.080911
# Servant Quarters    0.037383
# Store Rooms        -0.027690
# luxury_type        -0.085164
# dtype: float64

# %% [markdown]
# Removing `'Property era_Future', 'Store Rooms', 'Property era_Established' ,'Property era_Modern Era','Servant Quarters','luxury_type'`
#
# and evaluate the results again

# %%
# Before

# %%
from xgboost import XGBRegressor

clf = XGBRegressor(max_depth=2)
clf.fit(X_train_transformed,y_train_log)
y_pred = clf.predict(X_test_transformed)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9327821731567383
# Mean absolute error 1.4384479522705078

# %%
X_train_transformed_removed = X_train_transformed.drop(columns=['luxury_type'])

# %%
X_test_transformed_removed = X_test_transformed.drop(columns=['luxury_type',])

# %%
# After
from xgboost import XGBRegressor

clf = XGBRegressor(max_depth=2)
clf.fit(X_train_transformed_removed,y_train_log)
y_pred = clf.predict(X_test_transformed_removed)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9327259659767151
# Mean absolute error 1.4410243034362793

# %%
# The results are improved a bit and our features are reduced also

# Saving the new X_train and X_test

# %%
X_train_transformed_removed.to_csv('X_train_houses.csv')
X_test_transformed_removed.to_csv('X_test_houses.csv')

y_test.to_csv('y_test_houses.csv')
y_train.to_csv('y_train_houses.csv')
