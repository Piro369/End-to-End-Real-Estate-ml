# %% [markdown]
# # Outline
#
# - Perform Optuna with Model selection
# - Then choose a good model and then do hyper parameter tunning with it
# - Make a pickle file for pipeline (used in the Feature Selection) and for Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv('../Feature Selection/X_train_flats_test.csv',index_col=0,)
X_test = pd.read_csv('../Feature Selection/X_test_flats_test.csv',index_col=0)
y_train = pd.read_csv('../Feature Selection/y_train_flats.csv',index_col=0)
y_test = pd.read_csv('../Feature Selection/y_test_flats.csv',index_col=0)

# %%
X_train.head()
# Out:
#       Main Location  Building  Area(Marla)  Bath(s)  Bedroom(s)  \
# 6148       0.835680  0.835680     0.693147      1.0         1.0
# 4031       0.682126  0.688180     1.098612      1.0         1.0
# 1222       0.788549  0.800230     1.609438      3.0         3.0
# 1783       0.756197  0.800029     1.945910      2.0         2.0
# 1550       0.746192  0.746192     1.386294      2.0         2.0
#
#       Servant Quarters  Kitchens  Parking Spaces  Property era  Floor Level  \
# 6148               1.0       1.0             1.0             3            2
# 4031               0.0       1.0             1.0             4            2
# 1222               1.0       1.0             1.0             3            2
# 1783               1.0       1.0             1.0             3            2
# 1550               1.0       1.0             1.0             3            2
#
#       Building Type  Elevator Capacity
# 6148              3                  1
# 4031              2                  1
# 1222              1                  1
# 1783              1                  3
# 1550              3                  1

# %%
X_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1106 entries, 6148 to 4348
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Main Location      1106 non-null   float64
#  1   Building           1106 non-null   float64
#  2   Area(Marla)        1106 non-null   float64
#  3   Bath(s)            1106 non-null   float64
#  4   Bedroom(s)         1106 non-null   float64
#  5   Servant Quarters   1106 non-null   float64
#  6   Kitchens           1106 non-null   float64
#  7   Parking Spaces     1106 non-null   float64
#  8   Property era       1106 non-null   int64
#  9   Floor Level        1106 non-null   int64
#  10  Building Type      1106 non-null   int64
#  11  Elevator Capacity  1106 non-null   int64
# dtypes: float64(8), int64(4)
# memory usage: 112.3 KB

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
y_train_log = np.log1p(y_train)

# %% [markdown]
# With y_train log transformed

# %%
clf = RandomForestRegressor(random_state=42)
clf.fit(X_train,y_train_log)
y_pred = clf.predict(X_test)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
y_pred = np.expm1(y_pred)
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.9006921400490747
# Mean absolute error 0.4132241458925684

# %% [markdown]
# Without y_train log transformed

# %%
clf = RandomForestRegressor(random_state=42)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
# Out:
# C:\Users\Wajih\anaconda3\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
print('r2 Score',r2_score(y_test,y_pred))
print('Mean absolute error',mean_absolute_error(y_test,y_pred))
# Out:
# r2 Score 0.8991224527166608
# Mean absolute error 0.4243942336524204

# %% [markdown]
# With y_train as log_transformed, it is giving good results

# %% [markdown]
# ## Optuna (for Model Selection)

# %%
from sklearn.model_selection import StratifiedKFold

# %%
import optuna
from optuna.visualization import plot_contour,plot_optimization_history,plot_parallel_coordinate,plot_param_importances

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import KFold, cross_validate

def Multiple_Ml_Objective(trial):

    # 1. Select the Model
    regressor_name = trial.suggest_categorical('regressor', ['Random Forest', 'Extra Trees','Xgboost'])

    # 2. Random Forest Branch
    if regressor_name == 'Random Forest':
        n_estimators = trial.suggest_int('rf_n_estimators', 100, 800, step=100) 
        criterion = trial.suggest_categorical('rf_criterion', ['squared_error', 'absolute_error'])
        
        max_depth_option = trial.suggest_categorical('rf_max_depth_option', ['auto', 'fixed'])
        max_depth = None if max_depth_option == 'auto' else trial.suggest_int('rf_max_depth', 10, 150, step=10)
        
        min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 30)
        min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 20)
        max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', 1.0, 0.3, 0.5, 0.75])
        max_samples = trial.suggest_float('rf_max_samples', 0.4, 0.95)
        
        # NEW: Tree Pruning & Size Control
        max_leaf_nodes = trial.suggest_int('rf_max_leaf_nodes', 50, 2000, log=True)
        ccp_alpha = trial.suggest_float('rf_ccp_alpha', 0.0, 0.1)

        model = RandomForestRegressor(
            n_estimators=n_estimators, 
            criterion=criterion, 
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            max_features=max_features, 
            max_samples=max_samples,
            max_leaf_nodes=max_leaf_nodes,
            ccp_alpha=ccp_alpha,
            n_jobs=-1,
            random_state=42
        )

    # 3. Extra Trees Branch
    elif regressor_name == 'Extra Trees':
        n_estimators = trial.suggest_int('et_n_estimators', 100, 800, step=100)
        criterion = trial.suggest_categorical('et_criterion', ['squared_error', 'absolute_error'])
        
        max_depth_option = trial.suggest_categorical('et_max_depth_option', ['auto', 'fixed'])
        max_depth = None if max_depth_option == 'auto' else trial.suggest_int('et_max_depth', 10, 150, step=10)
        
        min_samples_split = trial.suggest_int('et_min_samples_split', 2, 30)
        min_samples_leaf = trial.suggest_int('et_min_samples_leaf', 1, 20)
        max_features = trial.suggest_categorical('et_max_features', ['sqrt', 'log2', 1.0, 0.3, 0.5, 0.75])
        
        # NEW: Bootstrapping & Pruning 
        bootstrap = trial.suggest_categorical('et_bootstrap', [True, False])
        max_samples = trial.suggest_float('et_max_samples', 0.4, 0.95) if bootstrap else None
        max_leaf_nodes = trial.suggest_int('et_max_leaf_nodes', 50, 2000, log=True)
        ccp_alpha = trial.suggest_float('et_ccp_alpha', 0.0, 0.1)

        model = ExtraTreesRegressor(
            n_estimators=n_estimators, 
            criterion=criterion, 
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            max_features=max_features, 
            bootstrap=bootstrap,
            max_samples=max_samples,
            max_leaf_nodes=max_leaf_nodes,
            ccp_alpha=ccp_alpha,
            n_jobs=-1,
            random_state=42
        )

    # 4. XGBoost Branch
    elif regressor_name == 'Xgboost':
        n_estimators = trial.suggest_int('xgb_n_estimators', 200, 1000, step=100)
        max_depth = trial.suggest_int('xgb_max_depth', 3, 20)
        learning_rate = trial.suggest_float('xgb_learning_rate', 1e-4, 0.3, log=True)
        subsample = trial.suggest_float('xgb_subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('xgb_colsample_bytree', 0.4, 1.0)
        gamma = trial.suggest_float('xgb_gamma', 0.0, 10.0)
        
        # NEW: L1/L2 Regularization and Node Splitting Control
        min_child_weight = trial.suggest_int('xgb_min_child_weight', 1, 20)
        reg_alpha = trial.suggest_float('xgb_reg_alpha', 1e-5, 10.0, log=True) # L1
        reg_lambda = trial.suggest_float('xgb_reg_lambda', 1e-5, 10.0, log=True) # L2
        colsample_bylevel = trial.suggest_float('xgb_colsample_bylevel', 0.4, 1.0)

        model = XGBRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            colsample_bylevel=colsample_bylevel,
            gamma=gamma,
            min_child_weight=min_child_weight,
            reg_alpha=reg_alpha,
            reg_lambda=reg_lambda,
            n_jobs=-1,
            random_state=42
        )

    # 5. Cross Validation
    cv_strategy = KFold(n_splits=5, shuffle=True, random_state=42)

    cv_results = cross_validate(
        model,
        X_train,
        y_train['Price(Cr)'], # Note: Ensure you use y_train_log here if you want to keep optimizing in log-space!
        scoring='neg_mean_absolute_error',
        cv=cv_strategy,
        return_train_score=True,
        n_jobs=-1 # Speeds up cross-validation
    )

    # 6. Extract Metrics
    train_score_mean = cv_results['train_score'].mean()
    val_score_mean = cv_results['test_score'].mean()

    # 7. Log Custom Attributes to Optuna Dashboard
    trial.set_user_attr('train_score_mean', train_score_mean)
    trial.set_user_attr('train_score_std', cv_results['train_score'].std())
    trial.set_user_attr('test_score_std', cv_results['test_score'].std())
    trial.set_user_attr('overfitting_gap', train_score_mean - val_score_mean)

    return (-val_score_mean)

# %%
multiple_ml_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(),study_name="Model_Selection")
# Out:
# [I 2026-05-17 20:51:28,268] A new study created in memory with name: Model_Selection

# %%
multiple_ml_study.optimize(Multiple_Ml_Objective,n_trials=10)
# Out:
# [I 2026-05-17 20:53:29,204] Trial 10 finished with value: 0.41733295384763 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 500, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.06856699118677426, 'xgb_subsample': 0.9099124808955465, 'xgb_colsample_bytree': 0.9131231037836564, 'xgb_gamma': 0.5938431745250075, 'xgb_min_child_weight': 9, 'xgb_reg_alpha': 8.397059236023666e-05, 'xgb_reg_lambda': 0.10514669293263224, 'xgb_colsample_bylevel': 0.6932261890581403}. Best is trial 10 with value: 0.41733295384763.
# [I 2026-05-17 20:53:30,064] Trial 11 finished with value: 0.423755659457702 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 500, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.0822270507466308, 'xgb_subsample': 0.9250089752124481, 'xgb_colsample_bytree': 0.9622834231512036, 'xgb_gamma': 0.09113710131586661, 'xgb_min_child_weight': 8, 'xgb_reg_alpha': 0.00010592121812714077, 'xgb_reg_lambda': 0.12687787506732112, 'xgb_colsample_bylevel': 0.6928180364421879}. Best is trial 10 with value: 0.41733295384763.
# [I 2026-05-17 20:53:30,847] Trial 12 finished with value: 0.42798576040272296 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 500, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.08695662498327393, 'xgb_subsample': 0.9354768015436434, 'xgb_colsample_bytree': 0.9767803619865475, 'xgb_gamma': 0.1513365314177611, 'xgb_min_child_weight': 9, 'xgb_reg_alpha': 8.631701821946323e-05, 'xgb_reg_lambda': 0.12691854254157206, 'xgb_colsample_bylevel': 0.6722369831990382}. Best is trial 10 with value: 0.41733295384763.
# [I 2026-05-17 20:53:31,991] Trial 13 finished with value: 0.416927919088938 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 500, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.05383989796495649, 'xgb_subsample': 0.9277590294028925, 'xgb_colsample_bytree': 0.9453794716806524, 'xgb_gamma': 0.07559371322157382, 'xgb_min_child_weight': 8, 'xgb_reg_alpha': 0.00011164520871477504, 'xgb_reg_lambda': 0.1096119469100437, 'xgb_colsample_bylevel': 0.7044309764116224}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:33,298] Trial 14 finished with value: 0.44168804979919696 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 600, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.011662915567631401, 'xgb_subsample': 0.7893793940832782, 'xgb_colsample_bytree': 0.7482684284001768, 'xgb_gamma': 2.821616725877317, 'xgb_min_child_weight': 4, 'xgb_reg_alpha': 6.362670001307508e-05, 'xgb_reg_lambda': 0.0004624721038928275, 'xgb_colsample_bylevel': 0.9152363871654635}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:35,043] Trial 15 finished with value: 1.7682887438406099 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 1000, 'xgb_max_depth': 19, 'xgb_learning_rate': 0.00023819513472465712, 'xgb_subsample': 0.9890155068653769, 'xgb_colsample_bytree': 0.756524770065455, 'xgb_gamma': 9.653977685122706, 'xgb_min_child_weight': 17, 'xgb_reg_alpha': 0.1589190465236189, 'xgb_reg_lambda': 1.4969047133365083, 'xgb_colsample_bylevel': 0.4089411425708593}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:35,399] Trial 16 finished with value: 0.5001131364951689 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 200, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.20724945101160042, 'xgb_subsample': 0.5416514472179068, 'xgb_colsample_bytree': 0.41174753318014234, 'xgb_gamma': 3.762372562118996, 'xgb_min_child_weight': 14, 'xgb_reg_alpha': 0.0032863943828250653, 'xgb_reg_lambda': 0.005008302754425196, 'xgb_colsample_bylevel': 0.7633537172647263}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:36,187] Trial 17 finished with value: 0.5050191699921498 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 300, 'xgb_max_depth': 11, 'xgb_learning_rate': 0.010312061480610164, 'xgb_subsample': 0.7915846474554055, 'xgb_colsample_bytree': 0.8761718004281384, 'xgb_gamma': 1.793877883512555, 'xgb_min_child_weight': 1, 'xgb_reg_alpha': 1.0174973540844067e-05, 'xgb_reg_lambda': 8.632392513314286, 'xgb_colsample_bylevel': 0.5682393102352942}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:37,094] Trial 18 finished with value: 0.4626706899477752 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 700, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0281760853653132, 'xgb_subsample': 0.8469446818031945, 'xgb_colsample_bytree': 0.8613699610383331, 'xgb_gamma': 6.83560924217768, 'xgb_min_child_weight': 11, 'xgb_reg_alpha': 0.0037393930230745316, 'xgb_reg_lambda': 0.036151405682847935, 'xgb_colsample_bylevel': 0.8375233715102129}. Best is trial 13 with value: 0.416927919088938.
# [I 2026-05-17 20:53:38,549] Trial 19 finished with value: 1.4472770308422986 and parameters: {'regressor': 'Xgboost', 'xgb_n_estimators': 800, 'xgb_max_depth': 17, 'xgb_learning_rate': 0.0006945899175905613, 'xgb_subsample': 0.6405978398706745, 'xgb_colsample_bytree': 0.567961249754792, 'xgb_gamma': 5.325970575533284, 'xgb_min_child_weight': 6, 'xgb_reg_alpha': 4.396023750357377, 'xgb_reg_lambda': 3.81059662241855e-05, 'xgb_colsample_bylevel': 0.591389139896169}. Best is trial 13 with value: 0.416927919088938.

# %%
df = multiple_ml_study.trials_dataframe()

# %%
df.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.549786 2026-05-17 20:51:30.147475 2026-05-17 20:51:42.958615
# 1       1  0.763402 2026-05-17 20:51:42.960956 2026-05-17 20:51:44.333538
# 2       2  0.617311 2026-05-17 20:51:44.335776 2026-05-17 20:51:49.189814
# 3       3  0.616689 2026-05-17 20:51:49.194674 2026-05-17 20:52:04.435647
# 4       4  0.636873 2026-05-17 20:52:04.442343 2026-05-17 20:52:10.234611
#
#                 duration params_et_bootstrap  params_et_ccp_alpha  \
# 0 0 days 00:00:12.811140               False             0.005141
# 1 0 days 00:00:01.372582               False             0.036720
# 2 0 days 00:00:04.854038                 NaN                  NaN
# 3 0 days 00:00:15.240973                 NaN                  NaN
# 4 0 days 00:00:05.792268                 NaN                  NaN
#
#   params_et_criterion  params_et_max_depth params_et_max_depth_option  ...  \
# 0       squared_error                 50.0                      fixed  ...
# 1       squared_error                 90.0                      fixed  ...
# 2                 NaN                  NaN                        NaN  ...
# 3                 NaN                  NaN                        NaN  ...
# 4                 NaN                  NaN                        NaN  ...
#
#   params_xgb_min_child_weight  params_xgb_n_estimators  params_xgb_reg_alpha  \
# 0                         NaN                      NaN                   NaN
# 1                         NaN                      NaN                   NaN
# 2                         NaN                      NaN                   NaN
# 3                         NaN                      NaN                   NaN
# 4                         NaN                      NaN                   NaN
#
#    params_xgb_reg_lambda  params_xgb_subsample  user_attrs_overfitting_gap  \
# 0                    NaN                   NaN                    0.047784
# 1                    NaN                   NaN                    0.023716
# 2                    NaN                   NaN                    0.027384
# 3                    NaN                   NaN                    0.054860
# 4                    NaN                   NaN                    0.035573
#
#   user_attrs_test_score_std  user_attrs_train_score_mean  \
# 0                  0.058782                    -0.502002
# 1                  0.085479                    -0.739686
# 2                  0.076468                    -0.589927
# 3                  0.055427                    -0.561829
# 4                  0.063122                    -0.601300
#
#   user_attrs_train_score_std     state
# 0                   0.014568  COMPLETE
# 1                   0.016713  COMPLETE
# 2                   0.018506  COMPLETE
# 3                   0.025684  COMPLETE
# 4                   0.009380  COMPLETE
#
# [5 rows x 42 columns]

# %%
df.groupby('params_regressor')['value'].mean()
# Out:
# params_regressor
# Extra Trees      0.684212
# Random Forest    0.670483
# Xgboost          0.681106
# Name: value, dtype: float64

# %%
df.groupby('params_regressor')['user_attrs_overfitting_gap'].mean()
# Out:
# params_regressor
# Extra Trees      0.026158
# Random Forest    0.035729
# Xgboost          0.110751
# Name: user_attrs_overfitting_gap, dtype: float64

# %%
df.sort_values(by=['value','user_attrs_overfitting_gap'],ascending=[True,True]).head()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 13      13  0.416928 2026-05-17 20:53:30.848862 2026-05-17 20:53:31.991271
# 10      10  0.417333 2026-05-17 20:53:28.333201 2026-05-17 20:53:29.204007
# 11      11  0.423756 2026-05-17 20:53:29.205865 2026-05-17 20:53:30.064797
# 12      12  0.427986 2026-05-17 20:53:30.066414 2026-05-17 20:53:30.847033
# 14      14  0.441688 2026-05-17 20:53:31.996097 2026-05-17 20:53:33.298227
#
#                  duration params_et_bootstrap  params_et_ccp_alpha  \
# 13 0 days 00:00:01.142409                 NaN                  NaN
# 10 0 days 00:00:00.870806                 NaN                  NaN
# 11 0 days 00:00:00.858932                 NaN                  NaN
# 12 0 days 00:00:00.780619                 NaN                  NaN
# 14 0 days 00:00:01.302130                 NaN                  NaN
#
#    params_et_criterion  params_et_max_depth params_et_max_depth_option  ...  \
# 13                 NaN                  NaN                        NaN  ...
# 10                 NaN                  NaN                        NaN  ...
# 11                 NaN                  NaN                        NaN  ...
# 12                 NaN                  NaN                        NaN  ...
# 14                 NaN                  NaN                        NaN  ...
#
#    params_xgb_min_child_weight  params_xgb_n_estimators  params_xgb_reg_alpha  \
# 13                         8.0                    500.0              0.000112
# 10                         9.0                    500.0              0.000084
# 11                         8.0                    500.0              0.000106
# 12                         9.0                    500.0              0.000086
# 14                         4.0                    600.0              0.000064
#
#     params_xgb_reg_lambda  params_xgb_subsample  user_attrs_overfitting_gap  \
# 13               0.109612              0.927759                    0.210559
# 10               0.105147              0.909912                    0.139922
# 11               0.126878              0.925009                    0.220659
# 12               0.126919              0.935477                    0.200948
# 14               0.000462              0.789379                    0.118339
#
#    user_attrs_test_score_std  user_attrs_train_score_mean  \
# 13                  0.042094                    -0.206368
# 10                  0.040928                    -0.277411
# 11                  0.043799                    -0.203097
# 12                  0.041455                    -0.227038
# 14                  0.049756                    -0.323349
#
#    user_attrs_train_score_std     state
# 13                   0.003874  COMPLETE
# 10                   0.004713  COMPLETE
# 11                   0.005491  COMPLETE
# 12                   0.003940  COMPLETE
# 14                   0.004012  COMPLETE
#
# [5 rows x 42 columns]

# %%
# Extract the best overall score (lowest MAE)
print("Best Validation MAE :", multiple_ml_study.best_value)

# Extract the parameters that achieved this score
best_params = multiple_ml_study.best_params
print("\nBest Hyperparameters Found:")
for key, value in best_params.items():
    print(f"  {key}: {value}")

# Extract the custom attributes we logged for that specific trial
best_trial_attrs = multiple_ml_study.best_trial.user_attrs
print("\nBest Trial Diagnostics:")
print(f"  Training Score Mean: {best_trial_attrs['train_score_mean']}")
print(f"  Overfitting Gap: {best_trial_attrs['overfitting_gap']}")
# Out:
# Best Validation MAE : 0.416927919088938
#
# Best Hyperparameters Found:
#   regressor: Xgboost
#   xgb_n_estimators: 500
#   xgb_max_depth: 5
#   xgb_learning_rate: 0.05383989796495649
#   xgb_subsample: 0.9277590294028925
#   xgb_colsample_bytree: 0.9453794716806524
#   xgb_gamma: 0.07559371322157382
#   xgb_min_child_weight: 8
#   xgb_reg_alpha: 0.00011164520871477504
#   xgb_reg_lambda: 0.1096119469100437
#   xgb_colsample_bylevel: 0.7044309764116224
#
# Best Trial Diagnostics:
#   Training Score Mean: -0.2063684768810717
#   Overfitting Gap: 0.2105594422078663

# %% [markdown]
# <br>
#
# *Xgboost is giving better results so we will choose it*

# %% [markdown]
# ## Objective Function for XGboost only

# %%
from sklearn.model_selection import KFold

# %%
def XGBoost_Anti_Overfit_Objective(trial):
    trial.suggest_categorical('regressor', ['Xgboost'])

    # 1. Heavily constrain tree complexity
    # We drop max depth significantly. XGBoost rarely needs to go past 8 or 10.
    max_depth = trial.suggest_int('xgb_max_depth', 3, 8)
    
    # We switch back to 'depthwise' to prevent 'lossguide' from making runaway asymmetric branches
    grow_policy = 'depthwise'
    
    # 2. Lower estimators, slightly higher learning rate for stability
    n_estimators = trial.suggest_int('xgb_n_estimators', 300, 700, step=100)
    learning_rate = trial.suggest_float('xgb_learning_rate', 0.02, 0.1)

    # 3. Force Aggressive Subsampling (Feature & Row Dropping)
    # This forces trees to look at different columns and rows, preventing memorization
    subsample = trial.suggest_float('xgb_subsample', 0.60, 0.80)
    colsample_bytree = trial.suggest_float('xgb_colsample_bytree', 0.50, 0.75)
    colsample_bylevel = trial.suggest_float('xgb_colsample_bylevel', 0.50, 0.75)

    # 4. Drastically raise min_child_weight
    # Higher numbers mean a branch MUST contain a significant chunk of properties to exist
    min_child_weight = trial.suggest_int('xgb_min_child_weight', 15, 45)

    # 5. Crank up Regularization Penalties
    gamma = trial.suggest_float('xgb_gamma', 1.0, 8.0)
    reg_alpha = trial.suggest_float('xgb_reg_alpha', 0.01, 10.0, log=True)   # Stronger L1
    reg_lambda = trial.suggest_float('xgb_reg_lambda', 0.1, 20.0, log=True)  # Stronger L2

    model = XGBRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        colsample_bylevel=colsample_bylevel,
        gamma=gamma,
        min_child_weight=min_child_weight,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda,
        grow_policy=grow_policy,
        tree_method='hist',
        n_jobs=-1,
        random_state=42
    )

    # 6. Cross Validation Setup (Unchanged)
    cv_strategy = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_results = cross_validate(
        model,
        X_train, # Make sure this is your transformed data if you have categorical pipelines!
        y_train['Price(Cr)'],
        scoring='neg_mean_absolute_error',
        cv=cv_strategy,
        return_train_score=True,
        n_jobs=-1
    )

    # Convert scikit-learn's negative outputs into absolute positive numbers
    train_mae = abs(cv_results['train_score'].mean())
    val_mae = abs(cv_results['test_score'].mean())

    # 7. Log clear, positive attributes to Optuna Dashboard
    trial.set_user_attr('train_score_mean', train_mae)                     # Will show 0.102
    trial.set_user_attr('overfitting_gap', val_mae - train_mae)            # Will show 0.268

    # 8. Return positive metric to MINIMIZE
    return val_mae                                                         # Optuna will minimize 0.370 down towards 0

# %%
# Create your fresh study
study = optuna.create_study(direction='minimize', study_name="XGBoost_Final_Production")

xgb_trial_154 = {
    'regressor': 'Xgboost', 
    'xgb_n_estimators': 400, 
    'xgb_max_depth': 4, 
    'xgb_learning_rate': 0.055641, 
    'xgb_subsample': 0.792755, 
    'xgb_colsample_bytree': 0.625803, 
    'xgb_colsample_bylevel': 0.578621, 
    'xgb_gamma': 3.183181, 
    'xgb_min_child_weight': 23, 
    'xgb_reg_alpha': 0.902825, 
    'xgb_reg_lambda': 6.352308
}
study.enqueue_trial(xgb_trial_154)

# Format Trial 4 perfectly for the encoder
gold_star_trial = {
    'regressor': 'Xgboost',
    'xgb_n_estimators': 700,
    'xgb_max_depth': 11,
    'xgb_learning_rate': 0.023514,
    'xgb_subsample': 0.525535,
    'xgb_colsample_bytree': 0.675238,
    'xgb_colsample_bylevel': 0.992857,
    'xgb_gamma': 6.402284,
    'xgb_min_child_weight': 6,
    'xgb_reg_alpha': 0.063855,
    'xgb_reg_lambda': 0.000568,
    'xgb_grow_policy': 'lossguide',
    'xgb_max_leaves': 53
}

# Inject it into the study's memory
study.enqueue_trial(gold_star_trial)
# Out:
# [I 2026-05-17 20:55:27,976] A new study created in memory with name: XGBoost_Final_Production

# %%
study.optimize(XGBoost_Anti_Overfit_Objective,n_trials=50)
# Out:
# [I 2026-05-17 21:04:07,008] Trial 200 finished with value: 0.4524613719560501 and parameters: {'regressor': 'Xgboost', 'xgb_max_depth': 8, 'xgb_n_estimators': 500, 'xgb_learning_rate': 0.03937941736487778, 'xgb_subsample': 0.6084958651352514, 'xgb_colsample_bytree': 0.7116913690814622, 'xgb_colsample_bylevel': 0.6317493163113497, 'xgb_min_child_weight': 16, 'xgb_gamma': 1.121018888499972, 'xgb_reg_alpha': 0.3682183431032674, 'xgb_reg_lambda': 4.755086233842394}. Best is trial 176 with value: 0.44936285345395055.
# [I 2026-05-17 21:04:07,825] Trial 201 finished with value: 0.454741929946987 and parameters: {'regressor': 'Xgboost', 'xgb_max_depth': 8, 'xgb_n_estimators': 500, 'xgb_learning_rate': 0
 'xgb_min_child_weight': 15, 'xgb_gamma': 1.2545832246528108, 'xgb_reg_alpha': 0.2881824109652263, 'xgb_reg_lambda': 4.1062222067222205}. Best is trial 233 with value: 0.449082847818249.
# [I 2026-05-17 21:04:48,686] Trial 249 finished with value: 0.4576759471013257 and parameters: {'regressor': 'Xgboost', 'xgb_max_depth': 8, 'xgb_n_estimators': 500, 'xgb_learning_rate': 0.0350689354714295, 'xgb_subsample': 0.6173601271850926, 'xgb_colsample_bytree': 0.707609654158666, 'xgb_colsample_bylevel': 0.6437362254386839, 'xgb_min_child_weight': 15, 'xgb_gamma': 1.4891289348103391, 'xgb_reg_alpha': 0.3598077731386779, 'xgb_reg_lambda': 3.5628267445016104}. Best is trial 233 with value: 0.449082847818249.

# %%
df = study.trials_dataframe()
df.sort_values(by=['value','user_attrs_overfitting_gap'],ascending=[True,True]).head(3)
# Out:
#      number     value             datetime_start          datetime_complete  \
# 176     176  0.449363 2026-05-17 21:02:10.220652 2026-05-17 21:02:11.021476
# 165     165  0.450294 2026-05-17 21:02:00.450674 2026-05-17 21:02:01.286521
# 77       77  0.450741 2026-05-17 20:58:30.412814 2026-05-17 20:58:31.343368
#
#                   duration params_regressor  params_xgb_colsample_bylevel  \
# 176 0 days 00:00:00.800824          Xgboost                      0.626050
# 165 0 days 00:00:00.835847          Xgboost                      0.626427
# 77  0 days 00:00:00.930554          Xgboost                      0.606357
#
#      params_xgb_colsample_bytree  params_xgb_gamma  params_xgb_learning_rate  \
# 176                     0.727135          1.168102                  0.046708
# 165                     0.692233          1.250993                  0.043216
# 77                      0.644307          1.164031                  0.059052
#
#      params_xgb_max_depth  params_xgb_min_child_weight  \
# 176                     8                           15
# 165                     8                           15
# 77                      8                           16
#
#      params_xgb_n_estimators  params_xgb_reg_alpha  params_xgb_reg_lambda  \
# 176                      500              0.636192               2.859675
# 165                      500              0.319855               5.051309
# 77                       700              0.239721               1.827176
#
#      params_xgb_subsample  user_attrs_overfitting_gap  \
# 176              0.614870                    0.083658
# 165              0.627375                    0.081973
# 77               0.784131                    0.098108
#
#      user_attrs_train_score_mean system_attrs_fixed_params     state
# 176                     0.365705                       NaN  COMPLETE
# 165                     0.368321                       NaN  COMPLETE
# 77                      0.352633                       NaN  COMPLETE

# %%
study.best_params
# Out:
# {'regressor': 'Xgboost',
#  'xgb_max_depth': 8,
#  'xgb_n_estimators': 500,
#  'xgb_learning_rate': 0.04670825306742295,
#  'xgb_subsample': 0.6148695020533722,
#  'xgb_colsample_bytree': 0.7271345290115521,
#  'xgb_colsample_bylevel': 0.6260498326514382,
#  'xgb_min_child_weight': 15,
#  'xgb_gamma': 1.1681022733437558,
#  'xgb_reg_alpha': 0.6361923867055418,
#  'xgb_reg_lambda': 2.8596747139490795}

# %%
study.best_trials
# Out:
# [FrozenTrial(number=176, state=1, values=[0.44936285345395055], datetime_start=datetime.datetime(2026, 5, 17, 21, 2, 10, 220652), datetime_complete=datetime.datetime(2026, 5, 17, 21, 2, 11, 21476), params={'regressor': 'Xgboost', 'xgb_max_depth': 8, 'xgb_n_estimators': 500, 'xgb_learning_rate': 0.04670825306742295, 'xgb_subsample': 0.6148695020533722, 'xgb_colsample_bytree': 0.7271345290115521, 'xgb_colsample_bylevel': 0.6260498326514382, 'xgb_min_child_weight': 15, 'xgb_gamma': 1.1681022733437558, 'xgb_reg_alpha': 0.6361923867055418, 'xgb_reg_lambda': 2.8596747139490795}, user_attrs={'train_score_mean': np.float64(0.3657045165668184), 'overfitting_gap': np.float64(0.08365833688713215)}, system_attrs={}, intermediate_values={}, distributions={'regressor': CategoricalDistribution(choices=('Xgboost',)), 'xgb_max_depth': IntDistribution(high=8, log=False, low=3, step=1), 'xgb_n_estimators': IntDistribution(high=700, log=False, low=300, step=100), 'xgb_learning_rate': FloatDistribution(high=0.1, log=False, low=0.02, step=None), 'xgb_subsample': FloatDistribution(high=0.8, log=False, low=0.6, step=None), 'xgb_colsample_bytree': FloatDistribution(high=0.75, log=False, low=0.5, step=None), 'xgb_colsample_bylevel': FloatDistribution(high=0.75, log=False, low=0.5, step=None), 'xgb_min_child_weight': IntDistribution(high=45, log=False, low=15, step=1), 'xgb_gamma': FloatDistribution(high=8.0, log=False, low=1.0, step=None), 'xgb_reg_alpha': FloatDistribution(high=10.0, log=True, low=0.01, step=None), 'xgb_reg_lambda': FloatDistribution(high=20.0, log=True, low=0.1, step=None)}, trial_id=176, value=None)]

# %%
print("Best value: ",study.best_value)
# Out:
# Best value:  0.44936285345395055

# %%
params = study.best_params
params.pop('regressor')
# Out:
# 'Xgboost'

# %%
best_params = {}
for key,value in params.items():
    best_params[key[4:]] = value

# %%
best_params
# Out:
# {'max_depth': 8,
#  'n_estimators': 500,
#  'learning_rate': 0.04670825306742295,
#  'subsample': 0.6148695020533722,
#  'colsample_bytree': 0.7271345290115521,
#  'colsample_bylevel': 0.6260498326514382,
#  'min_child_weight': 15,
#  'gamma': 1.1681022733437558,
#  'reg_alpha': 0.6361923867055418,
#  'reg_lambda': 2.8596747139490795}

# %%
underfitted_best_params = {'max_depth': 8,
 'n_estimators': 700,
 'learning_rate': 0.03784249384284771,
 'subsample': 0.7836105782268438,
 'colsample_bytree': 0.7237677753352395,
 'colsample_bylevel': 0.5446839132083849,
 'min_child_weight': 15,
 'gamma': 1.359495501026701,
 'reg_alpha': 0.014393494799461814,
 'reg_lambda': 0.19305735637398955}

# %%
overfitted_params = {'n_estimators': 1000,
 'max_depth': 15,
 'learning_rate': 0.00505825958265549,
 'subsample': 0.8944998368111671,
 'colsample_bytree': 0.9305368372411382,
 'colsample_bylevel': 0.7407153424980754,
 'gamma': 0.021373237297058784,
 'min_child_weight': 4,
 'reg_alpha': 0.005116450915274579,
 'reg_lambda': 0.0007460273123214234,
 'grow_policy': 'lossguide',
 'max_leaves': 52}

# %%
# Training the best model with overfitted params

# %%
best_model = XGBRegressor(**best_params)
best_model.fit(X_train,y_train['Price(Cr)'])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=0.6260498326514382, colsample_bynode=None,
#              colsample_bytree=0.7271345290115521, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=1.1681022733437558, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.04670825306742295,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=15, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
y_pred = best_model.predict(X_test)
print('R2 Score ',r2_score(y_test,y_pred))
print('MAE ',mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score  0.8967318534851074
# MAE  0.4634043574333191

# %%
y_pred = best_model.predict(X_train)
print('R2 Score ',r2_score(y_train,y_pred))
print('MAE ',mean_absolute_error(y_train,y_pred))
# Out:
# R2 Score  0.9669373035430908
# MAE  0.35402533411979675

# %%
import pickle

# %%
with open('model_flats.pkl','wb') as file:
    pickle.dump(best_model,file)

# %%
# Pipeline from Feature Selction/

# %%
from sklearn.preprocessing import OneHotEncoder,FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from category_encoders import TargetEncoder
from sklearn import set_config

set_config(transform_output='pandas')

# %%
ohe_cols = ['Property era', 'Floor Level', 'Building Type', 'Elevator Capacity']

preprocessor = ColumnTransformer(
    transformers=[
        ('OHE', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), ohe_cols),
        
        ('TargetEncoding', TargetEncoder(smoothing=5, min_samples_leaf=2, handle_unknown='value'), ['Main Location', 'Building']),
        
        ('LogTransform', FunctionTransformer(np.log1p), ['Area(Marla)'])
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
)

# %%
X_train.columns
# Out:
# Index(['Main Location', 'Building', 'Area(Marla)', 'Bath(s)', 'Bedroom(s)',
#        'Servant Quarters', 'Kitchens', 'Parking Spaces', 'Property era',
#        'Floor Level', 'Building Type', 'Elevator Capacity'],
#       dtype='str')

# %%
import pickle

# %%
with open('model_flats.pkl','rb') as file:
    best_model = pickle.load(file)

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=0.7407153424980754, colsample_bynode=None,
#              colsample_bytree=0.9305368372411382, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.021373237297058784, grow_policy='lossguide',
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.00505825958265549, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=15, max_leaves=52,
#              min_child_weight=4, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
best_model.fit(X_train,y_train)
y_pred = best_model.predict(X_test)
print('R2 Score ',r2_score(y_test,y_pred))
print('MAE ',mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score  0.9059523940086365
# MAE  0.4135400950908661

# %%
y_pred = best_model.predict(X_train)
print('R2 Score ',r2_score(y_train,y_pred))
print('MAE ',mean_absolute_error(y_train,y_pred))
# Out:
# R2 Score  0.9921247363090515
# MAE  0.17938539385795593

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from category_encoders import TargetEncoder
from xgboost import XGBRegressor

# 1. Define the Custom Mapper Class
class CustomOrdinalMapper(BaseEstimator, TransformerMixin):
    def __init__(self, mappings):
        self.mappings = mappings
        
    def fit(self, X, y=None):
        # Nothing to mathematically "learn" here, so we just return self
        return self
        
    def transform(self, X):
        # Create a copy so we don't alter the original dataframe
        X_processed = X.copy()
        
        for col, mapping_dict in self.mappings.items():
            if col in X_processed.columns:
                # Map strings to numbers. If a completely new string appears (e.g. user types nonsense), fallback to 1
                X_processed[col] = X_processed[col].map(mapping_dict).fillna(1).astype(int)
                
        return X_processed

# %%
# 2. Store your manual mappings
all_mappings = {
    'Property era': {
        'Vintage': 1, 'Established': 2, 'Recently Built': 3, 
        'Modern Era': 4, 'Brand New (2025)': 5, 'Future': 6
    },
    'Floor Level': {
        'Lower Floors': 1, 'Ground/First Floor': 2, 'Mid-Level': 3, 'High-Rise': 4
    },
    'Building Type': {
        'Ground/Flat': 1, 'Lower Levels': 2, 'Mid Rise Core': 3, 
        'High Rise': 4, 'Skyscarper': 5
    },
    'Elevator Capacity': {
        'Single/None': 1, 'Dual Setup': 2, 'Multiple Bank': 3, 'High-Capacity': 4
    }
}

# 3. Define the ColumnTransformer for the remaining complex columns
preprocessor = ColumnTransformer(
    transformers=[
        # Target encode the high-cardinality text columns
        ('TargetEncoding', TargetEncoder(smoothing=20, min_samples_leaf=2, handle_unknown='value'), ['Main Location', 'Building']),
        
        # Mathematically smooth out the Area column
        ('LogTransform', FunctionTransformer(np.log1p), ['Area(Marla)'])
    ],
    # 'passthrough' tells it to ignore the columns we already mapped in Step 1, letting them flow directly to XGBoost
    remainder='passthrough', 
    verbose_feature_names_out=False
)

# %%
# 4. Initialize your optimized XGBoost Model (Paste your best parameters here)
best_model 

# 5. Build the Master Pipeline
production_pipeline = Pipeline([
    ('ordinal_maps', CustomOrdinalMapper(all_mappings)), # Step 1: Map text to integers
    ('preprocessor', preprocessor),                      # Step 2: Target Encode & Log Transform
    ('model', best_model)                                # Step 3: Predict using XGBoost
])

# 6. FIT the entire pipeline on RAW data
# This trains the TargetEncoder and the XGBoost model simultaneously
print("Training full pipeline...")
production_pipeline.fit(X_train, y_train['Price(Cr)']) 

# 7. SAVE the pipeline as a .pkl file using Joblib
file_name = 'pak_real_estate_pipeline.pkl'
joblib.dump(production_pipeline, file_name)
print(f"Success! Pipeline completely packaged and saved as {file_name}")
# Out:
# Training full pipeline...
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Success! Pipeline completely packaged and saved as pak_real_estate_pipeline.pkl

# %%
# --- THIS CODE LIVES ON YOUR WEB SERVER (e.g., app.py) ---

import joblib
import pandas as pd

# Load the brain (Only happens once when the server starts)
real_estate_ai = joblib.load('pak_real_estate_pipeline.pkl')

def get_valuation(user_form_data):
    # Convert the user's web form inputs directly into a DataFrame
    # Note: These are raw strings, exactly as they appear in the UI dropdowns!
    df_input = pd.DataFrame([user_form_data])
    
    # The pipeline handles ALL the mapping, encoding, and math automatically
    prediction = real_estate_ai.predict(df_input)
    
    return round(prediction[0], 2) # Returns clean Crores

# Simulate a user clicking "Predict Price" on your website
test_user = {
    'Main Location': 'DHA Phase 2',
    'Building': 'None',
    'Area(Marla)': 10.0,
    'Property era': 'Brand New (2025)',
    'Floor Level': 'Ground/First Floor',
    'Building Type': 'Ground/Flat',
    'Elevator Capacity': 'Single/None',
    'Bedroom(s)':3, 'Bath(s)':4, 'Kitchens':6, 'Parking Spaces':3, 'Servant Quarters':2
}

print(f"Predicted Market Price: {get_valuation(test_user)} Crores")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 31
#      19 # Simulate a user clicking "Predict Price" on your website
#      20 test_user = {
#      21     'Main Location': 'DHA Phase 2',
#      22     'Building': 'None',
#    (...)
#      28     'Bedroom(s)':3, 'Bath(s)':4, 'Kitchens':6, 'Parking Spaces':3, 'Servant Quarters':2
#      29 }
# ---> 31 print(f"Predicted Market Price: {get_valuation(test_user)} Crores")
#
# Cell In[86], line 15, in get_valuation(user_form_data)
#      12 df_input = pd.DataFrame([user_form_data])
#      14 # The pipeline handles ALL the mapping, encoding, and math automatically
# ---> 15 prediction = real_estate_ai.predict(df_input)
#      17 return round(prediction[0], 2)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:746, in Pipeline.predict(self, X, **params)
#     744     for _, name, transform in self._iter(with_final=False):
#     745         Xt = transform.transform(Xt)
# --> 746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#     749 routed_params = process_routing(self, "predict", **params)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:1446, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1444 if self._can_use_inplace_predict():
#    1445     try:
# -> 1446         predts = self.get_booster().inplace_predict(
#    1447             data=X,
#    1448             iteration_range=iteration_range,
#    1449             predict_type="margin" if output_margin else "value",
#    1450             missing=self.missing,
#    1451             base_margin=base_margin,
#    1452             validate_features=validate_features,
#    1453         )
#    1454         if _is_cupy_alike(predts):
#    1455             cp = import_cupy()
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:2873, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2870 if _is_np_array_like(data):
#    2871     from .data import _ensure_np_dtype
# -> 2873     data, _ = _ensure_np_dtype(data, data.dtype)
#    2874     _check_call(
#    2875         _LIB.XGBoosterPredictFromDense(
#    2876             self.handle,
#    (...)
#    2883         )
#    2884     )
#    2885     return _prediction_output(shape, dims, preds, False)
#
# File ~\anaconda3\Lib\site-packages\xgboost\_data_utils.py:384, in _ensure_np_dtype(data, dtype)
#     382 if array_hasobject(data) or data.dtype in [np.float16, np.bool_]:
#     383     dtype = np.float32
# --> 384     data = data.astype(dtype, copy=False)
#     385 if not data.flags.aligned:
#     386     data = np.require(data, requirements="A")
#
# ValueError: could not convert string to float: 'DHA Phase 2'

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from category_encoders import TargetEncoder
from xgboost import XGBRegressor

# ==========================================
# 1. DEFINE CUSTOM TRANSFORMERS
# ==========================================

# Transformer for your custom ordinal dictionary scales
class CustomOrdinalMapper(BaseEstimator, TransformerMixin):
    def __init__(self, mappings):
        self.mappings = mappings
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X_copy = X.copy()
        for col, mapping_dict in self.mappings.items():
            if col in X_copy.columns:
                X_copy[col] = X_copy[col].map(mapping_dict).fillna(1).astype(int)
        return X_copy

# Transformer for your log transformations that preserves DataFrames
class DataFrameLogTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X_copy = X.copy()
        for col in self.columns:
            if col in X_copy.columns:
                X_copy[col] = np.log1p(X_copy[col].astype(float))
        return X_copy


# ==========================================
# 2. SET UP CONFIGURATIONS & MASTER PIPELINE
# ==========================================

all_mappings = {
    'Property era': {
        'Vintage': 1, 'Established': 2, 'Recently Built': 3, 
        'Modern Era': 4, 'Brand New (2025)': 5, 'Future': 6
    },
    'Floor Level': {
        'Lower Floors': 1, 'Ground/First Floor': 2, 'Mid-Level': 3, 'High-Rise': 4
    },
    'Building Type': {
        'Ground/Flat': 1, 'Lower Levels': 2, 'Mid Rise Core': 3, 
        'High Rise': 4, 'Skyscarper': 5
    },
    'Elevator Capacity': {
        'Single/None': 1, 'Dual Setup': 2, 'Multiple Bank': 3, 'High-Capacity': 4
    }
}

# Assemble a clean, linear, pure DataFrame pipeline
production_pipeline = Pipeline([
    # Step 1: Map manual categorical text hierarchies to ordered integers
    ('ordinal_maps', CustomOrdinalMapper(all_mappings)),
    
    # Step 2: Target Encode location data (EXPLICITLY declaring cols here fixes the bug)
    ('target_encode', TargetEncoder(
        cols=['Main Location', 'Building'], 
        smoothing=20, 
        min_samples_leaf=2, 
        handle_unknown='value'
    )),
    
    # Step 3: Log transform the area column smoothly inline
    ('log_transform', DataFrameLogTransformer(columns=['Area(Marla)'])),
    
    # Step 4: Your elite production XGBoost model state
    ('model', best_model)
])


# ==========================================
# 3. TRAIN AND PICKLE
# ==========================================

# Fit the entire pipeline on your completely RAW, untouched training dataframe
print("Training production pipeline...")
production_pipeline.fit(X_train, y_train['Price(Cr)'])

# Save the master pipeline to disk
joblib.dump(production_pipeline, 'pak_real_estate_pipeline.pkl')
print("Success! Saved as pak_real_estate_pipeline.pkl")
# Out:
# Training production pipeline...
# Success! Saved as pak_real_estate_pipeline.pkl

# %%
# Load the newly exported asset
real_estate_ai = joblib.load('pak_real_estate_pipeline.pkl')

def get_valuation(user_form_data):
    # Convert input dict to a 1-row DataFrame
    df_input = pd.DataFrame([user_form_data])
    
    # Predict directly using the streamlined pipeline
    prediction = real_estate_ai.predict(df_input)
    return round(prediction[0], 2)

# Your exact test user profile
test_user = {     
    'Main Location': 'F-8',     
    'Building': 'The Centaurus',   
    'Area(Marla)': 10000.0,
    'Property era': 'Brand New (2025)',
    'Floor Level': 'Ground/First Floor',
    'Building Type': 'Ground/Flat',
    'Elevator Capacity': 'Single/None',
    'Bedroom(s)': 30, 
    'Bath(s)': 20, 
    'Kitchens': 6, 
    'Parking Spaces': 5, 
    'Servant Quarters': 2
}

print(f"Predicted Market Price: {get_valuation(test_user)} Crores")
# Out:
# Predicted Market Price: 4.449999809265137 Crores

# %%
pd.DataFrame(test_user,index=[0])
# Out:
#   Main Location       Building  Area(Marla)      Property era  \
# 0           F-8  The Centaurus      10000.0  Brand New (2025)
#
#           Floor Level Building Type Elevator Capacity  Bedroom(s)  Bath(s)  \
# 0  Ground/First Floor   Ground/Flat       Single/None          30       20
#
#    Kitchens  Parking Spaces  Servant Quarters
# 0         6               5                 2

# %%
best_model.predict(pd.DataFrame(test_user,index=[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 best_model.predict(pd.DataFrame(test_user,index=[0]))
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\sklearn.py:1463, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1459     except TypeError:
#    1460         # coo, csc, dt
#    1461         pass
# -> 1463 test = DMatrix(
#    1464     X,
#    1465     base_margin=base_margin,
#    1466     missing=self.missing,
#    1467     nthread=self.n_jobs,
#    1468     feature_types=self.feature_types,
#    1469     enable_categorical=self.enable_categorical,
#    1470 )
#    1471 return self.get_booster().predict(
#    1472     data=test,
#    1473     iteration_range=iteration_range,
#    1474     output_margin=output_margin,
#    1475     validate_features=validate_features,
#    1476 )
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\anaconda3\Lib\site-packages\xgboost\core.py:999, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     996     assert self.handle is not None
#     997     return
# --> 999 handle, feature_names, feature_types = dispatch_data_backend(
#    1000     data=data,
#    1001     missing=self.missing,
#    1002     threads=self.nthread,
#    1003     feature_names=feature_names,
#    1004     feature_types=feature_types,
#    1005     enable_categorical=enable_categorical,
#    1006     data_split_mode=data_split_mode,
#    1007 )
#    1008 assert handle is not None
#    1009 self.handle = handle
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:1464, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1462     assert check_cats(feature_types)
#    1463     array = np.asarray(data)
# -> 1464     return _from_numpy_array(
#    1465         data=array,
#    1466         missing=missing,
#    1467         nthread=threads,
#    1468         feature_names=feature_names,
#    1469         feature_types=feature_types,
#    1470     )
#    1472 converted = _convert_unknown_data(data)
#    1473 if converted is not None:
#
# File ~\anaconda3\Lib\site-packages\xgboost\data.py:285, in _from_numpy_array(data, missing, nthread, feature_names, feature_types, data_split_mode)
#     283 """Initialize data from a 2-D numpy matrix."""
#     284 _check_data_shape(data)
# --> 285 data, _ = _ensure_np_dtype(data, data.dtype)
#     286 handle = ctypes.c_void_p()
#     287 _check_call(
#     288     _LIB.XGDMatrixCreateFromDense(
#     289         array_interface(data),
#    (...)
#     296     )
#     297 )
#
# File ~\anaconda3\Lib\site-packages\xgboost\_data_utils.py:384, in _ensure_np_dtype(data, dtype)
#     382 if array_hasobject(data) or data.dtype in [np.float16, np.bool_]:
#     383     dtype = np.float32
# --> 384     data = data.astype(dtype, copy=False)
#     385 if not data.flags.aligned:
#     386     data = np.require(data, requirements="A")
#
# ValueError: could not convert string to float: 'F-8'
