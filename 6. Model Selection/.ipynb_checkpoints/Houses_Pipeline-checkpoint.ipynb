# %% [markdown]
# # Outline
#
# - Test the best model from model selection
# - Make Pickle file for pipeline and model

# %%
import numpy as np
import pandas as pd

# %%
X_train = pd.read_csv('../4. Missing Values Imputation/Houses/X_train.csv',index_col=0)
X_test = pd.read_csv('../4. Missing Values Imputation/Houses/X_test.csv',index_col=0)
y_train = pd.read_csv('../4. Missing Values Imputation/Houses/y_train.csv',index_col=0)
y_test = pd.read_csv('../4. Missing Values Imputation/Houses/y_test.csv',index_col=0)

# %%
X_train
# Out:
#       Bath(s)  Area(Marla)  Bedroom(s)  Servant Quarters  Kitchens  \
# 906       5.0          7.0         5.0               1.0       2.0
# 3379      6.0         10.0         5.0               1.0       2.0
# 2094      4.0          5.0         3.0               1.0       2.0
# 218       6.0         14.0         6.0               1.0       1.0
# 3455      5.0          4.0         5.0               1.0       2.0
# ...       ...          ...         ...               ...       ...
# 5175      5.0         20.0         5.0               2.0       2.0
# 686       7.0         20.0         6.0               1.0       1.0
# 4631      4.0          4.0         4.0               1.0       2.0
# 5701      7.0         26.0         6.0               2.0       2.0
# 1246      4.0         11.0         4.0               1.0       2.0
#
#       Store Rooms  Storey Unit          Main Location  IsPrimeLoc  \
# 906           1.0          2.0                   D-12       False
# 3379          1.0          2.0         Bahria Enclave       False
# 2094          1.0          2.0  MPCHS - Multi Gardens        True
# 218           1.0          2.0                    G-9        True
# 3455          1.0          2.0                   G-13        True
# ...           ...          ...                    ...         ...
# 5175          2.0          2.0            DHA Phase 2       False
# 686           1.0          2.0                   G-13       False
# 4631          1.0          2.0                   G-13       False
# 5701          2.0          2.0                    F-7       False
# 1246          2.0          2.0            DHA Phase 1       False
#
#       SolarInstalled  WaterBore  CornerHouse  luxury_type      Property era
# 906            False      False        False            0  Brand New (2025)
# 3379           False      False        False            0  Brand New (2025)
# 2094           False      False         True            0  Brand New (2025)
# 218            False      False        False            0  Brand New (2025)
# 3455           False      False        False            0  Brand New (2025)
# ...              ...        ...          ...          ...               ...
# 5175           False      False        False            0    Recently Built
# 686            False      False        False            1  Brand New (2025)
# 4631           False      False        False            0  Brand New (2025)
# 5701           False      False        False            0    Recently Built
# 1246           False      False        False            0  Brand New (2025)
#
# [2878 rows x 14 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler,FunctionTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score,mean_absolute_error
from category_encoders import TargetEncoder
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from sklearn import set_config

set_config(transform_output='pandas')

# %%
X_train['Plot_Size_Sqft'] = X_train['Area(Marla)'] * 272.251
FOOTPRINT_FACTOR = 0.8
X_train['Total Built up space'] = X_train['Plot_Size_Sqft'] * FOOTPRINT_FACTOR * X_train['Storey Unit']

X_test['Plot_Size_Sqft'] = X_test['Area(Marla)'] * 272.251
FOOTPRINT_FACTOR = 0.8
X_test['Total Built up space'] = X_test['Plot_Size_Sqft'] * FOOTPRINT_FACTOR * X_test['Storey Unit']

# %%
X_train.drop(columns=['Servant Quarters','Kitchens','Store Rooms','luxury_type','Plot_Size_Sqft'],inplace=True)
X_test.drop(columns=['Servant Quarters','Kitchens','Store Rooms','luxury_type','Plot_Size_Sqft'],inplace=True)

# %%
# --- 1. PREPARE THE RAW PKR TARGETS ---
# Multiply by 1 Crore to get raw PKR
y_train_raw = y_train['Price(Cr)'] * 10000000
y_test_raw = y_test['Price(Cr)'] * 10000000

# Apply standard log
y_train_log = np.log(y_train_raw)
y_test_log = np.log(y_test_raw)

# %%
numeric_transformer = Pipeline(steps=[
    ('Log', FunctionTransformer(np.log1p)),
    ('Scale', RobustScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        # ('Custom Ordinal Encoder',CustomOrdinalMapperHouses(all_mappings_houses),categorical_cols),
        ('TargetEncoding', TargetEncoder(smoothing=5, min_samples_leaf=2, handle_unknown='value'), ['Main Location','Property era']),
        ('NumericTransform', numeric_transformer, ['Area(Marla)', 'Total Built up space']),
        ('DropRedundant', 'drop', ['Storey Unit'])
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
)

X_train_transformed = preprocessor.fit_transform(X_train, y_train_log)
X_test_transformed = preprocessor.transform(X_test)

# %%
overfitted_params = {'n_estimators': 1000,
 'max_depth': 15,
 'learning_rate': 0.00505825958265549,
 'subsample': 0.8944998368111671,
 'colsample_bytree': 0.9305368372411382,
 'colsample_bylevel': 0.7407153424980754,
 'gamma': 0.021373237297058784,
 'min_child_weight': 4,
 'reg_alpha': 0.005116450915274579,
 'reg_lambda': 0.0007460273123214234,
 'grow_policy': 'lossguide',
 'max_leaves': 52}

improved_params = {
 'n_estimators': 1000,          # Keep this, but make sure to use early_stopping_rounds!
 'max_depth': 5,                # Drastically reduced to stop memorizing rows
 'learning_rate': 0.005,        
 'subsample': 0.89,
 'colsample_bytree': 0.93,
 'colsample_bylevel': 0.74,
 'gamma': 0.1,                  # Increased to prune useless branches
 'min_child_weight': 1,         # Reduced so rare 2-storey units aren't ignored
 'reg_alpha': 0.005,
 'reg_lambda': 0.001,
 'grow_policy': 'lossguide',
 'max_leaves': 15               # Reduced to prevent overly complex trees
}

# %%
y_train_log
# Out:
# 906     18.395363
# 3379    17.622173
# 2094    17.073607
# 218     18.298513
# 3455    17.370859
#           ...
# 5175    18.459901
# 686     18.839391
# 4631    17.356470
# 5701    20.212440
# 1246    17.529083
# Name: Price(Cr), Length: 2878, dtype: float64

# %%
X_train_transformed.columns
# Out:
# Index(['Main Location', 'Property era', 'Area(Marla)', 'Total Built up space',
#        'Bath(s)', 'Bedroom(s)', 'IsPrimeLoc', 'SolarInstalled', 'WaterBore',
#        'CornerHouse'],
#       dtype='object')

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import XGBRegressor

# --- 1. PREPARE THE RAW PKR TARGETS ---
# Multiply by 1 Crore to get raw PKR
y_train_raw = y_train['Price(Cr)'] * 10000000
y_test_raw = y_test['Price(Cr)'] * 10000000

# Apply standard log
y_train_log = np.log(y_train_raw)
y_test_log = np.log(y_test_raw)

# --- 2. RETRAIN THE MODEL FROM SCRATCH ---
# Re-initialize to clear old memory
best_model = XGBRegressor(**improved_params)

best_model.fit(
    X_train_transformed, 
    y_train_log, # Train on the new log-PKR targets
    eval_set=[(X_train_transformed, y_train_log), (X_test_transformed, y_test_log)],
    verbose=100
)

# --- 3. PREDICT AND REVERSE ---
# Predict (outputs will be in log-PKR)
y_pred_log = best_model.predict(X_test_transformed)

# Reverse the log back to raw PKR
y_pred_pkr = np.exp(y_pred_log)

# --- 4. CALCULATE TRUE ERROR ---
r2 = r2_score(y_test_raw, y_pred_pkr)
mae_pkr = mean_absolute_error(y_test_raw, y_pred_pkr)

print("\n--- FINAL RESULTS ---")
print(f"R-Squared Score: {r2:.3f}")
print(f"Average Error: {mae_pkr:,.0f} PKR")
# Out:
# [0]	validation_0-rmse:0.94270	validation_1-rmse:0.92266
# [100]	validation_0-rmse:0.61515	validation_1-rmse:0.61242
# [200]	validation_0-rmse:0.42179	validation_1-rmse:0.43208
# [300]	validation_0-rmse:0.31025	validation_1-rmse:0.33042
# [400]	validation_0-rmse:0.25047	validation_1-rmse:0.27772
# [500]	validation_0-rmse:0.21901	validation_1-rmse:0.25067
# [600]	validation_0-rmse:0.20215	validation_1-rmse:0.23669
# [700]	validation_0-rmse:0.19204	validation_1-rmse:0.22867
# [800]	validation_0-rmse:0.18540	validation_1-rmse:0.22379
# [900]	validation_0-rmse:0.18053	validation_1-rmse:0.22060
# [999]	validation_0-rmse:0.17671	validation_1-rmse:0.21821
#
# --- FINAL RESULTS ---
# R-Squared Score: 0.933
# Average Error: 13,902,220 PKR

# %%
test_input = X_train.iloc[:5]

# %%
test_input
# Out:
#       Bath(s)  Area(Marla)  Bedroom(s)  Storey Unit          Main Location  \
# 906       5.0          7.0         5.0          2.0                   D-12
# 3379      6.0         10.0         5.0          2.0         Bahria Enclave
# 2094      4.0          5.0         3.0          2.0  MPCHS - Multi Gardens
# 218       6.0         14.0         6.0          2.0                    G-9
# 3455      5.0          4.0         5.0          2.0                   G-13
#
#       IsPrimeLoc  SolarInstalled  WaterBore  CornerHouse      Property era  \
# 906        False           False      False        False  Brand New (2025)
# 3379       False           False      False        False  Brand New (2025)
# 2094        True           False      False         True  Brand New (2025)
# 218         True           False      False        False  Brand New (2025)
# 3455        True           False      False        False  Brand New (2025)
#
#       Total Built up space
# 906              3049.2112
# 3379             4356.0160
# 2094             2178.0080
# 218              6098.4224
# 3455             1742.4064

# %%
test_input_transformed = preprocessor.transform(test_input)

# %%
y_pred_test_log = best_model.predict(test_input_transformed)
y_pred_test = np.exp(y_pred_test_log)
r2_score(y_train[:5]*10000000,y_pred_test)
# Out:
# 0.574460506439209

# %%
mean_absolute_error(y_train[:5]*10000000,y_pred_test)
# Out:
# 13986102.0

# %%
y_train[:5]
# Out:
#       Price(Cr)
# 906        9.75
# 3379       4.50
# 2094       2.60
# 218        8.85
# 3455       3.50

# %%
model_pipeline = Pipeline(
    [
        ('Preprocessor',preprocessor),
        ('Model',best_model)
    ]
)

# %%
model_pipeline.fit(X_train,y_train_log)
# Out:
# Pipeline(steps=[('Preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('TargetEncoding',
#                                                   TargetEncoder(min_samples_leaf=2,
#                                                                 smoothing=5),
#                                                   ['Main Location',
#                                                    'Property era']),
#                                                  ('NumericTransform',
#                                                   Pipeline(steps=[('Log',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('Scale',
#                                                                    RobustScaler())]),
#                                                   ['Area(Marla)',
#                                                    'Total Built up space']),
#                                                  ('DropRedundant',...
#                               feature_types=None, feature_weights=None,
#                               gamma=0.1, grow_policy='lossguide',
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.005,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=5, max_leaves=15, min_child_weight=1,
#                               missing=nan, monotone_constraints=None,
#                               multi_strategy=None, n_estimators=1000,
#                               n_jobs=None, num_parallel_tree=None, ...))])

# %%
np.exp(model_pipeline.predict(X_train[:5]))
# Out:
# array([6.8944272e+07, 4.6592580e+07, 2.3995520e+07, 1.1871764e+08,
#        4.2560080e+07], dtype=float32)

# %%
# Dump the best pipeline
import joblib

joblib.dump(model_pipeline,'pipeline_pickle_houses_new.joblib')
# Out:
# ['pipeline_pickle_houses_new.joblib']

# %%
test_input_transformed.columns
# Out:
# Index(['Main Location', 'Property era', 'Area(Marla)', 'Total Built up space',
#        'Bath(s)', 'Bedroom(s)', 'Kitchens', 'IsPrimeLoc', 'SolarInstalled',
#        'WaterBore', 'CornerHouse'],
#       dtype='object')

# %%
import joblib
model = joblib.load('pipeline_pickle_houses_new.joblib')

# %%
y_pred =model.predict(X_test)
y_pred = np.exp(y_pred)
r2_score(y_test_raw,y_pred)
# Out:
# 0.9340476821144535

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.3294177055358887

# %%
model.feature_names_in_
# Out:
# array(['Bath(s)', 'Area(Marla)', 'Bedroom(s)', 'Servant Quarters',
#        'Kitchens', 'Store Rooms', 'Storey Unit', 'Main Location',
#        'IsPrimeLoc', 'SolarInstalled', 'WaterBore', 'CornerHouse',
#        'luxury_type', 'Property era', 'Plot_Size_Sqft',
#        'Total Built up space'], dtype=object)
